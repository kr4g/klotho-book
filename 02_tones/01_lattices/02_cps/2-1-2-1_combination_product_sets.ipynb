# %% [markdown]
# ---
# jupyter: false
# ---
#
# # 02 | Tones | 04 | Combination Product Sets

# %%
import sympy as sp
from fractions import Fraction
import numpy as np

from klotho import plot, play
from klotho.topos.collections import CombinationSet as CS
from klotho.tonos import (
    CombinationProductSet, Hexany, Eikosany, Hebdomekontany, MasterSet,
    PitchCollection as PC, Chord, ChordSequence,
)
from klotho.tonos.systems.combination_product_sets import match_pattern
# Out:
# <script>
# if (!globalThis.__klothoSonic) {
#     globalThis.__klothoSonic = { instance: null, promise: null, loadedDefs: new Set() };
#     globalThis.__klothoSonic.promise = (async function() {
#         try {
#             var config = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
#             var mod = await import("https://unpkg.com/supersonic-scsynth@latest");
#             globalThis.SuperSonic = mod.SuperSonic;
#             var sonic = new mod.SuperSonic(config);
#             await sonic.init();
#             globalThis.__klothoSonic.instance = sonic;
#             return sonic;
#         } catch(e) {
#             console.warn("[Klotho] SuperSonic session boot failed:", e);
#             globalThis.__klothoSonic.promise = null;
#             return null;
#         }
#     })();
# }
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (!state) {
#             state = { instance: null, promise: null, loadedDefs: new Set() };
#             globalThis.__klothoSonic = state;
#         }
#         if (state.instance) return Promise.resolve(state.instance);
#         if (state.promise) return state.promise;
#         return Promise.resolve(null);
#     };
# }
# (function() {
#   if (globalThis.DrawScheduler) return;
#   globalThis.DrawScheduler = class {
#     constructor() {
#       this._queue = [];
#       this._running = false;
#     }
#
#     schedule(callback, timeMs) {
#       var lo = 0, hi = this._queue.length;
#       while (lo < hi) {
#         var mid = (lo + hi) >>> 1;
#         if (this._queue[mid].time <= timeMs) lo = mid + 1;
#         else hi = mid;
#       }
#       this._queue.splice(lo, 0, { time: timeMs, callback: callback });
#       if (!this._running) this._startLoop();
#     }
#
#     _startLoop() {
#       this._running = true;
#       var self = this;
#       function tick() {
#         if (!self._running) return;
#         var now = performance.now();
#         while (self._queue.length && self._queue[0].time <= now) {
#           var item = self._queue.shift();
#           try { item.callback(); } catch(e) {}
#         }
#         if (self._queue.length || self._running) {
#           requestAnimationFrame(tick);
#         }
#       }
#       requestAnimationFrame(tick);
#     }
#
#     clear() {
#       this._queue = [];
#       this._running = false;
#     }
#   };
# })();
#
# (function() {
#   if (globalThis.BrowserScheduler) return;
#
#   var MAX_EVENTS_PER_BATCH = 500;
#   var BATCH_OVERLAP_RATIO = 0.8;
#   var NTP_EPOCH_OFFSET = 2208988800;
#   var STARTUP_DELAY = 0.1;
#   var DEFAULT_RING_TIME = 5;
#   var FIRST_PRIVATE_BUS = 16;
#   var BUS_CHANNELS = 2;
#
#   function getNTP() {
#     return (performance.timeOrigin + performance.now()) / 1000 + NTP_EPOCH_OFFSET;
#   }
#
#   globalThis.BrowserScheduler = class {
#     constructor(config) {
#       this.sonic = config.sonic;
#       this.manifest = config.manifest || { synths: {}, inserts: {} };
#       this.ringTime = (config.ringTime != null) ? config.ringTime : DEFAULT_RING_TIME;
#
#       this.isPlaying = false;
#       this.stopToken = 0;
#       this.nodeMap = new Map();
#       this._defNames = new Map();
#
#       this._scoreGroupId = null;
#       this._groupId = null;
#       this._trackMap = null;
#       this._controlGroupId = null;
#       this._controlBusMap = [];
#       this._nextAudioBus = FIRST_PRIVATE_BUS;
#       this._nextControlBus = 0;
#       this._activeBuffers = [];
#
#       this._playStartNTP = 0;
#       this._playStartPerfMs = 0;
#       this._batchTimeoutId = null;
#       this._finishTimeoutId = null;
#       this._deferredRings = [];
#
#       this.drawScheduler = new DrawScheduler();
#       this.onEvent = null;
#       this.onFinish = null;
#     }
#
#     _createGroup() {
#       var gid = this.sonic.nextNodeId();
#       this.sonic.send('/g_new', gid, 0, 0);
#       this._groupId = gid;
#     }
#
#     _freeGroup() {
#       if (this._groupId == null) return;
#       try { this.sonic.send('/g_freeAll', this._groupId); } catch(e) {}
#       try { this.sonic.send('/n_free', this._groupId); } catch(e) {}
#       this._groupId = null;
#     }
#
#     _freeGroupDeferred(groupId) {
#       var sonic = this.sonic;
#       var ringMs = this.ringTime * 1000;
#       var bufs = this._activeBuffers.slice();
#       var tid = setTimeout(function() {
#         try { sonic.send('/g_freeAll', groupId); } catch(e) {}
#         try { sonic.send('/n_free', groupId); } catch(e) {}
#         for (var i = 0; i < bufs.length; i++) {
#           try { sonic.send('/b_free', bufs[i]); } catch(e) {}
#         }
#       }, ringMs);
#       this._deferredRings.push({ tid: tid, gid: groupId });
#       this._activeBuffers = [];
#     }
#
#     _freeBuffers() {
#       for (var i = 0; i < this._activeBuffers.length; i++) {
#         try { this.sonic.send('/b_free', this._activeBuffers[i]); } catch(e) {}
#       }
#       this._activeBuffers = [];
#     }
#
#     _cancelAllDeferredRings() {
#       for (var i = 0; i < this._deferredRings.length; i++) {
#         clearTimeout(this._deferredRings[i].tid);
#         var gid = this._deferredRings[i].gid;
#         try { this.sonic.send('/g_freeAll', gid); } catch(e) {}
#         try { this.sonic.send('/n_free', gid); } catch(e) {}
#       }
#       this._deferredRings = [];
#     }
#
#     _getByPath(obj, path) {
#       if (!obj || !path) return undefined;
#       var parts = path.split('.');
#       var cur = obj;
#       for (var i = 0; i < parts.length; i++) {
#         var key = parts[i];
#         if (cur == null || typeof cur !== 'object' || !(key in cur)) return undefined;
#         cur = cur[key];
#       }
#       return cur;
#     }
#
#     _resolveDefPfields(defName, pfields) {
#       var out = {};
#       for (var key in pfields) {
#         if (!pfields.hasOwnProperty(key)) continue;
#         var val = pfields[key];
#         if (val === null || val === undefined) continue;
#         if (typeof val === 'object') continue;
#         out[key] = val;
#       }
#       var meta = (this.manifest.synths || {})[defName] || {};
#       var paths = meta.paths || {};
#       for (var srcPath in paths) {
#         if (!paths.hasOwnProperty(srcPath)) continue;
#         var dstKey = paths[srcPath];
#         var mapped = this._getByPath(pfields, srcPath);
#         if (mapped === undefined || mapped === null) continue;
#         if (typeof mapped === 'object') continue;
#         out[dstKey] = mapped;
#       }
#       return out;
#     }
#
#     _resolveDefName(name) {
#       if (name === "__rest__") return "__rest__";
#       if (!name || name === "sonic-pi-beep") return "kl_tri";
#       return name;
#     }
#
#     _bundleNew(ev, ntp) {
#       if (ev.defName === "__rest__") return;
#       var defName = this._resolveDefName(ev.defName);
#       var nodeId = this.sonic.nextNodeId();
#
#       var target;
#       var pf = this._resolveDefPfields(defName, ev.pfields || {});
#
#       if (this._trackMap) {
#         var group = ev.group || "default";
#         var trackInfo = this._trackMap[group] || this._trackMap["default"] || this._trackMap["main"];
#         target = trackInfo ? trackInfo.srcGroup : (this._scoreGroupId || this._groupId || 0);
#         if (trackInfo) {
#           pf.out = trackInfo.srcBus;
#         }
#       } else {
#         target = this._groupId != null ? this._groupId : 0;
#       }
#
#       var args = [defName, nodeId, 0, target];
#       for (var key in pf) {
#         if (!pf.hasOwnProperty(key)) continue;
#         var v = pf[key];
#         if (v === undefined || v === null || typeof v === 'object') continue;
#         args.push(key, v);
#       }
#       var bundle = globalThis.SuperSonic.osc.encodeSingleBundle(ntp, '/s_new', args);
#       this.sonic.sendOSC(bundle);
#       this.nodeMap.set(ev.id, nodeId);
#       this._defNames.set(ev.id, defName);
#
#       if (typeof this._getControlMappingsForEvent === 'function') {
#         var mappings = this._getControlMappingsForEvent(ev.id);
#         if (mappings) {
#           for (var mi = 0; mi < mappings.length;

# %%
def chord_from_shape(cps, shape, root='C4'):
    ratios = sorted(cps.graph[n]['ratio'] for n in shape)
    return Chord(ratios).root(root)

def chords_from_matches(cps, matches, root='C4'):
    return ChordSequence([chord_from_shape(cps, m, root) for m in matches])

# %% [markdown]
# # Combination Product Sets

# %% [markdown]
# ***Combination Product Sets*** (**CPS**) are a special type of lattice structure created by Erv Wilson.
#
# So far, all the lattices we've looked at had a tonal center—meaning, there is an origin where the ratio is `1` and all other points represent successive multiplications.
#
# **CPS** lattices are different in that there is no tonal center—i.e., there is no origin. Which is to say, there is no hierarchy. There is no "gravity".

# %% [markdown]
# ### Deriving CPS
#
# Ok, here's the deal: there's really no easy way to explain this without being a little confusing so I'm just going go through it step-by-step and (hopefully) it'll all make sense in the end.
#
# Don't worry, just follow along...

# %% [markdown]
# #### 1. Initial Set
#
# Imagine we have a collection of *`n`*-elements:
#
# $$\{A\ B\ C\ D\}$$
#
# In this case, `4` elements. These letters don't represent note names, they're just algebraic variables—they could have been emojis instead of letters, it really doesn't matter.

# %% [markdown]
# #### 2. Arrange the Elements Spatially
#
# Arrange each element so that we form a ***complete graph***. A *complete graph* means a graph where every node is connected to every other node.

# %%
plot(MasterSet.tetrad(), figsize=(7,7))
# Out:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><text x="350.0" y="18" text-anchor="middle" font-family="Arial" font-size="14" fill="white">MasterSet: tetrad</text>
# <line x1="350.00" y1="427.72" x2="80.77" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <line x1="350.00" y1="427.72" x2="350.00" y2="116.84" stroke="#808080" stroke-width="1.5"/>
# <line x1="350.00" y1="427.72" x2="619.23" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <line x1="80.77" y1="583.16" x2="350.00" y2="116.84" stroke="#808080" stroke-width="1.5"/>
# <line x1="350.00" y1="116.84" x2="619.23" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <line x1="619.23" y1="583.16" x2="80.77" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <circle cx="80.77" cy="583.16" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgms_11a1c7b3"/>
# <text x="80.77" y="584.16" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">A</text>
# <circle cx="350.00" cy="116.84" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgms_11a1c7b3"/>
# <text x="350.00" y="117.84" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">B</text>
# <circle cx="619.23" cy="583.16" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgms_11a1c7b3"/>
# <text x="619.23" y="584.16" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">C</text>
# <circle cx="350.00" cy="427.72" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgms_11a1c7b3"/>
# <text x="350.00" y="428.72" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">D</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
#     }
#
#     function reorderEventsFrom(allEvents, startGi, total, gap) {
#       var gapSec = typeof gap === "number" ? Math.max(0, gap) : _pause;
#       var buckets = [];
#       for (var g = 0; g < total; g++) buckets.push([]);
#       for (var i = 0; i < allEvents.length; i++) {
#         var si = allEvents[i]._stepIndex;
#         if (si >= 0 && si < total) buckets[si].push(allEvents[i]);
#       }
#       var groupStarts = [];
#       for (var g1 = 0; g1 < total; g1++) {
#         var mn = Infinity;
#         for (var i1 = 0; i1 < buckets[g1].length; i1++) {
#           if (buckets[g1][i1].start < mn) mn = buckets[g1][i1].start;
#         }
#         groupStarts.push(mn === Infinity ? 0 : mn);
#       }
#       var groupDurs = [];
#       for (var g2 = 0; g2 < total; g2++) {
#         var mx = 0;
#         for (var i2 = 0; i2 < buckets[g2].length; i2++) {
#           var end = eventEnd(buckets[g2][i2]);
#           if (end > mx) mx = end;
#         }
#         groupDurs.push(mx - groupStarts[g2]);
#       }
#       var result = [];
#       var cursor = 0;
#       var seqMap = [];
#       for (var step = 0; step < total; step++) {
#         var gi = (startGi + step) % total;
#         seqMap.push(gi);
#         var base = groupStarts[gi];
#         for (var i3 = 0; i3 < buckets[gi].length; i3++) {
#           var e2 = {};
#           for (var k2 in buckets[gi][i3]) e2[k2] = buckets[gi][i3][k2];
#           e2.start = cursor + (buckets[gi][i3].start - base);
#           e2._stepIndex = step;
#           result.push(e2);
#         }
#         cursor += groupDurs[gi] + gapSec;
#       }
#       return { events: result, seqMap: seqMap };
#     }
#
#     function isPlaying() {
#       if (engine === "supersonic") return !!(_ssScheduler && _ssScheduler.isPlaying);
#       return !!(_aPlayer && _aPlayer.isPlaying());
#     }
#
#     async function stop() {
#       if (engine === "supersonic") {
#         if (_ssScheduler && _ssScheduler.isPlaying) await _ssScheduler.stop();
#         return;
#       }
#       if (_aPlayer && _aPlayer.isPlaying()) _aPlayer.stop();
#     }
#
#     async function resumeAudio() {
#       if (engine === "supersonic") {
#         if (_ssSonic && _ssSonic.audioContext && _ssSonic.audioContext.state === "suspended") {
#           await _ssSonic.audioContext.resume();
#         }
#         return;
#       }
#       if (typeof Tone !== "undefined" && Tone.context && Tone.context.state === "suspended") {
#         try { await Tone.start(); } catch(_) {}
#         try { await Tone.context.resume(); } catch(_) {}
#       }
#     }
#
#     async function play(ev

# %% [markdown]
# Ok, this geometric form is what we're calling our ***generating tetrad***. Put it aside for now, we're going to use it later...

# %% [markdown]
# #### 3. Compute *`k`*-wise Groupings

# %% [markdown]
# We started with `4` elements ($\{A\ B\ C\ D\}$), let's find every possible pairing, or `2`-wise grouping of elements:

# %%
elems = ('A', 'B', 'C', 'D')

for combo in CS(elems, 2).combos:
  print(*combo, end='\n\n')
# Out:
# A B
#
# A D
#
# C D
#
# B D
#
# B C
#
# A C

# %% [markdown]
# #### 4. Review Basic Algebra

# %% [markdown]
# That's right, let's review our algebra...

# %%
A, B, C, D = sp.symbols('A B C D', nonzero=True)

e1 = A*B
e2 = A*C
print(f'({e1}) / ({e2}) = {sp.simplify(e1 / e2)}', end='\n\n')

e1 = B*C
e2 = A*C
print(f'({e1}) / ({e2}) = {sp.simplify(e1 / e2)}', end='\n\n')

e1 = B*D
e2 = A*B
print(f'({e1}) / ({e2}) = {sp.simplify(e1 / e2)}', end='\n\n')

print('etc...')
# Out:
# (A*B) / (A*C) = B/C
#
# (B*C) / (A*C) = B/A
#
# (B*D) / (A*B) = D/A
#
# etc...

# %% [markdown]
# Is it all coming back? Ok, good...

# %% [markdown]
# #### 5. Review Basic Geometry
#
# Let's look again at our generating tetrad:

# %%
plot(MasterSet.tetrad(), figsize=(7,7))
# Out:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><text x="350.0" y="18" text-anchor="middle" font-family="Arial" font-size="14" fill="white">MasterSet: tetrad</text>
# <line x1="350.00" y1="427.72" x2="80.77" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <line x1="350.00" y1="427.72" x2="350.00" y2="116.84" stroke="#808080" stroke-width="1.5"/>
# <line x1="350.00" y1="427.72" x2="619.23" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <line x1="80.77" y1="583.16" x2="350.00" y2="116.84" stroke="#808080" stroke-width="1.5"/>
# <line x1="350.00" y1="116.84" x2="619.23" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <line x1="619.23" y1="583.16" x2="80.77" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <circle cx="80.77" cy="583.16" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgms_9224f5b6"/>
# <text x="80.77" y="584.16" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">A</text>
# <circle cx="350.00" cy="116.84" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgms_9224f5b6"/>
# <text x="350.00" y="117.84" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">B</text>
# <circle cx="619.23" cy="583.16" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgms_9224f5b6"/>
# <text x="619.23" y="584.16" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">C</text>
# <circle cx="350.00" cy="427.72" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgms_9224f5b6"/>
# <text x="350.00" y="428.72" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">D</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
#     }
#
#     function reorderEventsFrom(allEvents, startGi, total, gap) {
#       var gapSec = typeof gap === "number" ? Math.max(0, gap) : _pause;
#       var buckets = [];
#       for (var g = 0; g < total; g++) buckets.push([]);
#       for (var i = 0; i < allEvents.length; i++) {
#         var si = allEvents[i]._stepIndex;
#         if (si >= 0 && si < total) buckets[si].push(allEvents[i]);
#       }
#       var groupStarts = [];
#       for (var g1 = 0; g1 < total; g1++) {
#         var mn = Infinity;
#         for (var i1 = 0; i1 < buckets[g1].length; i1++) {
#           if (buckets[g1][i1].start < mn) mn = buckets[g1][i1].start;
#         }
#         groupStarts.push(mn === Infinity ? 0 : mn);
#       }
#       var groupDurs = [];
#       for (var g2 = 0; g2 < total; g2++) {
#         var mx = 0;
#         for (var i2 = 0; i2 < buckets[g2].length; i2++) {
#           var end = eventEnd(buckets[g2][i2]);
#           if (end > mx) mx = end;
#         }
#         groupDurs.push(mx - groupStarts[g2]);
#       }
#       var result = [];
#       var cursor = 0;
#       var seqMap = [];
#       for (var step = 0; step < total; step++) {
#         var gi = (startGi + step) % total;
#         seqMap.push(gi);
#         var base = groupStarts[gi];
#         for (var i3 = 0; i3 < buckets[gi].length; i3++) {
#           var e2 = {};
#           for (var k2 in buckets[gi][i3]) e2[k2] = buckets[gi][i3][k2];
#           e2.start = cursor + (buckets[gi][i3].start - base);
#           e2._stepIndex = step;
#           result.push(e2);
#         }
#         cursor += groupDurs[gi] + gapSec;
#       }
#       return { events: result, seqMap: seqMap };
#     }
#
#     function isPlaying() {
#       if (engine === "supersonic") return !!(_ssScheduler && _ssScheduler.isPlaying);
#       return !!(_aPlayer && _aPlayer.isPlaying());
#     }
#
#     async function stop() {
#       if (engine === "supersonic") {
#         if (_ssScheduler && _ssScheduler.isPlaying) await _ssScheduler.stop();
#         return;
#       }
#       if (_aPlayer && _aPlayer.isPlaying()) _aPlayer.stop();
#     }
#
#     async function resumeAudio() {
#       if (engine === "supersonic") {
#         if (_ssSonic && _ssSonic.audioContext && _ssSonic.audioContext.state === "suspended") {
#           await _ssSonic.audioContext.resume();
#         }
#         return;
#       }
#       if (typeof Tone !== "undefined" && Tone.context && Tone.context.state === "suspended") {
#         try { await Tone.start(); } catch(_) {}
#         try { await Tone.context.resume(); } catch(_) {}
#       }
#     }
#
#     async function play(ev

# %% [markdown]
# We're going to take the angle formed by each pair of adjacent nodes and assign them to the ratios of `node1 / node2` and `node2 / node1`.
#
# What do I mean by this? E.g., take nodes `A` and `B`. The edge between them forms a horizontal line. So, we're going to say that the ratio of `A/B` or `B/A` means an angle of either `0` or `180` degrees.
#
# Look at nodes `C` and `D`. The angle formed by the edge between them is a vertical line. So, we're going to say that the ratio of `C/D` or `D/C` means an angle of either `90` or `270` degrees.
#
# And so on for each pair of adjacent nodes...

# %% [markdown]
# #### 6. Map Ratios to Groups
#
# Find the ratio between each pairing of *`k`*-wise groupings.
#
# If the ratio is an edge-group found in the set of *`k`*-wise groupings, keep it.

# %%
cs = CS(elems, 2)
for combo1 in cs.combos:
  for combo2 in cs.combos:
    if combo1 != combo2:
      e1 = sp.sympify(f'{combo1[0]}/{combo1[1]}')
      e2 = sp.sympify(f'{combo2[0]}/{combo2[1]}')
      simp = sp.simplify(e1 / e2)
      if tuple(str(simp).split('/')) in cs.combos:
        print(f'({e1}) / ({e2}) = {simp}', end='\n\n')
# Out:
# (A/D) / (A/B) = B/D
#
# (A/D) / (C/D) = A/C
#
# (A/D) / (B/D) = A/B
#
# (A/D) / (A/C) = C/D
#
# (B/D) / (C/D) = B/C
#
# (B/D) / (B/C) = C/D
#
# (A/C) / (A/B) = B/C
#
# (A/C) / (B/C) = A/B

# %% [markdown]
# #### 7. Make the Graph
#
# Compare the resultant ratio to the edges in the generating tetrad to determine the angle of the line between them:

# %%
print("GENERATING TETRAD")
plot(MasterSet.tetrad(), figsize=(7,7))

print("\nCPS")
plot(Hexany(), figsize=(7,7))
# Out:
# GENERATING TETRAD
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><text x="350.0" y="18" text-anchor="middle" font-family="Arial" font-size="14" fill="white">MasterSet: tetrad</text>
# <line x1="350.00" y1="427.72" x2="80.77" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <line x1="350.00" y1="427.72" x2="350.00" y2="116.84" stroke="#808080" stroke-width="1.5"/>
# <line x1="350.00" y1="427.72" x2="619.23" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <line x1="80.77" y1="583.16" x2="350.00" y2="116.84" stroke="#808080" stroke-width="1.5"/>
# <line x1="350.00" y1="116.84" x2="619.23" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <line x1="619.23" y1="583.16" x2="80.77" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <circle cx="80.77" cy="583.16" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgms_fb492f88"/>
# <text x="80.77" y="584.16" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">A</text>
# <circle cx="350.00" cy="116.84" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgms_fb492f88"/>
# <text x="350.00" y="117.84" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">B</text>
# <circle cx="619.23" cy="583.16" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgms_fb492f88"/>
# <text x="619.23" y="584.16" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">C</text>
# <circle cx="350.00" cy="427.72" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgms_fb492f88"/>
# <text x="350.00" y="428.72" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">D</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
#     }
#
#     function reorderEventsFrom(allEvents, startGi, total, gap) {
#       var gapSec = typeof gap === "number" ? Math.max(0, gap) : _pause;
#       var buckets = [];
#       for (var g = 0; g < total; g++) buckets.push([]);
#       for (var i = 0; i < allEvents.length; i++) {
#         var si = allEvents[i]._stepIndex;
#         if (si >= 0 && si < total) buckets[si].push(allEvents[i]);
#       }
#       var groupStarts = [];
#       for (var g1 = 0; g1 < total; g1++) {
#         var mn = Infinity;
#         for (var i1 = 0; i1 < buckets[g1].length; i1++) {
#           if (buckets[g1][i1].start < mn) mn = buckets[g1][i1].start;
#         }
#         groupStarts.push(mn === Infinity ? 0 : mn);
#       }
#       var groupDurs = [];
#       for (var g2 = 0; g2 < total; g2++) {
#         var mx = 0;
#         for (var i2 = 0; i2 < buckets[g2].length; i2++) {
#           var end = eventEnd(buckets[g2][i2]);
#           if (end > mx) mx = end;
#         }
#         groupDurs.push(mx - groupStarts[g2]);
#       }
#       var result = [];
#       var cursor = 0;
#       var seqMap = [];
#       for (var step = 0; step < total; step++) {
#         var gi = (startGi + step) % total;
#         seqMap.push(gi);
#         var base = groupStarts[gi];
#         for (var i3 = 0; i3 < buckets[gi].length; i3++) {
#           var e2 = {};
#           for (var k2 in buckets[gi][i3]) e2[k2] = buckets[gi][i3][k2];
#           e2.start = cursor + (buckets[gi][i3].start - base);
#           e2._stepIndex = step;
#           result.push(e2);
#         }
#         cursor += groupDurs[gi] + gapSec;
#       }
#       return { events: result, seqMap: seqMap };
#     }
#
#     function isPlaying() {
#       if (engine === "supersonic") return !!(_ssScheduler && _ssScheduler.isPlaying);
#       return !!(_aPlayer && _aPlayer.isPlaying());
#     }
#
#     async function stop() {
#       if (engine === "supersonic") {
#         if (_ssScheduler && _ssScheduler.isPlaying) await _ssScheduler.stop();
#         return;
#       }
#       if (_aPlayer && _aPlayer.isPlaying()) _aPlayer.stop();
#     }
#
#     async function resumeAudio() {
#       if (engine === "supersonic") {
#         if (_ssSonic && _ssSonic.audioContext && _ssSonic.audioContext.state === "suspended") {
#           await _ssSonic.audioContext.resume();
#         }
#         return;
#       }
#       if (typeof Tone !== "undefined" && Tone.context && Tone.context.state === "suspended") {
#         try { await Tone.start(); } catch(_) {}
#         try { await Tone.context.resume(); } catch(_) {}
#       }
#     }
#
#     async function play(ev
# CPS
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><rect width="700" height="700" fill="black"/>
# <text x="350.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D]</text>
# <line x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <circle id="svgcps_ecc0d3c5_nd1" cx="140.16" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_ecc0d3c5"/>
# <text x="140.16" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AB</text>
# <circle id="svgcps_ecc0d3c5_nd2" cx="350.00" cy="607.31" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_ecc0d3c5"/>
# <text x="350.00" y="607.31" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AC</text>
# <circle id="svgcps_ecc0d3c5_nd3" cx="140.16" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_ecc0d3c5"/>
# <text x="140.16" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AD</text>
# <circle id="svgcps_ecc0d3c5_nd4" cx="559.84" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgcps_ecc0d3c5"/>
# <text x="559.84" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BC</text>
# <circle id="svgcps_ecc0d3c5_nd5" cx="350.00" cy="122.69" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgcps_ecc0d3c5"/>
# <text x="350.00" y="122.69" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BD</text>
# <circle id="svgcps_ecc0d3c5_nd6" cx="559.84" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgcps_ecc0d3c5"/>
# <text x="559.84" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">CD</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;

# %% [markdown]
# Ok, whew...
#
# I know, it's a bit confusing, but take a look at the result.
#
# Look at each node in the CPS (here, each node represents a *`k`*-wise grouping—pairs in our case) and notice the angle of the line between them.
#
# E.g., the edge between `AD` and `BD` is a horizontal line. Why?
#
# $AD / BD = A/B$
#
# Look at the generating tetrad. The angle between nodes `A` and `B`. It's a horizontal line.
#
# Look back at the CPS graph. Take a look at nodes `CD` and `BD` and take note of the angle of the edge between them. It's the same angle as between `C` and `B` in the generating tetrad. Because $CD / BD = C/B$.
#
# And so on...

# %% [markdown]
# ## Hexany
#
# The above CPS is the simplest, known as the ***Hexany***.
#
# So, what do these letters actually mean? Each element in the initial set represents an integer that we will use as a harmonic multiple of some fundamental frequency. So, let's say:
#
# `A = 1`
#
# `B = 3`
#
# `C = 5`
#
# `D = 7`
#
# They don't have to be these numbers, but let's go with these.
#
# Each ***combination*** of elements is called a ***product***. Why? Because:
#
# `AB = 1 * 3 = 3`
#
# `BC = 3 * 5 = 15`
#
# `CD = 5 * 7 = 35`
#
# etc...
#
# which results in a set of *ratios*—the tone world of this particular Hexany.

# %%
hx = Hexany()
print('Ratios: ', *[str(r) for r in hx.ratios])
plot(hx, figsize=(7,7))
pc = PC.from_degrees(list(hx.ratios), equave='2/1')
# idx = list(range(-len(hx.ratios)*2 + len(hx.ratios), len(hx.ratios)*2 + len(hx.ratios)))
idx = list(range(-len(hx.ratios)*2, len(hx.ratios)*2))
play(pc.root('C4')[idx + idx[-2::-1]], dur=0.2)
# Out:
# Ratios:  35/32 5/4 21/16 3/2 7/4 15/8
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><rect width="700" height="700" fill="black"/>
# <text x="350.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D]</text>
# <line x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <circle id="svgcps_842114af_nd1" cx="140.16" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_842114af"/>
# <text x="140.16" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AB</text>
# <circle id="svgcps_842114af_nd2" cx="350.00" cy="607.31" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_842114af"/>
# <text x="350.00" y="607.31" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AC</text>
# <circle id="svgcps_842114af_nd3" cx="140.16" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_842114af"/>
# <text x="140.16" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AD</text>
# <circle id="svgcps_842114af_nd4" cx="559.84" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgcps_842114af"/>
# <text x="559.84" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BC</text>
# <circle id="svgcps_842114af_nd5" cx="350.00" cy="122.69" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgcps_842114af"/>
# <text x="350.00" y="122.69" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BD</text>
# <circle id="svgcps_842114af_nd6" cx="559.84" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgcps_842114af"/>
# <text x="559.84" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">CD</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
# <div id="klotho_ss_fc4f67da" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 6px 10px;
#     background: #1a1a2e;
#     border-radius: 6px;
#     user-select: none;
# ">
#     <button id="klotho_ss_fc4f67da_toggle" style="
#         width: 32px;
#         height: 32px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#     ">
#         <span id="klotho_ss_fc4f67da_icon" style="
#             width: 0;
#             height: 0;
#             border-top: 7px solid transparent;
#             border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80;
#             margin-left: 3px;
#         "></span>
#     </button>
#     <button id="klotho_ss_fc4f67da_loop" style="
#         width: 28px;
#         height: 28px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#         opacity: 0.5;
#     ">
#         <svg id="klotho_ss_fc4f67da_loop_svg" width="16" height="16" viewBox="0 0 24 24" fill="none" stroke="#a0a0a0" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path>
#             <path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path>
#             <path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
#     <span id="klotho_ss_fc4f67da_status" style="
#         color: #666;
#         font-size: 10px;
#         min-width: 60px;
#     ">ready</span>
# </div>
#
# <script>
#
# // SuperSonic standalone playback widget.
# // Python replaces: klotho_ss_fc4f67da, [{"type": "new", "id": "9e50fef1802846c6b36869c74c49bf9a", "defName": "kl_tri", "start": 0, "pfields": {"freq": 71.5382, "amp": 0.32465768312924875}, "_stepIndex": 0}, {"type": "release", "id": "9e50fef1802846c6b36869c74c49bf9a", "start": 0.2, "_stepIndex": 0}, {"type": "new", "id": "193868ba45704f71955375d85344bc42", "defName": "kl_tri", "start": 0.2, "pfields": {"freq": 81.758, "amp": 0.33433332784005887}, "_stepIndex": 1}, {"type": "release", "id": "193868ba45704f71955375d85344bc42", "start": 0.4, "_stepIndex": 1}, {"type": "new", "id": "8c12004ab840473aa75a7bc98ab5e259", "defName": "kl_tri", "start": 0.4, "pfields": {"freq": 85.8459, "amp": 0.33797075387458925}, "_stepIndex": 2}, {"type": "release", "id": "8c12004ab840473aa75a7bc98ab5e259", "start": 0.6000000000000001, "_stepIndex": 2}, {"type": "new", "id": "e909671a3b954619ab55cbcd0ccdcaa0", "defName": "kl_tri", "start": 0.6000000000000001, "pfields": {"freq": 98.1096, "amp": 0.34842026788607267}, "_stepIndex": 3}, {"type": "release", "id": "e909671a3b954619ab55cbcd0ccdcaa0", "start": 0.8, "_stepIndex": 3}, {"type": "new", "id": "bd6436ebf47d4ee79718b3e2dd1eb34a", "defName": "kl_tri", "start": 0.8, "pfields": {"freq": 114.4612, "amp": 0.3620248787580148}, "_stepIndex": 4}, {"type": "release", "id": "bd6436ebf47d4ee79718b3e2dd1eb34a", "start": 1.0, "_stepIndex": 4}, {"type": "new", "id": "421ddc0d8ea74097979018f7b3509606", "defName": "kl_tri", "start": 1.0, "pfields": {"freq": 122.637, "amp": 0.3687474438592235}, "_stepIndex": 5}, {"type": "release", "id": "421ddc0d8ea74097979018f7b3509606", "start": 1.2, "_stepIndex": 5}, {"type": "new", "id": "66a9cd210a38464f97830d8ca5b3c149", "defName": "kl_tri", "start": 1.2, "pfields": {"freq": 143.0765, "amp": 0.3851372505985531}, "_stepIndex": 6}, {"type": "release", "id": "66a9cd210a38464f97830d8ca5b3c149", "start": 1.4, "_stepIndex": 6}, {"type": "new", "id": "fee980b8b0794946a80cef86ef872164", "defName": "kl_tri", "start": 1.4, "pfields": {"freq": 163.516, "amp": 0.4006440314150796}, "_stepIndex": 7}, {"type": "release", "id": "fee980b8b0794946a80cef86ef872164", "start": 1.5999999999999999, "_stepIndex": 7}, {"type": "new", "id": "87bf253842d54b828896461b207b4ca4", "defName": "kl_tri", "start": 1.5999999999999999, "pfields": {"freq": 171.6918, "amp": 0.40651889163039745}, "_stepIndex": 8}, {"type": "release", "id": "87bf253842d54b828896461b207b4ca4", "start": 1.7999999999999998, "_stepIndex": 8}, {"type": "new", "id": "f68eec5bebe644fba984c0dfe1dfbb25", "defName": "kl_tri", "start": 1.7999999999999998, "pfields": {"freq": 196.2192, "amp": 0.4227200184411173}, "_stepIndex": 9}, {"type": "release", "id": "f68eec5bebe644fba984c0dfe1dfbb25", "start": 1.9999999999999998, "_stepIndex": 9}, {"type": "new", "id": "69e7eb2428ec4b14bfd4c6f93712e577", "defName": "kl_tri", "start": 1.9999999999999998, "pfields": {"freq": 228.9224, "amp": 0.44037718222926503}, "_stepIndex": 10}, {"type": "release", "id": "69e7eb2428ec4b14bfd4c6f93712e577", "start": 2.1999999999999997, "_stepIndex": 10}, {"type": "new", "id": "53c9a0f81813446e822b76b1450f2c05", "defName": "kl_tri", "start": 2.1999999999999997, "pfields": {"freq": 245.274, "amp": 0.4475524738657926}, "_stepIndex": 11}, {"type": "release", "id": "53c9a0f81813446e822b76b1450f2c05", "start": 2.4, "_stepIndex": 11}, {"type": "new", "id": "1c42b77b625e4ed3a59cb28fc408de4c", "defName": "kl_tri", "start": 2.4, "pfields": {"freq": 286.153, "amp": 0.46124976648817834}, "_stepIndex": 12}, {"type": "release", "id": "1c42b77b625e4ed3a59cb28fc408de4c", "start": 2.6, "_stepIndex": 12}, {"type": "new", "id": "6d16468f771649f1845b67e864ee5688", "defName": "kl_tri", "start": 2.6, "pfields": {"freq": 327.032, "amp": 0.4697954849148101}, "_stepIndex": 13}, {"type": "release", "id": "6d16468f771649f1845b67e864ee5688", "start": 2.8000000000000003, "_stepIndex": 13}, {"type": "new", "id": "7468d65aeac24f59a46d7ef614b41ce4", "defName": "kl_tri", "start": 2.8000000000000003, " ...

# %% [markdown]
# Now, recall that those letters in the initial set are just variables; we can change their values and get a structure with different intervals.
#
# Let's try that:

# %%
hx2 = Hexany((1, 5, 13, 31))
print('Ratios: ', *[str(r) for r in hx2.ratios])
plot(hx2, figsize=(7,7))
pc = PC.from_degrees(list(hx2.ratios), equave='2/1')
idx = list(range(-len(hx2.ratios)*2, len(hx2.ratios)*2))
play(pc.root('C4')[idx + idx[-2::-1]], dur=0.2)
# Out:
# Ratios:  65/64 155/128 5/4 403/256 13/8 31/16
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><rect width="700" height="700" fill="black"/>
# <text x="350.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D]</text>
# <line x1="350.00" y1="122.69" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <circle id="svgcps_1cf563f3_nd1" cx="140.16" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_1cf563f3"/>
# <text x="140.16" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AB</text>
# <circle id="svgcps_1cf563f3_nd2" cx="350.00" cy="607.31" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_1cf563f3"/>
# <text x="350.00" y="607.31" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AC</text>
# <circle id="svgcps_1cf563f3_nd3" cx="140.16" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_1cf563f3"/>
# <text x="140.16" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AD</text>
# <circle id="svgcps_1cf563f3_nd4" cx="559.84" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgcps_1cf563f3"/>
# <text x="559.84" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BC</text>
# <circle id="svgcps_1cf563f3_nd5" cx="350.00" cy="122.69" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgcps_1cf563f3"/>
# <text x="350.00" y="122.69" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BD</text>
# <circle id="svgcps_1cf563f3_nd6" cx="559.84" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgcps_1cf563f3"/>
# <text x="559.84" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">CD</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
# <div id="klotho_ss_958d9074" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 6px 10px;
#     background: #1a1a2e;
#     border-radius: 6px;
#     user-select: none;
# ">
#     <button id="klotho_ss_958d9074_toggle" style="
#         width: 32px;
#         height: 32px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#     ">
#         <span id="klotho_ss_958d9074_icon" style="
#             width: 0;
#             height: 0;
#             border-top: 7px solid transparent;
#             border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80;
#             margin-left: 3px;
#         "></span>
#     </button>
#     <button id="klotho_ss_958d9074_loop" style="
#         width: 28px;
#         height: 28px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#         opacity: 0.5;
#     ">
#         <svg id="klotho_ss_958d9074_loop_svg" width="16" height="16" viewBox="0 0 24 24" fill="none" stroke="#a0a0a0" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path>
#             <path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path>
#             <path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
#     <span id="klotho_ss_958d9074_status" style="
#         color: #666;
#         font-size: 10px;
#         min-width: 60px;
#     ">ready</span>
# </div>
#
# <script>
#
# // SuperSonic standalone playback widget.
# // Python replaces: klotho_ss_958d9074, [{"type": "new", "id": "fb78617b1fba40e89313d349154ecf78", "defName": "kl_tri", "start": 0, "pfields": {"freq": 66.4284, "amp": 0.3194124043530338}, "_stepIndex": 0}, {"type": "release", "id": "fb78617b1fba40e89313d349154ecf78", "start": 0.2, "_stepIndex": 0}, {"type": "new", "id": "f72c4a3aa55e4c8cb79bc320d3765fdd", "defName": "kl_tri", "start": 0.2, "pfields": {"freq": 79.2031, "amp": 0.3320006038063629}, "_stepIndex": 1}, {"type": "release", "id": "f72c4a3aa55e4c8cb79bc320d3765fdd", "start": 0.4, "_stepIndex": 1}, {"type": "new", "id": "2633b0c57bd24c62a5dd50a80fc06dcf", "defName": "kl_tri", "start": 0.4, "pfields": {"freq": 81.758, "amp": 0.33433332784005887}, "_stepIndex": 2}, {"type": "release", "id": "2633b0c57bd24c62a5dd50a80fc06dcf", "start": 0.6000000000000001, "_stepIndex": 2}, {"type": "new", "id": "56c3973e19b44fb48df320cf1caab7e8", "defName": "kl_tri", "start": 0.6000000000000001, "pfields": {"freq": 102.964, "amp": 0.35247390066678075}, "_stepIndex": 3}, {"type": "release", "id": "56c3973e19b44fb48df320cf1caab7e8", "start": 0.8, "_stepIndex": 3}, {"type": "new", "id": "f16c2d6569434d50b29f6f1388aa8c8b", "defName": "kl_tri", "start": 0.8, "pfields": {"freq": 106.2854, "amp": 0.3552416343620657}, "_stepIndex": 4}, {"type": "release", "id": "f16c2d6569434d50b29f6f1388aa8c8b", "start": 1.0, "_stepIndex": 4}, {"type": "new", "id": "7152f18767344da384c0c1972596d7fa", "defName": "kl_tri", "start": 1.0, "pfields": {"freq": 126.7249, "amp": 0.37207877481243334}, "_stepIndex": 5}, {"type": "release", "id": "7152f18767344da384c0c1972596d7fa", "start": 1.2, "_stepIndex": 5}, {"type": "new", "id": "67c9bf57f36b4530b01acd07f3dfa9e5", "defName": "kl_tri", "start": 1.2, "pfields": {"freq": 132.8567, "amp": 0.37703019514576214}, "_stepIndex": 6}, {"type": "release", "id": "67c9bf57f36b4530b01acd07f3dfa9e5", "start": 1.4, "_stepIndex": 6}, {"type": "new", "id": "31553fe093ba4063a17e3849d9b95955", "defName": "kl_tri", "start": 1.4, "pfields": {"freq": 158.4061, "amp": 0.39686978016413765}, "_stepIndex": 7}, {"type": "release", "id": "31553fe093ba4063a17e3849d9b95955", "start": 1.5999999999999999, "_stepIndex": 7}, {"type": "new", "id": "bc5390deca12428289f5d275d938e3fe", "defName": "kl_tri", "start": 1.5999999999999999, "pfields": {"freq": 163.516, "amp": 0.4006440314150796}, "_stepIndex": 8}, {"type": "release", "id": "bc5390deca12428289f5d275d938e3fe", "start": 1.7999999999999998, "_stepIndex": 8}, {"type": "new", "id": "d93dfca80c1e454b82b3cf38f06f3247", "defName": "kl_tri", "start": 1.7999999999999998, "pfields": {"freq": 205.928, "amp": 0.42844615064914254}, "_stepIndex": 9}, {"type": "release", "id": "d93dfca80c1e454b82b3cf38f06f3247", "start": 1.9999999999999998, "_stepIndex": 9}, {"type": "new", "id": "31b2f3e9de614d21a84593d12dca30ca", "defName": "kl_tri", "start": 1.9999999999999998, "pfields": {"freq": 212.5708, "amp": 0.43212370490865454}, "_stepIndex": 10}, {"type": "release", "id": "31b2f3e9de614d21a84593d12dca30ca", "start": 2.1999999999999997, "_stepIndex": 10}, {"type": "new", "id": "81628dfd6616465b9abb663249f020ba", "defName": "kl_tri", "start": 2.1999999999999997, "pfields": {"freq": 253.4498, "amp": 0.45075847271437913}, "_stepIndex": 11}, {"type": "release", "id": "81628dfd6616465b9abb663249f020ba", "start": 2.4, "_stepIndex": 11}, {"type": "new", "id": "33199353cbb8480d82fc9bac33f04044", "defName": "kl_tri", "start": 2.4, "pfields": {"freq": 265.7135, "amp": 0.4551159190197478}, "_stepIndex": 12}, {"type": "release", "id": "33199353cbb8480d82fc9bac33f04044", "start": 2.6, "_stepIndex": 12}, {"type": "new", "id": "c84670e2f0a44dffbf46ff1cb032fbaf", "defName": "kl_tri", "start": 2.6, "pfields": {"freq": 316.8122, "amp": 0.46808001079316197}, "_stepIndex": 13}, {"type": "release", "id": "c84670e2f0a44dffbf46ff1cb032fbaf", "start": 2.8000000000000003, "_stepIndex": 13}, {"type": "new", "id": "4adb01853eb04733b5eded99a4c38b5f", "defName": "kl_tri", "start": 2.80000000000000 ...

# %% [markdown]
# Compare it to the one above. The graph structure will be the same since the same abstract algebraic relationships remain intact, but their specific values are different. Thus, the resultant "tone world" will be different.
#
# Let's do another one...

# %%
hx3 = Hexany((3, 17, 23, 53))
print('Ratios: ', *[str(r) for r in hx3.ratios])
plot(hx3, figsize=(7,7))
pc = PC.from_degrees(list(hx3.ratios), equave='2/1')
idx = list(range(-len(hx3.ratios)*2, len(hx3.ratios)*2))
play(pc.root('C4')[idx + idx[-2::-1]], dur=0.2)
# Out:
# Ratios:  69/64 1219/1024 159/128 391/256 51/32 901/512
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><rect width="700" height="700" fill="black"/>
# <text x="350.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D]</text>
# <line x1="140.16" y1="486.15" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <circle id="svgcps_afc5c3f2_nd1" cx="140.16" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_afc5c3f2"/>
# <text x="140.16" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AB</text>
# <circle id="svgcps_afc5c3f2_nd2" cx="350.00" cy="607.31" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_afc5c3f2"/>
# <text x="350.00" y="607.31" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AC</text>
# <circle id="svgcps_afc5c3f2_nd3" cx="140.16" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_afc5c3f2"/>
# <text x="140.16" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AD</text>
# <circle id="svgcps_afc5c3f2_nd4" cx="559.84" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgcps_afc5c3f2"/>
# <text x="559.84" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BC</text>
# <circle id="svgcps_afc5c3f2_nd5" cx="350.00" cy="122.69" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgcps_afc5c3f2"/>
# <text x="350.00" y="122.69" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BD</text>
# <circle id="svgcps_afc5c3f2_nd6" cx="559.84" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgcps_afc5c3f2"/>
# <text x="559.84" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">CD</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
# <div id="klotho_ss_1697db15" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 6px 10px;
#     background: #1a1a2e;
#     border-radius: 6px;
#     user-select: none;
# ">
#     <button id="klotho_ss_1697db15_toggle" style="
#         width: 32px;
#         height: 32px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#     ">
#         <span id="klotho_ss_1697db15_icon" style="
#             width: 0;
#             height: 0;
#             border-top: 7px solid transparent;
#             border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80;
#             margin-left: 3px;
#         "></span>
#     </button>
#     <button id="klotho_ss_1697db15_loop" style="
#         width: 28px;
#         height: 28px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#         opacity: 0.5;
#     ">
#         <svg id="klotho_ss_1697db15_loop_svg" width="16" height="16" viewBox="0 0 24 24" fill="none" stroke="#a0a0a0" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path>
#             <path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path>
#             <path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
#     <span id="klotho_ss_1697db15_status" style="
#         color: #666;
#         font-size: 10px;
#         min-width: 60px;
#     ">ready</span>
# </div>
#
# <script>
#
# // SuperSonic standalone playback widget.
# // Python replaces: klotho_ss_1697db15, [{"type": "new", "id": "df56562147804dd7998d6641922f3fdd", "defName": "kl_tri", "start": 0, "pfields": {"freq": 70.5163, "amp": 0.3236333802338282}, "_stepIndex": 0}, {"type": "release", "id": "df56562147804dd7998d6641922f3fdd", "start": 0.2, "_stepIndex": 0}, {"type": "new", "id": "7e299b53465940db857b64937bfe8990", "defName": "kl_tri", "start": 0.2, "pfields": {"freq": 77.8617, "amp": 0.33075494382807474}, "_stepIndex": 1}, {"type": "release", "id": "7e299b53465940db857b64937bfe8990", "start": 0.4, "_stepIndex": 1}, {"type": "new", "id": "434acd9c6dff49149a066e463ff0ec06", "defName": "kl_tri", "start": 0.4, "pfields": {"freq": 81.247, "amp": 0.3338707205350856}, "_stepIndex": 2}, {"type": "release", "id": "434acd9c6dff49149a066e463ff0ec06", "start": 0.6000000000000001, "_stepIndex": 2}, {"type": "new", "id": "e1915334d2ac46ffbd86ce0830eda462", "defName": "kl_tri", "start": 0.6000000000000001, "pfields": {"freq": 99.8981, "amp": 0.34991489626920064}, "_stepIndex": 3}, {"type": "release", "id": "e1915334d2ac46ffbd86ce0830eda462", "start": 0.8, "_stepIndex": 3}, {"type": "new", "id": "af9befd0b0024826a2956f2555fb4563", "defName": "kl_tri", "start": 0.8, "pfields": {"freq": 104.2414, "amp": 0.3535389992710421}, "_stepIndex": 4}, {"type": "release", "id": "af9befd0b0024826a2956f2555fb4563", "start": 1.0, "_stepIndex": 4}, {"type": "new", "id": "3151e8e9a7014a09b020d5ff15a2421c", "defName": "kl_tri", "start": 1.0, "pfields": {"freq": 115.0999, "amp": 0.3625525339135989}, "_stepIndex": 5}, {"type": "release", "id": "3151e8e9a7014a09b020d5ff15a2421c", "start": 1.2, "_stepIndex": 5}, {"type": "new", "id": "c0fbad096dbd4561be905046d57121f3", "defName": "kl_tri", "start": 1.2, "pfields": {"freq": 141.0326, "amp": 0.3835321080518373}, "_stepIndex": 6}, {"type": "release", "id": "c0fbad096dbd4561be905046d57121f3", "start": 1.4, "_stepIndex": 6}, {"type": "new", "id": "bc0c370fde0348a9ac885f92008ebe00", "defName": "kl_tri", "start": 1.4, "pfields": {"freq": 155.7234, "amp": 0.3948590945014346}, "_stepIndex": 7}, {"type": "release", "id": "bc0c370fde0348a9ac885f92008ebe00", "start": 1.5999999999999999, "_stepIndex": 7}, {"type": "new", "id": "1f1fc78406d54bda89a4674e4040c6e0", "defName": "kl_tri", "start": 1.5999999999999999, "pfields": {"freq": 162.494, "amp": 0.3998952009622652}, "_stepIndex": 8}, {"type": "release", "id": "1f1fc78406d54bda89a4674e4040c6e0", "start": 1.7999999999999998, "_stepIndex": 8}, {"type": "new", "id": "516a1756d8b44ade876b477c26dbecad", "defName": "kl_tri", "start": 1.7999999999999998, "pfields": {"freq": 199.7961, "amp": 0.42487866483714026}, "_stepIndex": 9}, {"type": "release", "id": "516a1756d8b44ade876b477c26dbecad", "start": 1.9999999999999998, "_stepIndex": 9}, {"type": "new", "id": "807542f77ff648b9a3d085af81ab2e58", "defName": "kl_tri", "start": 1.9999999999999998, "pfields": {"freq": 208.4829, "amp": 0.4298833668171688}, "_stepIndex": 10}, {"type": "release", "id": "807542f77ff648b9a3d085af81ab2e58", "start": 2.1999999999999997, "_stepIndex": 10}, {"type": "new", "id": "6a844e08465849a28539ed81e4546380", "defName": "kl_tri", "start": 2.1999999999999997, "pfields": {"freq": 230.1999, "amp": 0.4409756537862877}, "_stepIndex": 11}, {"type": "release", "id": "6a844e08465849a28539ed81e4546380", "start": 2.4, "_stepIndex": 11}, {"type": "new", "id": "6a151dfbcbc2416a9521a8588396622b", "defName": "kl_tri", "start": 2.4, "pfields": {"freq": 282.0651, "amp": 0.4601305630107781}, "_stepIndex": 12}, {"type": "release", "id": "6a151dfbcbc2416a9521a8588396622b", "start": 2.6, "_stepIndex": 12}, {"type": "new", "id": "6206d23cef894dae8f6171044552ea1b", "defName": "kl_tri", "start": 2.6, "pfields": {"freq": 311.4469, "amp": 0.4670729092669841}, "_stepIndex": 13}, {"type": "release", "id": "6206d23cef894dae8f6171044552ea1b", "start": 2.8000000000000003, "_stepIndex": 13}, {"type": "new", "id": "21b91fce7638457daabef5a6d6b6e236", "defName": "kl_tri", "start": 2.8000000000000003, " ...

# %% [markdown]
# Interesting...
#
# Ok, let's go back to the initial Hexany we created. It gets cooler.

# %%
print('Ratios: ', *[str(r) for r in hx.ratios])
plot(hx, figsize=(7,7))
pc = PC.from_degrees(list(hx.ratios), equave='2/1')
idx = list(range(-len(hx.ratios)*2, len(hx.ratios)*2))
play(pc.root('C4')[idx + idx[-2::-1]], dur=0.2)
# Out:
# Ratios:  35/32 5/4 21/16 3/2 7/4 15/8
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><rect width="700" height="700" fill="black"/>
# <text x="350.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D]</text>
# <line x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <circle id="svgcps_09bd7050_nd1" cx="140.16" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_09bd7050"/>
# <text x="140.16" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AB</text>
# <circle id="svgcps_09bd7050_nd2" cx="350.00" cy="607.31" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_09bd7050"/>
# <text x="350.00" y="607.31" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AC</text>
# <circle id="svgcps_09bd7050_nd3" cx="140.16" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_09bd7050"/>
# <text x="140.16" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AD</text>
# <circle id="svgcps_09bd7050_nd4" cx="559.84" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgcps_09bd7050"/>
# <text x="559.84" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BC</text>
# <circle id="svgcps_09bd7050_nd5" cx="350.00" cy="122.69" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgcps_09bd7050"/>
# <text x="350.00" y="122.69" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BD</text>
# <circle id="svgcps_09bd7050_nd6" cx="559.84" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgcps_09bd7050"/>
# <text x="559.84" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">CD</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
# <div id="klotho_ss_18eb2e27" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 6px 10px;
#     background: #1a1a2e;
#     border-radius: 6px;
#     user-select: none;
# ">
#     <button id="klotho_ss_18eb2e27_toggle" style="
#         width: 32px;
#         height: 32px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#     ">
#         <span id="klotho_ss_18eb2e27_icon" style="
#             width: 0;
#             height: 0;
#             border-top: 7px solid transparent;
#             border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80;
#             margin-left: 3px;
#         "></span>
#     </button>
#     <button id="klotho_ss_18eb2e27_loop" style="
#         width: 28px;
#         height: 28px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#         opacity: 0.5;
#     ">
#         <svg id="klotho_ss_18eb2e27_loop_svg" width="16" height="16" viewBox="0 0 24 24" fill="none" stroke="#a0a0a0" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path>
#             <path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path>
#             <path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
#     <span id="klotho_ss_18eb2e27_status" style="
#         color: #666;
#         font-size: 10px;
#         min-width: 60px;
#     ">ready</span>
# </div>
#
# <script>
#
# // SuperSonic standalone playback widget.
# // Python replaces: klotho_ss_18eb2e27, [{"type": "new", "id": "e4621c3d0beb49dc8650e7712efcd0f7", "defName": "kl_tri", "start": 0, "pfields": {"freq": 71.5382, "amp": 0.32465768312924875}, "_stepIndex": 0}, {"type": "release", "id": "e4621c3d0beb49dc8650e7712efcd0f7", "start": 0.2, "_stepIndex": 0}, {"type": "new", "id": "12c2064b453746de95ee9acfb7d48b58", "defName": "kl_tri", "start": 0.2, "pfields": {"freq": 81.758, "amp": 0.33433332784005887}, "_stepIndex": 1}, {"type": "release", "id": "12c2064b453746de95ee9acfb7d48b58", "start": 0.4, "_stepIndex": 1}, {"type": "new", "id": "6e6405f74ff445c1bc79f1c3f19b978d", "defName": "kl_tri", "start": 0.4, "pfields": {"freq": 85.8459, "amp": 0.33797075387458925}, "_stepIndex": 2}, {"type": "release", "id": "6e6405f74ff445c1bc79f1c3f19b978d", "start": 0.6000000000000001, "_stepIndex": 2}, {"type": "new", "id": "78929b7d1749470c99ebb65f4b43ffc2", "defName": "kl_tri", "start": 0.6000000000000001, "pfields": {"freq": 98.1096, "amp": 0.34842026788607267}, "_stepIndex": 3}, {"type": "release", "id": "78929b7d1749470c99ebb65f4b43ffc2", "start": 0.8, "_stepIndex": 3}, {"type": "new", "id": "733b44f51b0e4ef3b779eab1a0cf13e9", "defName": "kl_tri", "start": 0.8, "pfields": {"freq": 114.4612, "amp": 0.3620248787580148}, "_stepIndex": 4}, {"type": "release", "id": "733b44f51b0e4ef3b779eab1a0cf13e9", "start": 1.0, "_stepIndex": 4}, {"type": "new", "id": "23492e89a10349909e711f3d9c24f6b5", "defName": "kl_tri", "start": 1.0, "pfields": {"freq": 122.637, "amp": 0.3687474438592235}, "_stepIndex": 5}, {"type": "release", "id": "23492e89a10349909e711f3d9c24f6b5", "start": 1.2, "_stepIndex": 5}, {"type": "new", "id": "cf56468de24544e7ba30601ba2bafea3", "defName": "kl_tri", "start": 1.2, "pfields": {"freq": 143.0765, "amp": 0.3851372505985531}, "_stepIndex": 6}, {"type": "release", "id": "cf56468de24544e7ba30601ba2bafea3", "start": 1.4, "_stepIndex": 6}, {"type": "new", "id": "5d25a76e315c405f963eaaa79e66409c", "defName": "kl_tri", "start": 1.4, "pfields": {"freq": 163.516, "amp": 0.4006440314150796}, "_stepIndex": 7}, {"type": "release", "id": "5d25a76e315c405f963eaaa79e66409c", "start": 1.5999999999999999, "_stepIndex": 7}, {"type": "new", "id": "f9dff648609f42578277ffd61eeb659d", "defName": "kl_tri", "start": 1.5999999999999999, "pfields": {"freq": 171.6918, "amp": 0.40651889163039745}, "_stepIndex": 8}, {"type": "release", "id": "f9dff648609f42578277ffd61eeb659d", "start": 1.7999999999999998, "_stepIndex": 8}, {"type": "new", "id": "20f0749b11344ca7a2dd65606c5379e7", "defName": "kl_tri", "start": 1.7999999999999998, "pfields": {"freq": 196.2192, "amp": 0.4227200184411173}, "_stepIndex": 9}, {"type": "release", "id": "20f0749b11344ca7a2dd65606c5379e7", "start": 1.9999999999999998, "_stepIndex": 9}, {"type": "new", "id": "b04d8d815eb8423abea11b10eb98d6a6", "defName": "kl_tri", "start": 1.9999999999999998, "pfields": {"freq": 228.9224, "amp": 0.44037718222926503}, "_stepIndex": 10}, {"type": "release", "id": "b04d8d815eb8423abea11b10eb98d6a6", "start": 2.1999999999999997, "_stepIndex": 10}, {"type": "new", "id": "db216c61f32340e48434182990a70d83", "defName": "kl_tri", "start": 2.1999999999999997, "pfields": {"freq": 245.274, "amp": 0.4475524738657926}, "_stepIndex": 11}, {"type": "release", "id": "db216c61f32340e48434182990a70d83", "start": 2.4, "_stepIndex": 11}, {"type": "new", "id": "c6f672bf4e5d4d3895d86619c8a47d47", "defName": "kl_tri", "start": 2.4, "pfields": {"freq": 286.153, "amp": 0.46124976648817834}, "_stepIndex": 12}, {"type": "release", "id": "c6f672bf4e5d4d3895d86619c8a47d47", "start": 2.6, "_stepIndex": 12}, {"type": "new", "id": "0e35fe9aabab47c689f5e4324dfcc7f2", "defName": "kl_tri", "start": 2.6, "pfields": {"freq": 327.032, "amp": 0.4697954849148101}, "_stepIndex": 13}, {"type": "release", "id": "0e35fe9aabab47c689f5e4324dfcc7f2", "start": 2.8000000000000003, "_stepIndex": 13}, {"type": "new", "id": "c9a57305ba974903b90abc6db51aee94", "defName": "kl_tri", "start": 2.8000000000000003, " ...

# %% [markdown]
# This is a geometric form. Which means, yes, we have points (individual notes), but we also have *faces*. I.e., we can select multiple nodes and create a surface. What does that give us?
#
# Well, if a single point is a single note, then multiple points are multiple notes—i.e., chords...

# %%
shape = [0, 4, 3]
print('Target Shape:')
matches = match_pattern(hx, shape, sort_by='position', include_target=True)
plot(hx, shape=matches, figsize=(7,7)).play(dur=2, releaseTime=2)
# Out:
# Target Shape:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><rect width="700" height="700" fill="black"/>
# <text x="350.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D]</text>
# <line x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line id="svgcps_e628b837_se1" x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_e628b837_se2" x1="140.16" y1="243.85" x2="559.84" y2="243.85" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_e628b837_se3" x1="350.00" y1="122.69" x2="559.84" y2="243.85" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_e628b837_se4" x1="350.00" y1="122.69" x2="559.84" y2="243.85" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_e628b837_se5" x1="350.00" y1="122.69" x2="559.84" y2="486.15" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_e628b837_se6" x1="559.84" y1="243.85" x2="559.84" y2="486.15" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_e628b837_se7" x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_e628b837_se8" x1="350.00" y1="607.31" x2="559.84" y2="243.85" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_e628b837_se9" x1="559.84" y1="486.15" x2="559.84" y2="243.85" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_e628b837_se10" x1="140.16" y1="486.15" x2="350.00" y2="607.31" stroke="#87CEEB" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_e628b837_se11" x1="140.16" y1="486.15" x2="559.84" y2="486.15" stroke="#87CEEB" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_e628b837_se12" x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#87CEEB" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_e628b837_se13" x1="140.16" y1="243.85" x2="140.16" y2="486.15" stroke="#DDA0DD" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_e628b837_se14" x1="140.16" y1="243.85" x2="350.00" y2="607.31" stroke="#DDA0DD" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_e628b837_se15" x1="140.16" y1="486.15" x2="350.00" y2="607.31" stroke="#DDA0DD" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_e628b837_se16" x1="140.16" y1="486.15" x2="140.16" y2="243.85" stroke="#FFA07A" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_e628b837_se17" x1="140.16" y1="486.15" x2="350.00" y2="122.69" stroke="#FFA07A" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_e628b837_se18" x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#FFA07A" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <circle id="svgcps_e628b837_nd19" cx="140.16" cy="243.85" r="15.0" fill="#FFA07A" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_e628b837"/>
# <text x="140.16" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AB</text>
# <circle id="svgcps_e628b837_nd20" cx="350.00" cy="607.31" r="15.0" fill="#DDA0DD" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_e628b837"/>
# <text x="350.00" y="607.31" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AC</text>
# <circle id="svgcps_e628b837_nd21" cx="140.16" cy="486.15" r="15.0" fill="#FFA07A" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_e628b837"/>
# <text x="140.16" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AD</text>
# <circle id="svgcps_e628b837_nd22" cx="559.84" cy="243.85" r="15.0" fill="#FF6B6B" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgcps_e628b837"/>
# <text x="559.84" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BC</text>
# <circle id="svgcps_e628b837_nd23" cx="350.00" cy="122.69" r="15.0" fill="#FFA07A" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgcps_e628b837"/>
# <text x="350.00" y="122.69" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BD</text>
# <circle id="svgcps_e628b837_nd24" cx="559.84" cy="486.15" r="15.0" fill="#87CEEB" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgcps_e628b837"/>
# <text x="559.84" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">CD</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _raw

# %% [markdown]
# That's a pretty cool sequence of chords. And we didn't really need to work that hard to get it. All we did was find some pattern in the Hexany, find every other instance of that pattern elsewhere in the Hexany, then just... play them in order. That's it.
#
# I consider this the "reward" for going through all the abstract algebraic geometry earlier.
#
# That triangle shape produces chords of a certain quality. What about other shapes?

# %%
shape = [1, 5, 0, 4]
print('Target Shape:')
matches = match_pattern(hx, shape, sort_by='rotation', include_target=True)
plot(hx, shape=matches, figsize=(7,7)).play(dur=1, pause=0)
# Out:
# Target Shape:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><rect width="700" height="700" fill="black"/>
# <text x="350.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D]</text>
# <line x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line id="svgcps_0a16edd0_se1" x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_0a16edd0_se2" x1="350.00" y1="607.31" x2="140.16" y2="243.85" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_0a16edd0_se3" x1="559.84" y1="486.15" x2="350.00" y2="122.69" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_0a16edd0_se4" x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_0a16edd0_se5" x1="350.00" y1="607.31" x2="140.16" y2="486.15" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_0a16edd0_se6" x1="350.00" y1="607.31" x2="559.84" y2="243.85" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_0a16edd0_se7" x1="140.16" y1="486.15" x2="350.00" y2="122.69" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_0a16edd0_se8" x1="559.84" y1="243.85" x2="350.00" y2="122.69" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_0a16edd0_se9" x1="140.16" y1="243.85" x2="140.16" y2="486.15" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_0a16edd0_se10" x1="140.16" y1="243.85" x2="559.84" y2="243.85" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_0a16edd0_se11" x1="140.16" y1="486.15" x2="559.84" y2="486.15" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_0a16edd0_se12" x1="559.84" y1="243.85" x2="559.84" y2="486.15" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <circle id="svgcps_0a16edd0_nd13" cx="140.16" cy="243.85" r="15.0" fill="#FF6B6B" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_0a16edd0"/>
# <text x="140.16" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AB</text>
# <circle id="svgcps_0a16edd0_nd14" cx="350.00" cy="607.31" r="15.0" fill="#FFD700" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_0a16edd0"/>
# <text x="350.00" y="607.31" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AC</text>
# <circle id="svgcps_0a16edd0_nd15" cx="140.16" cy="486.15" r="15.0" fill="#FF6B6B" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_0a16edd0"/>
# <text x="140.16" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AD</text>
# <circle id="svgcps_0a16edd0_nd16" cx="559.84" cy="243.85" r="15.0" fill="#FF6B6B" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgcps_0a16edd0"/>
# <text x="559.84" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BC</text>
# <circle id="svgcps_0a16edd0_nd17" cx="350.00" cy="122.69" r="15.0" fill="#FFD700" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgcps_0a16edd0"/>
# <text x="350.00" y="122.69" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BD</text>
# <circle id="svgcps_0a16edd0_nd18" cx="559.84" cy="486.15" r="15.0" fill="#FF6B6B" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgcps_0a16edd0"/>
# <text x="559.84" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">CD</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_s

# %% [markdown]
# ## Eikosany
#
# There are other types of CPS structures (in fact, there are *a lot* of them). After the Hexany, the most common is the ***Eikosany***.
#
# This one is a little different. Instead of finding all possible `2`-wise groups (i.e., pairs), we find all `3`-wise groupings. We also use a different generating geometry to build the resultant graph.
#
# The result is a more complex geometry and, thus, a more complex tone world:

# %%
print("GENERATING GEOMETRY")
plot(MasterSet.asterisk(), figsize=(6,6))

print("\nCPS")
ek = Eikosany(master_set='asterisk')
plot(ek, node_size=25, text_size=10, figsize=(8,8))
pc = PC.from_degrees(list(ek.ratios), equave='2/1')
idx = list(range(-len(ek.ratios)*2, len(ek.ratios)*2))
play(pc.root('C4')[idx + idx[-2::-1]], dur=0.15)
# Out:
# GENERATING GEOMETRY
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="600" height="600" style="display:block;background:black"><text x="300.0" y="18" text-anchor="middle" font-family="Arial" font-size="14" fill="white">MasterSet: asterisk</text>
# <line x1="300.00" y1="276.83" x2="300.00" y2="519.47" stroke="#808080" stroke-width="1.5"/>
# <line x1="300.00" y1="276.83" x2="69.23" y2="351.81" stroke="#808080" stroke-width="1.5"/>
# <line x1="300.00" y1="276.83" x2="157.38" y2="80.53" stroke="#808080" stroke-width="1.5"/>
# <line x1="300.00" y1="276.83" x2="442.62" y2="80.53" stroke="#808080" stroke-width="1.5"/>
# <line x1="300.00" y1="276.83" x2="530.77" y2="351.81" stroke="#808080" stroke-width="1.5"/>
# <circle cx="300.00" cy="276.83" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgms_cb8d5bbe"/>
# <text x="300.00" y="277.83" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">A</text>
# <circle cx="300.00" cy="519.47" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgms_cb8d5bbe"/>
# <text x="300.00" y="520.47" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">B</text>
# <circle cx="69.23" cy="351.81" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgms_cb8d5bbe"/>
# <text x="69.23" y="352.81" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">C</text>
# <circle cx="157.38" cy="80.53" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgms_cb8d5bbe"/>
# <text x="157.38" y="81.53" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">D</text>
# <circle cx="442.62" cy="80.53" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgms_cb8d5bbe"/>
# <text x="442.62" y="81.53" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">E</text>
# <circle cx="530.77" cy="351.81" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgms_cb8d5bbe"/>
# <text x="530.77" y="352.81" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">F</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
#     }
#
#     function reorderEventsFrom(allEvents, startGi, total, gap) {
#       var gapSec = typeof gap === "number" ? Math.max(0, gap) : _pause;
#       var buckets = [];
#       for (var g = 0; g < total; g++) buckets.push([]);
#       for (var i = 0; i < allEvents.length; i++) {
#         var si = allEvents[i]._stepIndex;
#         if (si >= 0 && si < total) buckets[si].push(allEvents[i]);
#       }
#       var groupStarts = [];
#       for (var g1 = 0; g1 < total; g1++) {
#         var mn = Infinity;
#         for (var i1 = 0; i1 < buckets[g1].length; i1++) {
#           if (buckets[g1][i1].start < mn) mn = buckets[g1][i1].start;
#         }
#         groupStarts.push(mn === Infinity ? 0 : mn);
#       }
#       var groupDurs = [];
#       for (var g2 = 0; g2 < total; g2++) {
#         var mx = 0;
#         for (var i2 = 0; i2 < buckets[g2].length; i2++) {
#           var end = eventEnd(buckets[g2][i2]);
#           if (end > mx) mx = end;
#         }
#         groupDurs.push(mx - groupStarts[g2]);
#       }
#       var result = [];
#       var cursor = 0;
#       var seqMap = [];
#       for (var step = 0; step < total; step++) {
#         var gi = (startGi + step) % total;
#         seqMap.push(gi);
#         var base = groupStarts[gi];
#         for (var i3 = 0; i3 < buckets[gi].length; i3++) {
#           var e2 = {};
#           for (var k2 in buckets[gi][i3]) e2[k2] = buckets[gi][i3][k2];
#           e2.start = cursor + (buckets[gi][i3].start - base);
#           e2._stepIndex = step;
#           result.push(e2);
#         }
#         cursor += groupDurs[gi] + gapSec;
#       }
#       return { events: result, seqMap: seqMap };
#     }
#
#     function isPlaying() {
#       if (engine === "supersonic") return !!(_ssScheduler && _ssScheduler.isPlaying);
#       return !!(_aPlayer && _aPlayer.isPlaying());
#     }
#
#     async function stop() {
#       if (engine === "supersonic") {
#         if (_ssScheduler && _ssScheduler.isPlaying) await _ssScheduler.stop();
#         return;
#       }
#       if (_aPlayer && _aPlaye
# CPS
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="800" height="800" style="display:block;background:black"><rect width="800" height="800" fill="black"/>
# <text x="400.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D E F]</text>
# <line x1="132.97" y1="328.24" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="328.24" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="328.24" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="501.76" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="501.76" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="501.76" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <circle id="svgcps_23385acf_nd1" cx="234.97" cy="642.15" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_23385acf"/>
# <text x="234.97" y="642.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABC</text>
# <circle id="svgcps_23385acf_nd2" cx="298.00" cy="448.14" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_23385acf"/>
# <text x="298.00" y="448.14" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABD</text>
# <circle id="svgcps_23385acf_nd3" cx="502.00" cy="448.14" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_23385acf"/>
# <text x="502.00" y="448.14" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABE</text>
# <circle id="svgcps_23385acf_nd4" cx="565.03" cy="642.15" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgcps_23385acf"/>
# <text x="565.03" y="642.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABF</text>
# <circle id="svgcps_23385acf_nd5" cx="132.97" cy="328.24" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgcps_23385acf"/>
# <text x="132.97" y="328.24" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ACD</text>
# <circle id="svgcps_23385acf_nd6" cx="336.96" cy="328.24" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgcps_23385acf"/>
# <text x="336.96" y="328.24" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ACE</text>
# <circle id="svgcps_23385acf_nd7" cx="400.00" cy="522.24" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="6" data-tip-uid="svgcps_23385acf"/>
# <text x="400.00" y="522.
# <div id="klotho_ss_13bd394d" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 6px 10px;
#     background: #1a1a2e;
#     border-radius: 6px;
#     user-select: none;
# ">
#     <button id="klotho_ss_13bd394d_toggle" style="
#         width: 32px;
#         height: 32px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#     ">
#         <span id="klotho_ss_13bd394d_icon" style="
#             width: 0;
#             height: 0;
#             border-top: 7px solid transparent;
#             border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80;
#             margin-left: 3px;
#         "></span>
#     </button>
#     <button id="klotho_ss_13bd394d_loop" style="
#         width: 28px;
#         height: 28px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#         opacity: 0.5;
#     ">
#         <svg id="klotho_ss_13bd394d_loop_svg" width="16" height="16" viewBox="0 0 24 24" fill="none" stroke="#a0a0a0" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path>
#             <path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path>
#             <path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
#     <span id="klotho_ss_13bd394d_status" style="
#         color: #666;
#         font-size: 10px;
#         min-width: 60px;
#     ">ready</span>
# </div>
#
# <script>
#
# // SuperSonic standalone playback widget.
# // Python replaces: klotho_ss_13bd394d, [{"type": "new", "id": "3427831c8d0e432897fb4b1ebc1220cb", "defName": "kl_tri", "start": 0, "pfields": {"freq": 67.4504, "amp": 0.32048700060925006}, "_stepIndex": 0}, {"type": "release", "id": "3427831c8d0e432897fb4b1ebc1220cb", "start": 0.15, "_stepIndex": 0}, {"type": "new", "id": "1fa1c643e71c47d8baaae0aae2471112", "defName": "kl_tri", "start": 0.15, "pfields": {"freq": 68.9833, "amp": 0.32207425551811875}, "_stepIndex": 1}, {"type": "release", "id": "1fa1c643e71c47d8baaae0aae2471112", "start": 0.3, "_stepIndex": 1}, {"type": "new", "id": "a25e19d6835740aca26f30bd07e47716", "defName": "kl_tri", "start": 0.3, "pfields": {"freq": 71.5382, "amp": 0.32465768312924875}, "_stepIndex": 2}, {"type": "release", "id": "a25e19d6835740aca26f30bd07e47716", "start": 0.44999999999999996, "_stepIndex": 2}, {"type": "new", "id": "f314662b5cf24f5ab119961d0364f0a8", "defName": "kl_tri", "start": 0.44999999999999996, "pfields": {"freq": 75.8816, "amp": 0.3288874252764311}, "_stepIndex": 3}, {"type": "release", "id": "f314662b5cf24f5ab119961d0364f0a8", "start": 0.6, "_stepIndex": 3}, {"type": "new", "id": "17befbbe5e2e4946b6dd95437f73bd03", "defName": "kl_tri", "start": 0.6, "pfields": {"freq": 78.6921, "amp": 0.33152785500850146}, "_stepIndex": 4}, {"type": "release", "id": "17befbbe5e2e4946b6dd95437f73bd03", "start": 0.75, "_stepIndex": 4}, {"type": "new", "id": "a15349d8b33b4c06855d20325a10aab4", "defName": "kl_tri", "start": 0.75, "pfields": {"freq": 80.4805, "amp": 0.33317317961507}, "_stepIndex": 5}, {"type": "release", "id": "a15349d8b33b4c06855d20325a10aab4", "start": 0.9, "_stepIndex": 5}, {"type": "new", "id": "5a111da877244cebb68ece6cd48dcc9d", "defName": "kl_tri", "start": 0.9, "pfields": {"freq": 84.3129, "amp": 0.33661912609210914}, "_stepIndex": 6}, {"type": "release", "id": "5a111da877244cebb68ece6cd48dcc9d", "start": 1.05, "_stepIndex": 6}, {"type": "new", "id": "40fa7c3dd2704c0dbb1425e22088763b", "defName": "kl_tri", "start": 1.05, "pfields": {"freq": 85.8459, "amp": 0.33797075387458925}, "_stepIndex": 7}, {"type": "release", "id": "40fa7c3dd2704c0dbb1425e22088763b", "start": 1.2, "_stepIndex": 7}, {"type": "new", "id": "8a0a3c6b48d14030aad9e46d0e40d996", "defName": "kl_tri", "start": 1.2, "pfields": {"freq": 88.5286, "amp": 0.3403049571710779}, "_stepIndex": 8}, {"type": "release", "id": "8a0a3c6b48d14030aad9e46d0e40d996", "start": 1.3499999999999999, "_stepIndex": 8}, {"type": "new", "id": "84e328e598d84215b5add0d5ef1dc754", "defName": "kl_tri", "start": 1.3499999999999999, "pfields": {"freq": 91.9777, "amp": 0.34325804568693724}, "_stepIndex": 9}, {"type": "release", "id": "84e328e598d84215b5add0d5ef1dc754", "start": 1.4999999999999998, "_stepIndex": 9}, {"type": "new", "id": "328810efb96040d7bd9eb2a8f62ce468", "defName": "kl_tri", "start": 1.4999999999999998, "pfields": {"freq": 96.5766, "amp": 0.34713666216187933}, "_stepIndex": 10}, {"type": "release", "id": "328810efb96040d7bd9eb2a8f62ce468", "start": 1.6499999999999997, "_stepIndex": 10}, {"type": "new", "id": "41fd6b22d7b047c7a2c124cbfc4a6ca3", "defName": "kl_tri", "start": 1.6499999999999997, "pfields": {"freq": 98.3651, "amp": 0.34863393410065163}, "_stepIndex": 11}, {"type": "release", "id": "41fd6b22d7b047c7a2c124cbfc4a6ca3", "start": 1.7999999999999996, "_stepIndex": 11}, {"type": "new", "id": "a8b1ca1596bc4ad9b86a9dcf991204b3", "defName": "kl_tri", "start": 1.7999999999999996, "pfields": {"freq": 101.1755, "amp": 0.3509815050788694}, "_stepIndex": 12}, {"type": "release", "id": "a8b1ca1596bc4ad9b86a9dcf991204b3", "start": 1.9499999999999995, "_stepIndex": 12}, {"type": "new", "id": "a1185317891c462ab9264b5f43234781", "defName": "kl_tri", "start": 1.9499999999999995, "pfields": {"freq": 107.3074, "amp": 0.35609209194991875}, "_stepIndex": 13}, {"type": "release", "id": "a1185317891c462ab9264b5f43234781", "start": 2.0999999999999996, "_stepIndex": 13}, {"type": "new", "id": "c7cbb829d77e4e34a81e7b52eb934613", "defName": "kl ...

# %% [markdown]
# We can do all the same operations with shapes. These do not necessarily need to be *faces*, we can specify any configuration of nodes and find all matching instances:

# %%
shape = [7, 16, 19, 13]
print('Target Shape:')
matches = match_pattern(ek, shape, sort_by='rotation', include_target=True)
plot(ek, shape=matches, node_size=20, text_size=8, figsize=(8,8)).play(dur=1)
# Out:
# Target Shape:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="800" height="800" style="display:block;background:black"><rect width="800" height="800" fill="black"/>
# <text x="400.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D E F]</text>
# <line x1="132.97" y1="328.24" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="328.24" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="328.24" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="501.76" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="501.76" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="501.76" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line id="svgcps_f71af404_se1" x1="400.00" y1="134.23" x2="234.97" y2="187.85" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_f71af404_se2" x1="400.00" y1="134.23" x2="565.03" y2="187.85" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_f71af404_se3" x1="400.00" y1="134.23" x2="400.00" y2="307.76" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_f71af404_se4" x1="400.00" y1="695.77" x2="234.97" y2="642.15" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_f71af404_se5" x1="400.00" y1="695.77" x2="565.03" y2="642.15" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_f71af404_se6" x1="400.00" y1="695.77" x2="400.00" y2="522.24" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_f71af404_se7" x1="234.97" y1="642.15" x2="132.97" y2="501.76" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_f71af404_se8" x1="234.97" y1="642.15" x2="400.00" y2="695.77" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_f71af404_se9" x1="234.97" y1="642.15" x2="336.96" y2="501.76" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_f71af404_se10" x1="565.03" y1="187.85" x2="400.00" y2="134.23" stroke="#87CEEB" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_f71af404_se11" x1="565.03" y1="187.85" x2="667.03" y2="328.24" stroke="#87CEEB" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_f71af404_se12" x1="565.03" y1="187.85" x2="463.04" y2="328.24" stroke="#87CEEB" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_f71af404_se13" x1="667.03" y1="328.24" x2="667.03" y2="501.76" stroke="#DDA0DD" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_f71af404_se14" x1="667.03" y1="328.24" x2="565.03" y2="187.85" stroke="#DDA0DD" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_f71af404_se15" x1="667.03" y1="328.24" x2="502.00" y2="381.86" stroke="#DDA0DD" str

# %% [markdown]
# Eikosany also has other forms. We can derive them by using a different generating geometry:

# %%
plot(MasterSet.centered_pentagon(), figsize=(6,6))
# Out:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="600" height="600" style="display:block;background:black"><text x="300.0" y="18" text-anchor="middle" font-family="Arial" font-size="14" fill="white">MasterSet: centered_pentagon</text>
# <line x1="300.00" y1="80.53" x2="69.23" y2="248.19" stroke="#808080" stroke-width="1.5"/>
# <line x1="300.00" y1="80.53" x2="530.77" y2="248.19" stroke="#808080" stroke-width="1.5"/>
# <line x1="69.23" y1="248.19" x2="157.38" y2="519.47" stroke="#808080" stroke-width="1.5"/>
# <line x1="530.77" y1="248.19" x2="442.62" y2="519.47" stroke="#808080" stroke-width="1.5"/>
# <line x1="157.38" y1="519.47" x2="442.62" y2="519.47" stroke="#808080" stroke-width="1.5"/>
# <circle cx="300.00" cy="323.17" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgms_63ce699a"/>
# <text x="300.00" y="324.17" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">A</text>
# <circle cx="300.00" cy="80.53" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgms_63ce699a"/>
# <text x="300.00" y="81.53" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">B</text>
# <circle cx="530.77" cy="248.19" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgms_63ce699a"/>
# <text x="530.77" y="249.19" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">C</text>
# <circle cx="442.62" cy="519.47" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgms_63ce699a"/>
# <text x="442.62" y="520.47" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">D</text>
# <circle cx="157.38" cy="519.47" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgms_63ce699a"/>
# <text x="157.38" y="520.47" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">E</text>
# <circle cx="69.23" cy="248.19" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgms_63ce699a"/>
# <text x="69.23" y="249.19" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">F</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
#     }
#
#     function reorderEventsFrom(allEvents, startGi, total, gap) {
#       var gapSec = typeof gap === "number" ? Math.max(0, gap) : _pause;
#       var buckets = [];
#       for (var g = 0; g < total; g++) buckets.push([]);
#       for (var i = 0; i < allEvents.length; i++) {
#         var si = allEvents[i]._stepIndex;
#         if (si >= 0 && si < total) buckets[si].push(allEvents[i]);
#       }
#       var groupStarts = [];
#       for (var g1 = 0; g1 < total; g1++) {
#         var mn = Infinity;
#         for (var i1 = 0; i1 < buckets[g1].length; i1++) {
#           if (buckets[g1][i1].start < mn) mn = buckets[g1][i1].start;
#         }
#         groupStarts.push(mn === Infinity ? 0 : mn);
#       }
#       var groupDurs = [];
#       for (var g2 = 0; g2 < total; g2++) {
#         var mx = 0;
#         for (var i2 = 0; i2 < buckets[g2].length; i2++) {
#           var end = eventEnd(buckets[g2][i2]);
#           if (end > mx) mx = end;
#         }
#         groupDurs.push(mx - groupStarts[g2]);
#       }
#       var result = [];
#       var cursor = 0;
#       var seqMap = [];
#       for (var step = 0; step < total; step++) {
#         var gi = (startGi + step) % total;
#         seqMap.push(gi);
#         var base = groupStarts[gi];
#         for (var i3 = 0; i3 < buckets[gi].length; i3++) {
#           var e2 = {};
#           for (var k2 in buckets[gi][i3]) e2[k2] = buckets[gi][i3][k2];
#           e2.start = cursor + (buckets[gi][i3].start - base);
#           e2._stepIndex = step;
#           result.push(e2);
#         }
#         cursor += groupDurs[gi] + gapSec;
#       }
#       return { events: result, seqMap: seqMap };
#     }
#
#     function isPlaying() {
#       if (engine === "supersonic") return !!(_ssScheduler && _ssScheduler.isPlaying);
#       return !!(_aPlayer && _aPlayer.isPlaying());
#     }
#
#     async function stop() {
#       if (engine === "supersonic") {
#         if (_ssScheduler && _ssScheduler.isPlaying) await _ssScheduler.stop();
#         return;
#       }
#       if (_aPlayer

# %%
ek = Eikosany(master_set='centered_pentagon')
print('Ratios: ', *[str(r) for r in ek.ratios])
plot(ek, node_size=25, text_size=10, figsize=(8,8))
pc = PC.from_degrees(list(ek.ratios), equave='2/1')
idx = list(range(-len(ek.ratios)*2, len(ek.ratios)*2))
play(pc.root('C4')[idx + idx[-2::-1]], dur=0.15)
# Out:
# Ratios:  33/32 135/128 35/32 297/256 77/64 315/256 165/128 21/16 693/512 45/32 189/128 385/256 99/64 105/64 27/16 55/32 231/128 15/8 495/256 63/32
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="800" height="800" style="display:block;background:black"><rect width="800" height="800" fill="black"/>
# <text x="400.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D E F]</text>
# <line x1="667.03" y1="501.76" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="501.76" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="328.24" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="328.24" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <circle id="svgcps_999fede2_nd1" cx="565.03" cy="187.85" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_999fede2"/>
# <text x="565.03" y="187.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABC</text>
# <circle id="svgcps_999fede2_nd2" cx="502.00" cy="381.86" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_999fede2"/>
# <text x="502.00" y="381.86" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABD</text>
# <circle id="svgcps_999fede2_nd3" cx="298.00" cy="381.86" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_999fede2"/>
# <text x="298.00" y="381.86" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABE</text>
# <circle id="svgcps_999fede2_nd4" cx="234.97" cy="187.85" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgcps_999fede2"/>
# <text x="234.97" y="187.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABF</text>
# <circle id="svgcps_999fede2_nd5" cx="667.03" cy="501.76" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgcps_999fede2"/>
# <text x="667.03" y="501.76" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ACD</text>
# <circle id="svgcps_999fede2_nd6" cx="463.04" cy="501.76" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgcps_999fede2"/>
# <text x="463.04" y="501.76" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ACE</text>
# <circle id="svgcps_999fede2_nd7" cx="400.00" cy="307.76" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="6" data-tip-uid="svgcps_999fede2"/>
# <text x="400.00" y="307.
# <div id="klotho_ss_1bb7b9d3" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 6px 10px;
#     background: #1a1a2e;
#     border-radius: 6px;
#     user-select: none;
# ">
#     <button id="klotho_ss_1bb7b9d3_toggle" style="
#         width: 32px;
#         height: 32px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#     ">
#         <span id="klotho_ss_1bb7b9d3_icon" style="
#             width: 0;
#             height: 0;
#             border-top: 7px solid transparent;
#             border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80;
#             margin-left: 3px;
#         "></span>
#     </button>
#     <button id="klotho_ss_1bb7b9d3_loop" style="
#         width: 28px;
#         height: 28px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#         opacity: 0.5;
#     ">
#         <svg id="klotho_ss_1bb7b9d3_loop_svg" width="16" height="16" viewBox="0 0 24 24" fill="none" stroke="#a0a0a0" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path>
#             <path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path>
#             <path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
#     <span id="klotho_ss_1bb7b9d3_status" style="
#         color: #666;
#         font-size: 10px;
#         min-width: 60px;
#     ">ready</span>
# </div>
#
# <script>
#
# // SuperSonic standalone playback widget.
# // Python replaces: klotho_ss_1bb7b9d3, [{"type": "new", "id": "ab587311ffc045788234ce1ca8ade31b", "defName": "kl_tri", "start": 0, "pfields": {"freq": 67.4504, "amp": 0.32048700060925006}, "_stepIndex": 0}, {"type": "release", "id": "ab587311ffc045788234ce1ca8ade31b", "start": 0.15, "_stepIndex": 0}, {"type": "new", "id": "7f3da34adc9d4038ad0ae78c90405cd8", "defName": "kl_tri", "start": 0.15, "pfields": {"freq": 68.9833, "amp": 0.32207425551811875}, "_stepIndex": 1}, {"type": "release", "id": "7f3da34adc9d4038ad0ae78c90405cd8", "start": 0.3, "_stepIndex": 1}, {"type": "new", "id": "5e6b1a5ae4524812b10f0bc6b524461d", "defName": "kl_tri", "start": 0.3, "pfields": {"freq": 71.5382, "amp": 0.32465768312924875}, "_stepIndex": 2}, {"type": "release", "id": "5e6b1a5ae4524812b10f0bc6b524461d", "start": 0.44999999999999996, "_stepIndex": 2}, {"type": "new", "id": "21e05f0a99fa4c0089e1ec8d046590aa", "defName": "kl_tri", "start": 0.44999999999999996, "pfields": {"freq": 75.8816, "amp": 0.3288874252764311}, "_stepIndex": 3}, {"type": "release", "id": "21e05f0a99fa4c0089e1ec8d046590aa", "start": 0.6, "_stepIndex": 3}, {"type": "new", "id": "e4acae6b4e784d0695cc72c6de61fa83", "defName": "kl_tri", "start": 0.6, "pfields": {"freq": 78.6921, "amp": 0.33152785500850146}, "_stepIndex": 4}, {"type": "release", "id": "e4acae6b4e784d0695cc72c6de61fa83", "start": 0.75, "_stepIndex": 4}, {"type": "new", "id": "74181386edd4430a8d675b03f35b9788", "defName": "kl_tri", "start": 0.75, "pfields": {"freq": 80.4805, "amp": 0.33317317961507}, "_stepIndex": 5}, {"type": "release", "id": "74181386edd4430a8d675b03f35b9788", "start": 0.9, "_stepIndex": 5}, {"type": "new", "id": "a37b33c0f2a54ddd8884c259a41382c8", "defName": "kl_tri", "start": 0.9, "pfields": {"freq": 84.3129, "amp": 0.33661912609210914}, "_stepIndex": 6}, {"type": "release", "id": "a37b33c0f2a54ddd8884c259a41382c8", "start": 1.05, "_stepIndex": 6}, {"type": "new", "id": "078247963bfb4168a91993b323425447", "defName": "kl_tri", "start": 1.05, "pfields": {"freq": 85.8459, "amp": 0.33797075387458925}, "_stepIndex": 7}, {"type": "release", "id": "078247963bfb4168a91993b323425447", "start": 1.2, "_stepIndex": 7}, {"type": "new", "id": "3fc7562db62e4d019327ff06c9533e7a", "defName": "kl_tri", "start": 1.2, "pfields": {"freq": 88.5286, "amp": 0.3403049571710779}, "_stepIndex": 8}, {"type": "release", "id": "3fc7562db62e4d019327ff06c9533e7a", "start": 1.3499999999999999, "_stepIndex": 8}, {"type": "new", "id": "eee6841c17224e30a5a3db36cf86dd26", "defName": "kl_tri", "start": 1.3499999999999999, "pfields": {"freq": 91.9777, "amp": 0.34325804568693724}, "_stepIndex": 9}, {"type": "release", "id": "eee6841c17224e30a5a3db36cf86dd26", "start": 1.4999999999999998, "_stepIndex": 9}, {"type": "new", "id": "124701ea142941a38a6b630a43a6257f", "defName": "kl_tri", "start": 1.4999999999999998, "pfields": {"freq": 96.5766, "amp": 0.34713666216187933}, "_stepIndex": 10}, {"type": "release", "id": "124701ea142941a38a6b630a43a6257f", "start": 1.6499999999999997, "_stepIndex": 10}, {"type": "new", "id": "c8733d8645f843709c01285b8b6133b5", "defName": "kl_tri", "start": 1.6499999999999997, "pfields": {"freq": 98.3651, "amp": 0.34863393410065163}, "_stepIndex": 11}, {"type": "release", "id": "c8733d8645f843709c01285b8b6133b5", "start": 1.7999999999999996, "_stepIndex": 11}, {"type": "new", "id": "ce820c2dd2ab465cb4c112577c160e94", "defName": "kl_tri", "start": 1.7999999999999996, "pfields": {"freq": 101.1755, "amp": 0.3509815050788694}, "_stepIndex": 12}, {"type": "release", "id": "ce820c2dd2ab465cb4c112577c160e94", "start": 1.9499999999999995, "_stepIndex": 12}, {"type": "new", "id": "bda875147a31464e87a2102cc1cae515", "defName": "kl_tri", "start": 1.9499999999999995, "pfields": {"freq": 107.3074, "amp": 0.35609209194991875}, "_stepIndex": 13}, {"type": "release", "id": "bda875147a31464e87a2102cc1cae515", "start": 2.0999999999999996, "_stepIndex": 13}, {"type": "new", "id": "2c4d261dc89a4f00ab895226f848e870", "defName": "kl ...

# %%
shape = [12, 14, 11, 13]
print('Target Shape:')
matches = match_pattern(ek, shape, sort_by='position', include_target=True)
plot(ek, shape=matches, node_size=20, text_size=8, figsize=(8,8)).play(dur=0.667, pause=0, sustainLevel=0.5)
# Out:
# Target Shape:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="800" height="800" style="display:block;background:black"><rect width="800" height="800" fill="black"/>
# <text x="400.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D E F]</text>
# <line x1="667.03" y1="501.76" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="501.76" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="328.24" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="328.24" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line id="svgcps_7fd6d582_se1" x1="400.00" y1="134.23" x2="336.96" y2="328.24" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_7fd6d582_se2" x1="400.00" y1="134.23" x2="463.04" y2="328.24" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_7fd6d582_se3" x1="336.96" y1="328.24" x2="400.00" y2="522.24" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_7fd6d582_se4" x1="463.04" y1="328.24" x2="400.00" y2="522.24" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_7fd6d582_se5" x1="565.03" y1="187.85" x2="502.00" y2="381.86" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_7fd6d582_se6" x1="565.03" y1="187.85" x2="400.00" y2="307.76" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_7fd6d582_se7" x1="502.00" y1="381.86" x2="336.96" y2="501.76" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_7fd6d582_se8" x1="400.00" y1="307.76" x2="336.96" y2="501.76" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_7fd6d582_se9" x1="667.03" y1="328.24" x2="463.04" y2="328.24" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_7fd6d582_se10" x1="667.03" y1="328.24" x2="502.00" y2="448.14" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_7fd6d582_se11" x1="463.04" y1="328.24" x2="298.00" y2="448.14" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_7fd6d582_se12" x1="502.00" y1="448.14" x2="298.00" y2="448.14" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_7fd6d582_se13" x1="298.00" y1="381.86" x2="502.00" y2="381.86" stroke="#87CEEB" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_7fd6d582_se14" x1="298.00" y1="381.86" x2="463.04" y2="501.76" stroke="#87CEEB" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_7fd6d582_se15" x1="502.00" y1="381.86" x2="667.03" y2="501.76" stroke="#87CEEB" str

# %% [markdown]
# Eikosany can also be built from a "distorted" hexagon. This form, devised by Erv Wilson, uses a slight
# geometric distortion to prevent two nodes from overlapping in the resultant CPS graph:

# %%
print('GENERATING GEOMETRY')
plot(MasterSet.irregular_hexagon(), figsize=(6,6))

print('\nCPS')
ek_ih = Eikosany(master_set='irregular_hexagon')
plot(ek_ih, node_size=25, text_size=10, figsize=(8,8))
pc = PC.from_degrees(list(ek_ih.ratios), equave='2/1')
idx = list(range(-len(ek_ih.ratios)*2, len(ek_ih.ratios)*2))
play(pc.root('C4')[idx + idx[-2::-1]], dur=0.15)
# Out:
# GENERATING GEOMETRY
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="600" height="600" style="display:block;background:black"><text x="300.0" y="18" text-anchor="middle" font-family="Arial" font-size="14" fill="white">MasterSet: irregular_hexagon</text>
# <line x1="300.00" y1="97.02" x2="468.93" y2="265.95" stroke="#808080" stroke-width="1.5"/>
# <line x1="468.93" y1="265.95" x2="530.77" y2="441.15" stroke="#808080" stroke-width="1.5"/>
# <line x1="530.77" y1="441.15" x2="300.00" y2="502.98" stroke="#808080" stroke-width="1.5"/>
# <line x1="300.00" y1="502.98" x2="69.23" y2="441.15" stroke="#808080" stroke-width="1.5"/>
# <line x1="69.23" y1="441.15" x2="131.07" y2="265.95" stroke="#808080" stroke-width="1.5"/>
# <line x1="131.07" y1="265.95" x2="300.00" y2="97.02" stroke="#808080" stroke-width="1.5"/>
# <circle cx="530.77" cy="441.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgms_0aaf4d0d"/>
# <text x="530.77" y="442.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">A</text>
# <circle cx="69.23" cy="441.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgms_0aaf4d0d"/>
# <text x="69.23" y="442.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">B</text>
# <circle cx="300.00" cy="97.02" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgms_0aaf4d0d"/>
# <text x="300.00" y="98.02" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">C</text>
# <circle cx="131.07" cy="265.95" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgms_0aaf4d0d"/>
# <text x="131.07" y="266.95" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">D</text>
# <circle cx="300.00" cy="502.98" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgms_0aaf4d0d"/>
# <text x="300.00" y="503.98" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">E</text>
# <circle cx="468.93" cy="265.95" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgms_0aaf4d0d"/>
# <text x="468.93" y="266.95" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">F</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
#     }
#
#     function reorderEventsFrom(allEvents, startGi, total, gap) {
#       var gapSec = typeof gap === "number" ? Math.max(0, gap) : _pause;
#       var buckets = [];
#       for (var g = 0; g < total; g++) buckets.push([]);
#       for (var i = 0; i < allEvents.length; i++) {
#         var si = allEvents[i]._stepIndex;
#         if (si >= 0 && si < total) buckets[si].push(allEvents[i]);
#       }
#       var groupStarts = [];
#       for (var g1 = 0; g1 < total; g1++) {
#         var mn = Infinity;
#         for (var i1 = 0; i1 < buckets[g1].length; i1++) {
#           if (buckets[g1][i1].start < mn) mn = buckets[g1][i1].start;
#         }
#         groupStarts.push(mn === Infinity ? 0 : mn);
#       }
#       var groupDurs = [];
#       for (var g2 = 0; g2 < total; g2++) {
#         var mx = 0;
#         for (var i2 = 0; i2 < buckets[g2].length; i2++) {
#           var end = eventEnd(buckets[g2][i2]);
#           if (end > mx) mx = end;
#         }
#         groupDurs.push(mx - groupStarts[g2]);
#       }
#       var result = [];
#       var cursor = 0;
#       var seqMap = [];
#       for (var step = 0; step < total; step++) {
#         var gi = (startGi + step) % total;
#         seqMap.push(gi);
#         var base = groupStarts[gi];
#         for (var i3 = 0; i3 < buckets[gi].length; i3++) {
#           var e2 = {};
#           for (var k2 in buckets[gi][i3]) e2[k2] = buckets[gi][i3][k2];
#           e2.start = cursor + (buckets[gi][i3].start - base);
#           e2._stepIndex = step;
#           result.push(e2);
#         }
#         cursor += groupDurs[gi] + gapSec;
#       }
#       return { events: result, seqMap: seqMap };
#     }
#
#     function isPlaying() {
#       if (engine === "supersonic") return !!(_ssScheduler && _ssScheduler.isPlaying);
#       return !!(_aPlayer && _aPlayer.isPlaying());
#     }
#
#     async function stop() {
#       if (engine === "supersonic") {
#         if (_ssScheduler && _s
# CPS
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="800" height="800" style="display:block;background:black"><rect width="800" height="800" fill="black"/>
# <text x="400.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D E F]</text>
# <line x1="445.22" y1="261.10" x2="276.46" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="261.10" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="261.10" x2="400.00" y2="132.97" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="261.10" x2="568.76" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="434.44" x2="107.69" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="434.44" x2="276.46" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="434.44" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="434.44" x2="354.78" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="107.69" y1="557.99" x2="231.24" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="107.69" y1="557.99" x2="276.46" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="686.11" x2="445.22" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="686.11" x2="354.78" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="306.32" x2="445.22" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="306.32" x2="231.24" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="306.32" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="306.32" x2="107.69" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="434.44" x2="445.22" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="434.44" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="434.44" x2="523.54" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="434.44" x2="692.31" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="261.10" x2="231.24" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="261.10" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="261.10" x2="400.00" y2="132.97" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="261.10" x2="523.54" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="557.99" x2="400.00" y2="686.11" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="557.99" x2="568.76" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="557.99" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="557.99" x2="276.46" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="384.64" x2="354.78" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="384.64" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="384.64" x2="107.69" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="384.64" x2="276.46" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="276.46" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="445.22" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="231.24" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="354.78" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="568.76" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="523.54" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="445.22" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="231.24" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="568.76" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="354.78" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="523.54" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="276.46" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="512.77" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="512.77" x2="354.78" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="512.77" x2="568.76" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="512.77" x2="692.31" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="132.97" x2="445.22" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="132.97" x2="354.78" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="557.99" x2="231.24" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="557.99" x2="400.00" y2="686.11" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="557.99" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="557.99" x2="523.54" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="692.31" y1="261.10" x2="568.76" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="692.31" y1="261.10" x2="523.54" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="107.69" y1="261.10" x2="276.46" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="107.69" y1="261.10" x2="231.24" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="384.64" x2="445.22" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="384.64" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="384.64" x2="523.54" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="384.64" x2="692.31" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="306.32" x2="568.76" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="306.32" x2="354.78" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="306.32" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="306.32" x2="692.31" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="512.77" x2="107.69" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="512.77" x2="445.22" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="512.77" x2="231.24" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="512.77" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="692.31" y1="557.99" x2="568.76" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="692.31" y1="557.99" x2="523.54" y2="512.77" stroke="#808080" stroke-width="1"/>
# <circle id="svgcps_09124f65_nd1" cx="400.00" cy="389.22" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_09124f65"/>
# <text x="400.00" y="389.22" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABC</text>
# <circle id="svgcps_09124f65_nd2" cx="276.46" cy="512.77" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_09124f65"/>
# <text x="276.46" y="512.77" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABD</text>
# <circle id="svgcps_09124f65_nd3" cx="400.00" cy="686.11" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_09124f65"/>
# <text x="400.00" y="686.11" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABE</text>
# <circle id="svgcps_09124f65_nd4" cx="523.54" cy="512.77" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="
# <div id="klotho_ss_ccf67698" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 6px 10px;
#     background: #1a1a2e;
#     border-radius: 6px;
#     user-select: none;
# ">
#     <button id="klotho_ss_ccf67698_toggle" style="
#         width: 32px;
#         height: 32px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#     ">
#         <span id="klotho_ss_ccf67698_icon" style="
#             width: 0;
#             height: 0;
#             border-top: 7px solid transparent;
#             border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80;
#             margin-left: 3px;
#         "></span>
#     </button>
#     <button id="klotho_ss_ccf67698_loop" style="
#         width: 28px;
#         height: 28px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#         opacity: 0.5;
#     ">
#         <svg id="klotho_ss_ccf67698_loop_svg" width="16" height="16" viewBox="0 0 24 24" fill="none" stroke="#a0a0a0" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path>
#             <path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path>
#             <path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
#     <span id="klotho_ss_ccf67698_status" style="
#         color: #666;
#         font-size: 10px;
#         min-width: 60px;
#     ">ready</span>
# </div>
#
# <script>
#
# // SuperSonic standalone playback widget.
# // Python replaces: klotho_ss_ccf67698, [{"type": "new", "id": "bc1f1903d13641898631eaa7f3ea804a", "defName": "kl_tri", "start": 0, "pfields": {"freq": 67.4504, "amp": 0.32048700060925006}, "_stepIndex": 0}, {"type": "release", "id": "bc1f1903d13641898631eaa7f3ea804a", "start": 0.15, "_stepIndex": 0}, {"type": "new", "id": "7242f0d0262549b9bcb0d6c4fd6fe956", "defName": "kl_tri", "start": 0.15, "pfields": {"freq": 68.9833, "amp": 0.32207425551811875}, "_stepIndex": 1}, {"type": "release", "id": "7242f0d0262549b9bcb0d6c4fd6fe956", "start": 0.3, "_stepIndex": 1}, {"type": "new", "id": "857dbc03a0934b488d188fdad7152627", "defName": "kl_tri", "start": 0.3, "pfields": {"freq": 71.5382, "amp": 0.32465768312924875}, "_stepIndex": 2}, {"type": "release", "id": "857dbc03a0934b488d188fdad7152627", "start": 0.44999999999999996, "_stepIndex": 2}, {"type": "new", "id": "1d32eeee9cc7412f944e03fb71445671", "defName": "kl_tri", "start": 0.44999999999999996, "pfields": {"freq": 75.8816, "amp": 0.3288874252764311}, "_stepIndex": 3}, {"type": "release", "id": "1d32eeee9cc7412f944e03fb71445671", "start": 0.6, "_stepIndex": 3}, {"type": "new", "id": "92890492672543568aabddd24355cde7", "defName": "kl_tri", "start": 0.6, "pfields": {"freq": 78.6921, "amp": 0.33152785500850146}, "_stepIndex": 4}, {"type": "release", "id": "92890492672543568aabddd24355cde7", "start": 0.75, "_stepIndex": 4}, {"type": "new", "id": "4b1f693302fe4a93acb4c4cecaccf8ad", "defName": "kl_tri", "start": 0.75, "pfields": {"freq": 80.4805, "amp": 0.33317317961507}, "_stepIndex": 5}, {"type": "release", "id": "4b1f693302fe4a93acb4c4cecaccf8ad", "start": 0.9, "_stepIndex": 5}, {"type": "new", "id": "f6d1d1079f07490192c93fa2645d6aee", "defName": "kl_tri", "start": 0.9, "pfields": {"freq": 84.3129, "amp": 0.33661912609210914}, "_stepIndex": 6}, {"type": "release", "id": "f6d1d1079f07490192c93fa2645d6aee", "start": 1.05, "_stepIndex": 6}, {"type": "new", "id": "bea5398635cb4be4b8ab4ccb5f3fb534", "defName": "kl_tri", "start": 1.05, "pfields": {"freq": 85.8459, "amp": 0.33797075387458925}, "_stepIndex": 7}, {"type": "release", "id": "bea5398635cb4be4b8ab4ccb5f3fb534", "start": 1.2, "_stepIndex": 7}, {"type": "new", "id": "8248af8d138d4b08966eda71a994fb41", "defName": "kl_tri", "start": 1.2, "pfields": {"freq": 88.5286, "amp": 0.3403049571710779}, "_stepIndex": 8}, {"type": "release", "id": "8248af8d138d4b08966eda71a994fb41", "start": 1.3499999999999999, "_stepIndex": 8}, {"type": "new", "id": "f5ee3629beb04cf89bf32bf63db6f1cd", "defName": "kl_tri", "start": 1.3499999999999999, "pfields": {"freq": 91.9777, "amp": 0.34325804568693724}, "_stepIndex": 9}, {"type": "release", "id": "f5ee3629beb04cf89bf32bf63db6f1cd", "start": 1.4999999999999998, "_stepIndex": 9}, {"type": "new", "id": "a4738bd6ada64c0eb4e48dc9b1ebbf28", "defName": "kl_tri", "start": 1.4999999999999998, "pfields": {"freq": 96.5766, "amp": 0.34713666216187933}, "_stepIndex": 10}, {"type": "release", "id": "a4738bd6ada64c0eb4e48dc9b1ebbf28", "start": 1.6499999999999997, "_stepIndex": 10}, {"type": "new", "id": "06c2bcc3d24847618206db37ea3c1f54", "defName": "kl_tri", "start": 1.6499999999999997, "pfields": {"freq": 98.3651, "amp": 0.34863393410065163}, "_stepIndex": 11}, {"type": "release", "id": "06c2bcc3d24847618206db37ea3c1f54", "start": 1.7999999999999996, "_stepIndex": 11}, {"type": "new", "id": "5c3f77c7ea504302810ecd418be6712a", "defName": "kl_tri", "start": 1.7999999999999996, "pfields": {"freq": 101.1755, "amp": 0.3509815050788694}, "_stepIndex": 12}, {"type": "release", "id": "5c3f77c7ea504302810ecd418be6712a", "start": 1.9499999999999995, "_stepIndex": 12}, {"type": "new", "id": "b04fb8661bdd4da196b5301b0069f887", "defName": "kl_tri", "start": 1.9499999999999995, "pfields": {"freq": 107.3074, "amp": 0.35609209194991875}, "_stepIndex": 13}, {"type": "release", "id": "b04fb8661bdd4da196b5301b0069f887", "start": 2.0999999999999996, "_stepIndex": 13}, {"type": "new", "id": "f3f04c38a146442dab2b92ab4302aa94", "defName": "kl ...

# %%
target_shapes = [[11, 16, 4, 0], [18, 6, 8, 19], [0, 12, 4], [12, 18, 5]]
print('Target Shape:')
matches = [match for shape in target_shapes for match in match_pattern(ek_ih, shape, include_target=True)]
np.random.shuffle(matches)
plot(ek_ih, shape=matches, node_size=20, text_size=8, figsize=(8,8)).play(dur=2, pause=0.5, strum=0.5, releaseTime=2)
# Out:
# Target Shape:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="800" height="800" style="display:block;background:black"><rect width="800" height="800" fill="black"/>
# <text x="400.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D E F]</text>
# <line x1="445.22" y1="261.10" x2="276.46" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="261.10" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="261.10" x2="400.00" y2="132.97" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="261.10" x2="568.76" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="434.44" x2="107.69" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="434.44" x2="276.46" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="434.44" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="434.44" x2="354.78" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="107.69" y1="557.99" x2="231.24" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="107.69" y1="557.99" x2="276.46" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="686.11" x2="445.22" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="686.11" x2="354.78" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="306.32" x2="445.22" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="306.32" x2="231.24" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="306.32" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="306.32" x2="107.69" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="434.44" x2="445.22" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="434.44" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="434.44" x2="523.54" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="434.44" x2="692.31" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="261.10" x2="231.24" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="261.10" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="261.10" x2="400.00" y2="132.97" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="261.10" x2="523.54" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="557.99" x2="400.00" y2="686.11" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="557.99" x2="568.76" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="557.99" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="557.99" x2="276.46" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="384.64" x2="354.78" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="384.64" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="384.64" x2="107.69" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="384.64" x2="276.46" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="276.46" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="445.22" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="231.24" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="354.78" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="568.76" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="523.54" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="445.22" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="231.24" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="568.76" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="354.78" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="523.54" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="276.46" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="512.77" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="512.77" x2="354.78" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="512.77" x2="568.76" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="512.77" x2="692.31" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="132.97" x2="445.22" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="132.97" x2="354.78" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="557.99" x2="231.24" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="557.99" x2="400.00" y2="686.11" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="557.99" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="557.99" x2="523.54" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="692.31" y1="261.10" x2="568.76" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="692.31" y1="261.10" x2="523.54" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="107.69" y1="261.10" x2="276.46" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="107.69" y1="261.10" x2="231.24" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="384.64" x2="445.22" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="384.64" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="384.64" x2="523.54" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="384.64" x2="692.31" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="306.32" x2="568.76" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="306.32" x2="354.78" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="306.32" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="306.32" x2="692.31" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="512.77" x2="107.69" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="512.77" x2="445.22" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="512.77" x2="231.24" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="512.77" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="692.31" y1="557.99" x2="568.76" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="692.31" y1="557.99" x2="523.54" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line id="svgcps_c97a2e3b_se1" x1="400.00" y1="686.11" x2="445.22" y2="557.99" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_c97a2e3b_se2" x1="400.00" y1="686.11" x2="354.78" y2="557.99" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_c97a2e3b_se3" x1="523.54" y1="306.32" x2="692.31" y2="261.10" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_c97a2e3b_se4" x1="523.54" y1="306.32" x2="400.00" y2="429.86" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_c97a2e3b_se5" x1="692.31" y1="261.10" x2="568.76" y2="384.64" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_c97a2e3b_se6" x1="568.76" y1="384.64" x2="400.00" y2="429.86" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_c97a2e3b_se7" x1="276.46" y1="512.77" x2="400.00" y2="389.22" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_c97a2e3b_se8" x1="276.46" y1="512.77" x2="107.69" y2="557.99" str

# %% [markdown]
# ## Hebdomekontany

# %%
heb = Hebdomekontany()
plot(heb, node_size=15, text_size=5, figsize=(10,10))
# Out:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1000" height="1000" style="display:block;background:black"><rect width="1000" height="1000" fill="black"/>
# <text x="500.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D E F G H]</text>
# <line x1="624.46" y1="702.59" x2="469.26" y2="738.02" stroke="#808080" stroke-width="1"/>
# <line x1="624.46" y1="702.59" x2="624.46" y2="543.41" stroke="#808080" stroke-width="1"/>
# <line x1="624.46" y1="702.59" x2="500.00" y2="603.34" stroke="#808080" stroke-width="1"/>
# <line x1="624.46" y1="702.59" x2="779.66" y2="738.02" stroke="#808080" stroke-width="1"/>
# <line x1="569.07" y1="459.92" x2="500.00" y2="603.34" stroke="#808080" stroke-width="1"/>
# <line x1="569.07" y1="459.92" x2="413.87" y2="495.34" stroke="#808080" stroke-width="1"/>
# <line x1="569.07" y1="459.92" x2="569.07" y2="300.73" stroke="#808080" stroke-width="1"/>
# <line x1="569.07" y1="459.92" x2="724.27" y2="495.34" stroke="#808080" stroke-width="1"/>
# <line x1="375.54" y1="702.59" x2="530.74" y2="738.02" stroke="#808080" stroke-width="1"/>
# <line x1="375.54" y1="702.59" x2="375.54" y2="543.41" stroke="#808080" stroke-width="1"/>
# <line x1="375.54" y1="702.59" x2="500.00" y2="603.34" stroke="#808080" stroke-width="1"/>
# <line x1="375.54" y1="702.59" x2="220.34" y2="738.02" stroke="#808080" stroke-width="1"/>
# <line x1="530.74" y1="738.02" x2="375.54" y2="702.59" stroke="#808080" stroke-width="1"/>
# <line x1="530.74" y1="738.02" x2="655.20" y2="837.27" stroke="#808080" stroke-width="1"/>
# <line x1="530.74" y1="738.02" x2="599.81" y2="594.59" stroke="#808080" stroke-width="1"/>
# <line x1="530.74" y1="738.02" x2="461.67" y2="594.59" stroke="#808080" stroke-width="1"/>
# <line x1="693.53" y1="630.02" x2="624.46" y2="486.59" stroke="#808080" stroke-width="1"/>
# <line x1="693.53" y1="630.02" x2="538.33" y2="594.59" stroke="#808080" stroke-width="1"/>
# <line x1="693.53" y1="630.02" x2="569.07" y2="729.27" stroke="#808080" stroke-width="1"/>
# <line x1="693.53" y1="630.02" x2="848.72" y2="594.59" stroke="#808080" stroke-width="1"/>
# <line x1="289.41" y1="594.59" x2="444.61" y2="630.02" stroke="#808080" stroke-width="1"/>
# <line x1="289.41" y1="594.59" x2="413.87" y2="495.34" stroke="#808080" stroke-width="1"/>
# <line x1="289.41" y1="594.59" x2="289.41" y2="435.41" stroke="#808080" stroke-width="1"/>
# <line x1="289.41" y1="594.59" x2="220.34" y2="738.02" stroke="#808080" stroke-width="1"/>
# <line x1="848.72" y1="435.41" x2="779.66" y2="291.98" stroke="#808080" stroke-width="1"/>
# <line x1="848.72" y1="435.41" x2="848.72" y2="594.59" stroke="#808080" stroke-width="1"/>
# <line x1="848.72" y1="435.41" x2="693.53" y2="399.98" stroke="#808080" stroke-width="1"/>
# <line x1="848.72" y1="435.41" x2="724.27" y2="534.66" stroke="#808080" stroke-width="1"/>
# <line x1="555.39" y1="399.98" x2="710.59" y2="435.41" stroke="#808080" stroke-width="1"/>
# <line x1="555.39" y1="399.98" x2="624.46" y2="543.41" stroke="#808080" stroke-width="1"/>
# <line x1="555.39" y1="399.98" x2="400.19" y2="435.41" stroke="#808080" stroke-width="1"/>
# <line x1="555.39" y1="399.98" x2="430.93" y2="300.73" stroke="#808080" stroke-width="1"/>
# <line x1="500.00" y1="157.31" x2="655.20" y2="192.73" stroke="#808080" stroke-width="1"/>
# <line x1="500.00" y1="157.31" x2="569.07" y2="300.73" stroke="#808080" stroke-width="1"/>
# <line x1="500.00" y1="157.31" x2="430.93" y2="300.73" stroke="#808080" stroke-width="1"/>
# <line x1="500.00" y1="157.31" x2="344.80" y2="192.73" stroke="#808080" stroke-width="1"/>
# <line x1="655.20" y1="837.27" x2="530.74" y2="738.02" stroke="#808080" stroke-width="1"/>
# <line x1="655.20" y1="837.27" x2="500.00" y2="872.69" stroke="#808080" stroke-width="1"/>
# <line x1="655.20" y1="837.27" x2="655.20" y2="678.08" stroke="#808080" stroke-width="1"/>
# <line x1="655.20" y1="837.27" x2="779.66" y2="738.02" stroke="#808080" stroke-width="1"/>
# <line x1="430.93" y1="570.08" x2="586.13" y2="534.66" stroke="#808080" stroke-width="1"/>
# <line x1="430.93" y1="570.08" x2="500.00" y2="426.66" stroke="#808080" stroke-width="1"/>
# <line x1="430.93" y1="570.08" x2="430.93" y2="729.27" stroke="#808080" stroke-width="1"/>
# <line x1="430.93" y1="570.08" x2="275.73" y2="534.66" stroke="#808080" stroke-width="1"/>
# <line x1="599.81" y1="594.59" x2="530.74" y2="738.02" stroke="#808080" stroke-width="1"/>
# <line x1="599.81" y1="594.59" x2="444.61" y2="630.02" stroke="#808080" stroke-width="1"/>
# <line x1="599.81" y1="594.59" x2="599.81" y2="435.41" stroke="#808080" stroke-width="1"/>
# <line x1="599.81" y1="594.59" x2="724.27" y2="495.34" stroke="#808080" stroke-width="1"/>
# <line x1="151.28" y1="594.59" x2="306.47" y2="630.02" stroke="#808080" stroke-width="1"/>
# <line x1="151.28" y1="594.59" x2="151.28" y2="435.41" stroke="#808080" stroke-width="1"/>
# <line x1="151.28" y1="594.59" x2="220.34" y2="738.02" stroke="#808080" stroke-width="1"/>
# <line x1="151.28" y1="594.59" x2="275.73" y2="495.34" stroke="#808080" stroke-width="1"/>
# <line x1="430.93" y1="459.92" x2="500.00" y2="603.34" stroke="#808080" stroke-width="1"/>
# <line x1="430.93" y1="459.92" x2="430.93" y2="300.73" stroke="#808080" stroke-width="1"/>
# <line x1="430.93" y1="459.92" x2="275.73" y2="495.34" stroke="#808080" stroke-width="1"/>
# <line x1="430.93" y1="459.92" x2="586.13" y2="495.34" stroke="#808080" stroke-width="1"/>
# <line x1="344.80" y1="351.92" x2="413.87" y2="495.34" stroke="#808080" stroke-width="1"/>
# <line x1="344.80" y1="351.92" x2="275.73" y2="495.34" stroke="#808080" stroke-width="1"/>
# <line x1="344.80" y1="351.92" x2="344.80" y2="192.73" stroke="#808080" stroke-width="1"/>
# <line x1="344.80" y1="351.92" x2="500.00" y2="387.34" stroke="#808080" stroke-width="1"/>
# <line x1="555.39" y1="630.02" x2="624.46" y2="486.59" stroke="#808080" stroke-width="1"/>
# <line x1="555.39" y1="630.02" x2="400.19" y2="594.59" stroke="#808080" stroke-width="1"/>
# <line x1="555.39" y1="630.02" x2="430.93" y2="729.27" stroke="#808080" stroke-width="1"/>
# <line x1="555.39" y1="630.02" x2="710.59" y2="594.59" stroke="#808080" stroke-width="1"/>
# <line x1="586.13" y1="534.66" x2="430.93" y2="570.08" stroke="#808080" stroke-width="1"/>
# <line x1="586.13" y1="534.66" x2="710.59" y2="435.41" stroke="#808080" stroke-width="1"/>
# <line x1="586.13" y1="534.66" x2="655.20" y2="678.08" stroke="#808080" stroke-width="1"/>
# <line x1="586.13" y1="534.66" x2="461.67" y2="435.41" stroke="#808080" stroke-width="1"/>
# <line x1="530.74" y1="291.98" x2="655.20" y2="192.73" stroke="#808080" stroke-width="1"/>
# <line x1="530.74" y1="291.98" x2="599.81" y2="435.41" stroke="#808080" stroke-width="1"/>
# <line x1="530.74" y1="291.98" x2="461.67" y2="435.41" stroke="#808080" stroke-width="1"/>
# <line x1="530.74" y1="291.98" x2="375.54" y2="327.41" stroke="#808080" stroke-width="1"/>
# <line x1="444.61" y1="630.02" x2="289.41" y2="594.59" stroke="#808080" stroke-width="1"/>
# <line x1="444.61" y1="630.02" x2="599.81" y2="594.59" stroke="#808080" stroke-width="1"/>
# <line x1="444.61" y1="630.02" x2="375.54" y2="486.59" stroke="#808080" stroke-width="1"/>
# <line x1="444.61" y1="630.02" x2="569.07" y2="729.27" stroke="#808080" stroke-width="1"/>
# <line x1="624.46" y1="486.59" x2="693.53" y2="630.02" stroke="#808080" stroke-width="1"/>
# <line x1="624.46" y1="486.59" x2="555.39" y2="630.02" stroke="#808080" stroke-width="1"/>
# <line x1="624.46" y1="486.59" x2="624.46" y2="327.41" stroke="#808080" stroke-width="1"/>
# <line x1="624.46" y1="486.59" x2="500.00" y2="387.34" stroke="#808080" stroke-width="1"/>
# <line x1="500.00" y1="642.66" x2="375.54" y2="543.41" stroke="#808080" stroke-width="1"/>
# <line x1="500.00" y1="642.66" x2="624.46" y2="543.41" stroke="#808080" stroke-width="1"/>
# <line x1="500.00" y1="642.66" x2="655.20" y2="678.08" stroke="#808080" stroke-width="1"/>
# <line x1="500.00" y1="642.66" x2="344.80" y2="678.08" stroke="#808080" stroke-width="1"/>
# <line x1="444.61" y1="399.98" x2="375.54" y2="543.41"

# %% [markdown]
# ...and so on...
#
# Again, these are just a few CPS lattices. There are many, *many* more.
