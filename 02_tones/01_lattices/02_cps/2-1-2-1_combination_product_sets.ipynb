# %% [markdown]
# ---
# jupyter: false
# ---
#
# # 02 | Tones | 04 | Combination Product Sets

# %%
import sympy as sp
from fractions import Fraction
import numpy as np

from klotho import plot, play
from klotho.topos.collections import CombinationSet as CS
from klotho.tonos import (
    CombinationProductSet, Hexany, Eikosany, Hebdomekontany, MasterSet,
    PitchCollection as PC, Chord, ChordSequence,
)
from klotho.tonos.systems.combination_product_sets import match_pattern
# Out:
# <script>
# if (!globalThis.__klothoSonic) {
#     globalThis.__klothoSonic = { instance: null, promise: null, loadedDefs: new Set() };
#     globalThis.__klothoSonic.promise = (async function() {
#         try {
#             var config = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
#             var mod = await import("https://unpkg.com/supersonic-scsynth@latest");
#             globalThis.SuperSonic = mod.SuperSonic;
#             var sonic = new mod.SuperSonic(config);
#             await sonic.init();
#             globalThis.__klothoSonic.instance = sonic;
#             return sonic;
#         } catch(e) {
#             console.warn("[Klotho] SuperSonic session boot failed:", e);
#             globalThis.__klothoSonic.promise = null;
#             return null;
#         }
#     })();
# }
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (!state) {
#             state = { instance: null, promise: null, loadedDefs: new Set() };
#             globalThis.__klothoSonic = state;
#         }
#         if (state.instance) return Promise.resolve(state.instance);
#         if (state.promise) return state.promise;
#         return Promise.resolve(null);
#     };
# }
# (function() {
#   if (globalThis.DrawScheduler) return;
#   globalThis.DrawScheduler = class {
#     constructor() {
#       this._queue = [];
#       this._running = false;
#     }
#
#     schedule(callback, timeMs) {
#       var lo = 0, hi = this._queue.length;
#       while (lo < hi) {
#         var mid = (lo + hi) >>> 1;
#         if (this._queue[mid].time <= timeMs) lo = mid + 1;
#         else hi = mid;
#       }
#       this._queue.splice(lo, 0, { time: timeMs, callback: callback });
#       if (!this._running) this._startLoop();
#     }
#
#     _startLoop() {
#       this._running = true;
#       var self = this;
#       function tick() {
#         if (!self._running) return;
#         var now = performance.now();
#         while (self._queue.length && self._queue[0].time <= now) {
#           var item = self._queue.shift();
#           try { item.callback(); } catch(e) {}
#         }
#         if (self._queue.length || self._running) {
#           requestAnimationFrame(tick);
#         }
#       }
#       requestAnimationFrame(tick);
#     }
#
#     clear() {
#       this._queue = [];
#       this._running = false;
#     }
#   };
# })();
#
# (function() {
#   if (globalThis.BrowserScheduler) return;
#
#   var MAX_EVENTS_PER_BATCH = 500;
#   var BATCH_OVERLAP_RATIO = 0.8;
#   var NTP_EPOCH_OFFSET = 2208988800;
#   var STARTUP_DELAY = 0.1;
#   var DEFAULT_RING_TIME = 5;
#   var FIRST_PRIVATE_BUS = 16;
#   var BUS_CHANNELS = 2;
#
#   function getNTP() {
#     return (performance.timeOrigin + performance.now()) / 1000 + NTP_EPOCH_OFFSET;
#   }
#
#   globalThis.BrowserScheduler = class {
#     constructor(config) {
#       this.sonic = config.sonic;
#       this.manifest = config.manifest || { synths: {}, inserts: {} };
#       this.ringTime = (config.ringTime != null) ? config.ringTime : DEFAULT_RING_TIME;
#
#       this.isPlaying = false;
#       this.stopToken = 0;
#       this.nodeMap = new Map();
#       this._defNames = new Map();
#
#       this._scoreGroupId = null;
#       this._groupId = null;
#       this._trackMap = null;
#       this._controlGroupId = null;
#       this._controlBusMap = [];
#       this._nextAudioBus = FIRST_PRIVATE_BUS;
#       this._nextControlBus = 0;
#       this._activeBuffers = [];
#
#       this._playStartNTP = 0;
#       this._playStartPerfMs = 0;
#       this._batchTimeoutId = null;
#       this._finishTimeoutId = null;
#       this._deferredRings = [];
#
#       this.drawScheduler = new DrawScheduler();
#       this.onEvent = null;
#       this.onFinish = null;
#     }
#
#     _createGroup() {
#       var gid = this.sonic.nextNodeId();
#       this.sonic.send('/g_new', gid, 0, 0);
#       this._groupId = gid;
#     }
#
#     _freeGroup() {
#       if (this._groupId == null) return;
#       try { this.sonic.send('/g_freeAll', this._groupId); } catch(e) {}
#       try { this.sonic.send('/n_free', this._groupId); } catch(e) {}
#       this._groupId = null;
#     }
#
#     _freeGroupDeferred(groupId) {
#       var sonic = this.sonic;
#       var ringMs = this.ringTime * 1000;
#       var bufs = this._activeBuffers.slice();
#       var tid = setTimeout(function() {
#         try { sonic.send('/g_freeAll', groupId); } catch(e) {}
#         try { sonic.send('/n_free', groupId); } catch(e) {}
#         for (var i = 0; i < bufs.length; i++) {
#           try { sonic.send('/b_free', bufs[i]); } catch(e) {}
#         }
#       }, ringMs);
#       this._deferredRings.push({ tid: tid, gid: groupId });
#       this._activeBuffers = [];
#     }
#
#     _freeBuffers() {
#       for (var i = 0; i < this._activeBuffers.length; i++) {
#         try { this.sonic.send('/b_free', this._activeBuffers[i]); } catch(e) {}
#       }
#       this._activeBuffers = [];
#     }
#
#     _cancelAllDeferredRings() {
#       for (var i = 0; i < this._deferredRings.length; i++) {
#         clearTimeout(this._deferredRings[i].tid);
#         var gid = this._deferredRings[i].gid;
#         try { this.sonic.send('/g_freeAll', gid); } catch(e) {}
#         try { this.sonic.send('/n_free', gid); } catch(e) {}
#       }
#       this._deferredRings = [];
#     }
#
#     _getByPath(obj, path) {
#       if (!obj || !path) return undefined;
#       var parts = path.split('.');
#       var cur = obj;
#       for (var i = 0; i < parts.length; i++) {
#         var key = parts[i];
#         if (cur == null || typeof cur !== 'object' || !(key in cur)) return undefined;
#         cur = cur[key];
#       }
#       return cur;
#     }
#
#     _resolveDefPfields(defName, pfields) {
#       var out = {};
#       for (var key in pfields) {
#         if (!pfields.hasOwnProperty(key)) continue;
#         var val = pfields[key];
#         if (val === null || val === undefined) continue;
#         if (typeof val === 'object') continue;
#         out[key] = val;
#       }
#       var meta = (this.manifest.synths || {})[defName] || {};
#       var paths = meta.paths || {};
#       for (var srcPath in paths) {
#         if (!paths.hasOwnProperty(srcPath)) continue;
#         var dstKey = paths[srcPath];
#         var mapped = this._getByPath(pfields, srcPath);
#         if (mapped === undefined || mapped === null) continue;
#         if (typeof mapped === 'object') continue;
#         out[dstKey] = mapped;
#       }
#       return out;
#     }
#
#     _resolveDefName(name) {
#       if (name === "__rest__") return "__rest__";
#       if (!name || name === "sonic-pi-beep") return "kl_tri";
#       return name;
#     }
#
#     _bundleNew(ev, ntp) {
#       if (ev.defName === "__rest__") return;
#       var defName = this._resolveDefName(ev.defName);
#       var nodeId = this.sonic.nextNodeId();
#
#       var target;
#       var pf = this._resolveDefPfields(defName, ev.pfields || {});
#
#       if (this._trackMap) {
#         var group = ev.group || "default";
#         var trackInfo = this._trackMap[group] || this._trackMap["default"] || this._trackMap["main"];
#         target = trackInfo ? trackInfo.srcGroup : (this._scoreGroupId || this._groupId || 0);
#         if (trackInfo) {
#           pf.out = trackInfo.srcBus;
#         }
#       } else {
#         target = this._groupId != null ? this._groupId : 0;
#       }
#
#       var args = [defName, nodeId, 0, target];
#       for (var key in pf) {
#         if (!pf.hasOwnProperty(key)) continue;
#         var v = pf[key];
#         if (v === undefined || v === null || typeof v === 'object') continue;
#         args.push(key, v);
#       }
#       var bundle = globalThis.SuperSonic.osc.encodeSingleBundle(ntp, '/s_new', args);
#       this.sonic.sendOSC(bundle);
#       this.nodeMap.set(ev.id, nodeId);
#       this._defNames.set(ev.id, defName);
#
#       if (typeof this._getControlMappingsForEvent === 'function') {
#         var mappings = this._getControlMappingsForEvent(ev.id);
#         if (mappings) {
#           for (var mi = 0; mi < mappings.length;

# %%
def chord_from_shape(cps, shape, root='C4'):
    ratios = sorted(cps.graph[n]['ratio'] for n in shape)
    return Chord(ratios).root(root)

def chords_from_matches(cps, matches, root='C4'):
    return ChordSequence([chord_from_shape(cps, m, root) for m in matches])

# %% [markdown]
# # Combination Product Sets

# %% [markdown]
# ***Combination Product Sets*** (**CPS**) are a special type of lattice structure created by Erv Wilson.
#
# So far, all the lattices we've looked at had a tonal center—meaning, there is an origin where the ratio is `1` and all other points represent successive multiplications.
#
# **CPS** lattices are different in that there is no tonal center—i.e., there is no origin. Which is to say, there is no hierarchy. There is no "gravity".

# %% [markdown]
# ### Deriving CPS
#
# Ok, here's the deal: there's really no easy way to explain this without being a little confusing so I'm just going go through it step-by-step and (hopefully) it'll all make sense in the end.
#
# Don't worry, just follow along...

# %% [markdown]
# #### 1. Initial Set
#
# Imagine we have a collection of *`n`*-elements:
#
# $$\{A\ B\ C\ D\}$$
#
# In this case, `4` elements. These letters don't represent note names, they're just algebraic variables—they could have been emojis instead of letters, it really doesn't matter.

# %% [markdown]
# #### 2. Arrange the Elements Spatially
#
# Arrange each element so that we form a ***complete graph***. A *complete graph* means a graph where every node is connected to every other node.

# %%
plot(MasterSet.tetrad(), figsize=(7,7))
# Out:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><text x="350.0" y="18" text-anchor="middle" font-family="Arial" font-size="14" fill="white">MasterSet: tetrad</text>
# <line x1="350.00" y1="427.72" x2="80.77" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <line x1="350.00" y1="427.72" x2="350.00" y2="116.84" stroke="#808080" stroke-width="1.5"/>
# <line x1="350.00" y1="427.72" x2="619.23" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <line x1="80.77" y1="583.16" x2="350.00" y2="116.84" stroke="#808080" stroke-width="1.5"/>
# <line x1="350.00" y1="116.84" x2="619.23" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <line x1="619.23" y1="583.16" x2="80.77" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <circle cx="80.77" cy="583.16" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgms_85f126ab"/>
# <text x="80.77" y="584.16" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">A</text>
# <circle cx="350.00" cy="116.84" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgms_85f126ab"/>
# <text x="350.00" y="117.84" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">B</text>
# <circle cx="619.23" cy="583.16" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgms_85f126ab"/>
# <text x="619.23" y="584.16" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">C</text>
# <circle cx="350.00" cy="427.72" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgms_85f126ab"/>
# <text x="350.00" y="428.72" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">D</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
#     }
#
#     function reorderEventsFrom(allEvents, startGi, total, gap) {
#       var gapSec = typeof gap === "number" ? Math.max(0, gap) : _pause;
#       var buckets = [];
#       for (var g = 0; g < total; g++) buckets.push([]);
#       for (var i = 0; i < allEvents.length; i++) {
#         var si = allEvents[i]._stepIndex;
#         if (si >= 0 && si < total) buckets[si].push(allEvents[i]);
#       }
#       var groupStarts = [];
#       for (var g1 = 0; g1 < total; g1++) {
#         var mn = Infinity;
#         for (var i1 = 0; i1 < buckets[g1].length; i1++) {
#           if (buckets[g1][i1].start < mn) mn = buckets[g1][i1].start;
#         }
#         groupStarts.push(mn === Infinity ? 0 : mn);
#       }
#       var groupDurs = [];
#       for (var g2 = 0; g2 < total; g2++) {
#         var mx = 0;
#         for (var i2 = 0; i2 < buckets[g2].length; i2++) {
#           var end = eventEnd(buckets[g2][i2]);
#           if (end > mx) mx = end;
#         }
#         groupDurs.push(mx - groupStarts[g2]);
#       }
#       var result = [];
#       var cursor = 0;
#       var seqMap = [];
#       for (var step = 0; step < total; step++) {
#         var gi = (startGi + step) % total;
#         seqMap.push(gi);
#         var base = groupStarts[gi];
#         for (var i3 = 0; i3 < buckets[gi].length; i3++) {
#           var e2 = {};
#           for (var k2 in buckets[gi][i3]) e2[k2] = buckets[gi][i3][k2];
#           e2.start = cursor + (buckets[gi][i3].start - base);
#           e2._stepIndex = step;
#           result.push(e2);
#         }
#         cursor += groupDurs[gi] + gapSec;
#       }
#       return { events: result, seqMap: seqMap };
#     }
#
#     function isPlaying() {
#       if (engine === "supersonic") return !!(_ssScheduler && _ssScheduler.isPlaying);
#       return !!(_aPlayer && _aPlayer.isPlaying());
#     }
#
#     async function stop() {
#       if (engine === "supersonic") {
#         if (_ssScheduler && _ssScheduler.isPlaying) await _ssScheduler.stop();
#         return;
#       }
#       if (_aPlayer && _aPlayer.isPlaying()) _aPlayer.stop();
#     }
#
#     async function resumeAudio() {
#       if (engine === "supersonic") {
#         if (_ssSonic && _ssSonic.audioContext && _ssSonic.audioContext.state === "suspended") {
#           await _ssSonic.audioContext.resume();
#         }
#         return;
#       }
#       if (typeof Tone !== "undefined" && Tone.context && Tone.context.state === "suspended") {
#         try { await Tone.start(); } catch(_) {}
#         try { await Tone.context.resume(); } catch(_) {}
#       }
#     }
#
#     async function play(ev

# %% [markdown]
# Ok, this geometric form is what we're calling our ***generating tetrad***. Put it aside for now, we're going to use it later...

# %% [markdown]
# #### 3. Compute *`k`*-wise Groupings

# %% [markdown]
# We started with `4` elements ($\{A\ B\ C\ D\}$), let's find every possible pairing, or `2`-wise grouping of elements:

# %%
elems = ('A', 'B', 'C', 'D')

for combo in CS(elems, 2).combos:
  print(*combo, end='\n\n')
# Out:
# A D
#
# C D
#
# A C
#
# B D
#
# B C
#
# A B

# %% [markdown]
# #### 4. Review Basic Algebra

# %% [markdown]
# That's right, let's review our algebra...

# %%
A, B, C, D = sp.symbols('A B C D', nonzero=True)

e1 = A*B
e2 = A*C
print(f'({e1}) / ({e2}) = {sp.simplify(e1 / e2)}', end='\n\n')

e1 = B*C
e2 = A*C
print(f'({e1}) / ({e2}) = {sp.simplify(e1 / e2)}', end='\n\n')

e1 = B*D
e2 = A*B
print(f'({e1}) / ({e2}) = {sp.simplify(e1 / e2)}', end='\n\n')

print('etc...')
# Out:
# (A*B) / (A*C) = B/C
#
# (B*C) / (A*C) = B/A
#
# (B*D) / (A*B) = D/A
#
# etc...

# %% [markdown]
# Is it all coming back? Ok, good...

# %% [markdown]
# #### 5. Review Basic Geometry
#
# Let's look again at our generating tetrad:

# %%
plot(MasterSet.tetrad(), figsize=(7,7))
# Out:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><text x="350.0" y="18" text-anchor="middle" font-family="Arial" font-size="14" fill="white">MasterSet: tetrad</text>
# <line x1="350.00" y1="427.72" x2="80.77" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <line x1="350.00" y1="427.72" x2="350.00" y2="116.84" stroke="#808080" stroke-width="1.5"/>
# <line x1="350.00" y1="427.72" x2="619.23" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <line x1="80.77" y1="583.16" x2="350.00" y2="116.84" stroke="#808080" stroke-width="1.5"/>
# <line x1="350.00" y1="116.84" x2="619.23" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <line x1="619.23" y1="583.16" x2="80.77" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <circle cx="80.77" cy="583.16" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgms_9862ad08"/>
# <text x="80.77" y="584.16" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">A</text>
# <circle cx="350.00" cy="116.84" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgms_9862ad08"/>
# <text x="350.00" y="117.84" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">B</text>
# <circle cx="619.23" cy="583.16" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgms_9862ad08"/>
# <text x="619.23" y="584.16" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">C</text>
# <circle cx="350.00" cy="427.72" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgms_9862ad08"/>
# <text x="350.00" y="428.72" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">D</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
#     }
#
#     function reorderEventsFrom(allEvents, startGi, total, gap) {
#       var gapSec = typeof gap === "number" ? Math.max(0, gap) : _pause;
#       var buckets = [];
#       for (var g = 0; g < total; g++) buckets.push([]);
#       for (var i = 0; i < allEvents.length; i++) {
#         var si = allEvents[i]._stepIndex;
#         if (si >= 0 && si < total) buckets[si].push(allEvents[i]);
#       }
#       var groupStarts = [];
#       for (var g1 = 0; g1 < total; g1++) {
#         var mn = Infinity;
#         for (var i1 = 0; i1 < buckets[g1].length; i1++) {
#           if (buckets[g1][i1].start < mn) mn = buckets[g1][i1].start;
#         }
#         groupStarts.push(mn === Infinity ? 0 : mn);
#       }
#       var groupDurs = [];
#       for (var g2 = 0; g2 < total; g2++) {
#         var mx = 0;
#         for (var i2 = 0; i2 < buckets[g2].length; i2++) {
#           var end = eventEnd(buckets[g2][i2]);
#           if (end > mx) mx = end;
#         }
#         groupDurs.push(mx - groupStarts[g2]);
#       }
#       var result = [];
#       var cursor = 0;
#       var seqMap = [];
#       for (var step = 0; step < total; step++) {
#         var gi = (startGi + step) % total;
#         seqMap.push(gi);
#         var base = groupStarts[gi];
#         for (var i3 = 0; i3 < buckets[gi].length; i3++) {
#           var e2 = {};
#           for (var k2 in buckets[gi][i3]) e2[k2] = buckets[gi][i3][k2];
#           e2.start = cursor + (buckets[gi][i3].start - base);
#           e2._stepIndex = step;
#           result.push(e2);
#         }
#         cursor += groupDurs[gi] + gapSec;
#       }
#       return { events: result, seqMap: seqMap };
#     }
#
#     function isPlaying() {
#       if (engine === "supersonic") return !!(_ssScheduler && _ssScheduler.isPlaying);
#       return !!(_aPlayer && _aPlayer.isPlaying());
#     }
#
#     async function stop() {
#       if (engine === "supersonic") {
#         if (_ssScheduler && _ssScheduler.isPlaying) await _ssScheduler.stop();
#         return;
#       }
#       if (_aPlayer && _aPlayer.isPlaying()) _aPlayer.stop();
#     }
#
#     async function resumeAudio() {
#       if (engine === "supersonic") {
#         if (_ssSonic && _ssSonic.audioContext && _ssSonic.audioContext.state === "suspended") {
#           await _ssSonic.audioContext.resume();
#         }
#         return;
#       }
#       if (typeof Tone !== "undefined" && Tone.context && Tone.context.state === "suspended") {
#         try { await Tone.start(); } catch(_) {}
#         try { await Tone.context.resume(); } catch(_) {}
#       }
#     }
#
#     async function play(ev

# %% [markdown]
# We're going to take the angle formed by each pair of adjacent nodes and assign them to the ratios of `node1 / node2` and `node2 / node1`.
#
# What do I mean by this? E.g., take nodes `A` and `B`. The edge between them forms a horizontal line. So, we're going to say that the ratio of `A/B` or `B/A` means an angle of either `0` or `180` degrees.
#
# Look at nodes `C` and `D`. The angle formed by the edge between them is a vertical line. So, we're going to say that the ratio of `C/D` or `D/C` means an angle of either `90` or `270` degrees.
#
# And so on for each pair of adjacent nodes...

# %% [markdown]
# #### 6. Map Ratios to Groups
#
# Find the ratio between each pairing of *`k`*-wise groupings.
#
# If the ratio is an edge-group found in the set of *`k`*-wise groupings, keep it.

# %%
cs = CS(elems, 2)
for combo1 in cs.combos:
  for combo2 in cs.combos:
    if combo1 != combo2:
      e1 = sp.sympify(f'{combo1[0]}/{combo1[1]}')
      e2 = sp.sympify(f'{combo2[0]}/{combo2[1]}')
      simp = sp.simplify(e1 / e2)
      if tuple(str(simp).split('/')) in cs.combos:
        print(f'({e1}) / ({e2}) = {simp}', end='\n\n')
# Out:
# (A/D) / (C/D) = A/C
#
# (A/D) / (A/C) = C/D
#
# (A/D) / (B/D) = A/B
#
# (A/D) / (A/B) = B/D
#
# (A/C) / (B/C) = A/B
#
# (A/C) / (A/B) = B/C
#
# (B/D) / (C/D) = B/C
#
# (B/D) / (B/C) = C/D

# %% [markdown]
# #### 7. Make the Graph
#
# Compare the resultant ratio to the edges in the generating tetrad to determine the angle of the line between them:

# %%
print("GENERATING TETRAD")
plot(MasterSet.tetrad(), figsize=(7,7))

print("\nCPS")
plot(Hexany(), figsize=(7,7))
# Out:
# GENERATING TETRAD
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><text x="350.0" y="18" text-anchor="middle" font-family="Arial" font-size="14" fill="white">MasterSet: tetrad</text>
# <line x1="350.00" y1="427.72" x2="80.77" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <line x1="350.00" y1="427.72" x2="350.00" y2="116.84" stroke="#808080" stroke-width="1.5"/>
# <line x1="350.00" y1="427.72" x2="619.23" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <line x1="80.77" y1="583.16" x2="350.00" y2="116.84" stroke="#808080" stroke-width="1.5"/>
# <line x1="350.00" y1="116.84" x2="619.23" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <line x1="619.23" y1="583.16" x2="80.77" y2="583.16" stroke="#808080" stroke-width="1.5"/>
# <circle cx="80.77" cy="583.16" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgms_a9a02b22"/>
# <text x="80.77" y="584.16" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">A</text>
# <circle cx="350.00" cy="116.84" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgms_a9a02b22"/>
# <text x="350.00" y="117.84" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">B</text>
# <circle cx="619.23" cy="583.16" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgms_a9a02b22"/>
# <text x="619.23" y="584.16" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">C</text>
# <circle cx="350.00" cy="427.72" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgms_a9a02b22"/>
# <text x="350.00" y="428.72" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">D</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
#     }
#
#     function reorderEventsFrom(allEvents, startGi, total, gap) {
#       var gapSec = typeof gap === "number" ? Math.max(0, gap) : _pause;
#       var buckets = [];
#       for (var g = 0; g < total; g++) buckets.push([]);
#       for (var i = 0; i < allEvents.length; i++) {
#         var si = allEvents[i]._stepIndex;
#         if (si >= 0 && si < total) buckets[si].push(allEvents[i]);
#       }
#       var groupStarts = [];
#       for (var g1 = 0; g1 < total; g1++) {
#         var mn = Infinity;
#         for (var i1 = 0; i1 < buckets[g1].length; i1++) {
#           if (buckets[g1][i1].start < mn) mn = buckets[g1][i1].start;
#         }
#         groupStarts.push(mn === Infinity ? 0 : mn);
#       }
#       var groupDurs = [];
#       for (var g2 = 0; g2 < total; g2++) {
#         var mx = 0;
#         for (var i2 = 0; i2 < buckets[g2].length; i2++) {
#           var end = eventEnd(buckets[g2][i2]);
#           if (end > mx) mx = end;
#         }
#         groupDurs.push(mx - groupStarts[g2]);
#       }
#       var result = [];
#       var cursor = 0;
#       var seqMap = [];
#       for (var step = 0; step < total; step++) {
#         var gi = (startGi + step) % total;
#         seqMap.push(gi);
#         var base = groupStarts[gi];
#         for (var i3 = 0; i3 < buckets[gi].length; i3++) {
#           var e2 = {};
#           for (var k2 in buckets[gi][i3]) e2[k2] = buckets[gi][i3][k2];
#           e2.start = cursor + (buckets[gi][i3].start - base);
#           e2._stepIndex = step;
#           result.push(e2);
#         }
#         cursor += groupDurs[gi] + gapSec;
#       }
#       return { events: result, seqMap: seqMap };
#     }
#
#     function isPlaying() {
#       if (engine === "supersonic") return !!(_ssScheduler && _ssScheduler.isPlaying);
#       return !!(_aPlayer && _aPlayer.isPlaying());
#     }
#
#     async function stop() {
#       if (engine === "supersonic") {
#         if (_ssScheduler && _ssScheduler.isPlaying) await _ssScheduler.stop();
#         return;
#       }
#       if (_aPlayer && _aPlayer.isPlaying()) _aPlayer.stop();
#     }
#
#     async function resumeAudio() {
#       if (engine === "supersonic") {
#         if (_ssSonic && _ssSonic.audioContext && _ssSonic.audioContext.state === "suspended") {
#           await _ssSonic.audioContext.resume();
#         }
#         return;
#       }
#       if (typeof Tone !== "undefined" && Tone.context && Tone.context.state === "suspended") {
#         try { await Tone.start(); } catch(_) {}
#         try { await Tone.context.resume(); } catch(_) {}
#       }
#     }
#
#     async function play(ev
# CPS
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><rect width="700" height="700" fill="black"/>
# <text x="350.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D]</text>
# <line x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <circle id="svgcps_acc737bf_nd1" cx="140.16" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_acc737bf"/>
# <text x="140.16" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AB</text>
# <circle id="svgcps_acc737bf_nd2" cx="350.00" cy="607.31" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_acc737bf"/>
# <text x="350.00" y="607.31" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AC</text>
# <circle id="svgcps_acc737bf_nd3" cx="140.16" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_acc737bf"/>
# <text x="140.16" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AD</text>
# <circle id="svgcps_acc737bf_nd4" cx="559.84" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgcps_acc737bf"/>
# <text x="559.84" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BC</text>
# <circle id="svgcps_acc737bf_nd5" cx="350.00" cy="122.69" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgcps_acc737bf"/>
# <text x="350.00" y="122.69" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BD</text>
# <circle id="svgcps_acc737bf_nd6" cx="559.84" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgcps_acc737bf"/>
# <text x="559.84" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">CD</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;

# %% [markdown]
# Ok, whew...
#
# I know, it's a bit confusing, but take a look at the result.
#
# Look at each node in the CPS (here, each node represents a *`k`*-wise grouping—pairs in our case) and notice the angle of the line between them.
#
# E.g., the edge between `AD` and `BD` is a horizontal line. Why?
#
# $AD / BD = A/B$
#
# Look at the generating tetrad. The angle between nodes `A` and `B`. It's a horizontal line.
#
# Look back at the CPS graph. Take a look at nodes `CD` and `BD` and take note of the angle of the edge between them. It's the same angle as between `C` and `B` in the generating tetrad. Because $CD / BD = C/B$.
#
# And so on...

# %% [markdown]
# ## Hexany
#
# The above CPS is the simplest, known as the ***Hexany***.
#
# So, what do these letters actually mean? Each element in the initial set represents an integer that we will use as a harmonic multiple of some fundamental frequency. So, let's say:
#
# `A = 1`
#
# `B = 3`
#
# `C = 5`
#
# `D = 7`
#
# They don't have to be these numbers, but let's go with these.
#
# Each ***combination*** of elements is called a ***product***. Why? Because:
#
# `AB = 1 * 3 = 3`
#
# `BC = 3 * 5 = 15`
#
# `CD = 5 * 7 = 35`
#
# etc...
#
# which results in a set of *ratios*—the tone world of this particular Hexany.

# %%
hx = Hexany()
print('Ratios: ', *[str(r) for r in hx.ratios])
plot(hx, figsize=(7,7))
pc = PC.from_degrees(list(hx.ratios), equave='2/1')
# idx = list(range(-len(hx.ratios)*2 + len(hx.ratios), len(hx.ratios)*2 + len(hx.ratios)))
idx = list(range(-len(hx.ratios)*2, len(hx.ratios)*2))
play(pc.root('C4')[idx + idx[-2::-1]], dur=0.2)
# Out:
# Ratios:  35/32 5/4 21/16 3/2 7/4 15/8
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><rect width="700" height="700" fill="black"/>
# <text x="350.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D]</text>
# <line x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <circle id="svgcps_231c9d7a_nd1" cx="140.16" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_231c9d7a"/>
# <text x="140.16" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AB</text>
# <circle id="svgcps_231c9d7a_nd2" cx="350.00" cy="607.31" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_231c9d7a"/>
# <text x="350.00" y="607.31" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AC</text>
# <circle id="svgcps_231c9d7a_nd3" cx="140.16" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_231c9d7a"/>
# <text x="140.16" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AD</text>
# <circle id="svgcps_231c9d7a_nd4" cx="559.84" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgcps_231c9d7a"/>
# <text x="559.84" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BC</text>
# <circle id="svgcps_231c9d7a_nd5" cx="350.00" cy="122.69" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgcps_231c9d7a"/>
# <text x="350.00" y="122.69" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BD</text>
# <circle id="svgcps_231c9d7a_nd6" cx="559.84" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgcps_231c9d7a"/>
# <text x="559.84" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">CD</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
# <div id="klotho_ss_e61b18f4" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 6px 10px;
#     background: #1a1a2e;
#     border-radius: 6px;
#     user-select: none;
# ">
#     <button id="klotho_ss_e61b18f4_toggle" style="
#         width: 32px;
#         height: 32px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#     ">
#         <span id="klotho_ss_e61b18f4_icon" style="
#             width: 0;
#             height: 0;
#             border-top: 7px solid transparent;
#             border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80;
#             margin-left: 3px;
#         "></span>
#     </button>
#     <button id="klotho_ss_e61b18f4_loop" style="
#         width: 28px;
#         height: 28px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#         opacity: 0.5;
#     ">
#         <svg id="klotho_ss_e61b18f4_loop_svg" width="16" height="16" viewBox="0 0 24 24" fill="none" stroke="#a0a0a0" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path>
#             <path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path>
#             <path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
#     <span id="klotho_ss_e61b18f4_status" style="
#         color: #666;
#         font-size: 10px;
#         min-width: 60px;
#     ">ready</span>
# </div>
#
# <script>
#
# // SuperSonic standalone playback widget.
# // Python replaces: klotho_ss_e61b18f4, [{"type": "new", "id": "56056d01472b4f4d9028f47871cc5252", "defName": "kl_tri", "start": 0, "pfields": {"freq": 71.5382, "amp": 0.32465768312924875}, "_stepIndex": 0}, {"type": "release", "id": "56056d01472b4f4d9028f47871cc5252", "start": 0.2, "_stepIndex": 0}, {"type": "new", "id": "822d669af91345f2be897388eb48c0d8", "defName": "kl_tri", "start": 0.2, "pfields": {"freq": 81.758, "amp": 0.33433332784005887}, "_stepIndex": 1}, {"type": "release", "id": "822d669af91345f2be897388eb48c0d8", "start": 0.4, "_stepIndex": 1}, {"type": "new", "id": "a19c33d910a74241ae653bb936d17464", "defName": "kl_tri", "start": 0.4, "pfields": {"freq": 85.8459, "amp": 0.33797075387458925}, "_stepIndex": 2}, {"type": "release", "id": "a19c33d910a74241ae653bb936d17464", "start": 0.6000000000000001, "_stepIndex": 2}, {"type": "new", "id": "9ddaebefd901461dbe5fbcd797e96b1e", "defName": "kl_tri", "start": 0.6000000000000001, "pfields": {"freq": 98.1096, "amp": 0.34842026788607267}, "_stepIndex": 3}, {"type": "release", "id": "9ddaebefd901461dbe5fbcd797e96b1e", "start": 0.8, "_stepIndex": 3}, {"type": "new", "id": "dd1663a9241b4f8890199bafc0de03b4", "defName": "kl_tri", "start": 0.8, "pfields": {"freq": 114.4612, "amp": 0.3620248787580148}, "_stepIndex": 4}, {"type": "release", "id": "dd1663a9241b4f8890199bafc0de03b4", "start": 1.0, "_stepIndex": 4}, {"type": "new", "id": "f1fbbc6b2b3948bbacaab6dcc3f55200", "defName": "kl_tri", "start": 1.0, "pfields": {"freq": 122.637, "amp": 0.3687474438592235}, "_stepIndex": 5}, {"type": "release", "id": "f1fbbc6b2b3948bbacaab6dcc3f55200", "start": 1.2, "_stepIndex": 5}, {"type": "new", "id": "0dbb29fa9a874eb680a05511550b82a6", "defName": "kl_tri", "start": 1.2, "pfields": {"freq": 143.0765, "amp": 0.3851372505985531}, "_stepIndex": 6}, {"type": "release", "id": "0dbb29fa9a874eb680a05511550b82a6", "start": 1.4, "_stepIndex": 6}, {"type": "new", "id": "385343e0b0524f4fb6a3c82f77321b3d", "defName": "kl_tri", "start": 1.4, "pfields": {"freq": 163.516, "amp": 0.4006440314150796}, "_stepIndex": 7}, {"type": "release", "id": "385343e0b0524f4fb6a3c82f77321b3d", "start": 1.5999999999999999, "_stepIndex": 7}, {"type": "new", "id": "979a1ce3e266448aa0a5ea31819f54af", "defName": "kl_tri", "start": 1.5999999999999999, "pfields": {"freq": 171.6918, "amp": 0.40651889163039745}, "_stepIndex": 8}, {"type": "release", "id": "979a1ce3e266448aa0a5ea31819f54af", "start": 1.7999999999999998, "_stepIndex": 8}, {"type": "new", "id": "4496333cd41b4125a0d80982a104c03a", "defName": "kl_tri", "start": 1.7999999999999998, "pfields": {"freq": 196.2192, "amp": 0.4227200184411173}, "_stepIndex": 9}, {"type": "release", "id": "4496333cd41b4125a0d80982a104c03a", "start": 1.9999999999999998, "_stepIndex": 9}, {"type": "new", "id": "a96b9589fe8044a1831e036f37cce6c2", "defName": "kl_tri", "start": 1.9999999999999998, "pfields": {"freq": 228.9224, "amp": 0.44037718222926503}, "_stepIndex": 10}, {"type": "release", "id": "a96b9589fe8044a1831e036f37cce6c2", "start": 2.1999999999999997, "_stepIndex": 10}, {"type": "new", "id": "c7c2c6209bec41a8a2784917b542f4cd", "defName": "kl_tri", "start": 2.1999999999999997, "pfields": {"freq": 245.274, "amp": 0.4475524738657926}, "_stepIndex": 11}, {"type": "release", "id": "c7c2c6209bec41a8a2784917b542f4cd", "start": 2.4, "_stepIndex": 11}, {"type": "new", "id": "8910ad86758a473a847e7159da6b4837", "defName": "kl_tri", "start": 2.4, "pfields": {"freq": 286.153, "amp": 0.46124976648817834}, "_stepIndex": 12}, {"type": "release", "id": "8910ad86758a473a847e7159da6b4837", "start": 2.6, "_stepIndex": 12}, {"type": "new", "id": "f0893dd323ca4f56b986634d71ccf0cc", "defName": "kl_tri", "start": 2.6, "pfields": {"freq": 327.032, "amp": 0.4697954849148101}, "_stepIndex": 13}, {"type": "release", "id": "f0893dd323ca4f56b986634d71ccf0cc", "start": 2.8000000000000003, "_stepIndex": 13}, {"type": "new", "id": "b47451be4d8f49b6a241fb03dae52b72", "defName": "kl_tri", "start": 2.8000000000000003, " ...

# %% [markdown]
# Now, recall that those letters in the initial set are just variables; we can change their values and get a structure with different intervals.
#
# Let's try that:

# %%
hx2 = Hexany((1, 5, 13, 31))
print('Ratios: ', *[str(r) for r in hx2.ratios])
plot(hx2, figsize=(7,7))
pc = PC.from_degrees(list(hx2.ratios), equave='2/1')
idx = list(range(-len(hx2.ratios)*2, len(hx2.ratios)*2))
play(pc.root('C4')[idx + idx[-2::-1]], dur=0.2)
# Out:
# Ratios:  65/64 155/128 5/4 403/256 13/8 31/16
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><rect width="700" height="700" fill="black"/>
# <text x="350.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D]</text>
# <line x1="350.00" y1="122.69" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <circle id="svgcps_f3f2b521_nd1" cx="140.16" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_f3f2b521"/>
# <text x="140.16" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AB</text>
# <circle id="svgcps_f3f2b521_nd2" cx="350.00" cy="607.31" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_f3f2b521"/>
# <text x="350.00" y="607.31" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AC</text>
# <circle id="svgcps_f3f2b521_nd3" cx="140.16" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_f3f2b521"/>
# <text x="140.16" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AD</text>
# <circle id="svgcps_f3f2b521_nd4" cx="559.84" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgcps_f3f2b521"/>
# <text x="559.84" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BC</text>
# <circle id="svgcps_f3f2b521_nd5" cx="350.00" cy="122.69" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgcps_f3f2b521"/>
# <text x="350.00" y="122.69" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BD</text>
# <circle id="svgcps_f3f2b521_nd6" cx="559.84" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgcps_f3f2b521"/>
# <text x="559.84" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">CD</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
# <div id="klotho_ss_83bd8a40" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 6px 10px;
#     background: #1a1a2e;
#     border-radius: 6px;
#     user-select: none;
# ">
#     <button id="klotho_ss_83bd8a40_toggle" style="
#         width: 32px;
#         height: 32px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#     ">
#         <span id="klotho_ss_83bd8a40_icon" style="
#             width: 0;
#             height: 0;
#             border-top: 7px solid transparent;
#             border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80;
#             margin-left: 3px;
#         "></span>
#     </button>
#     <button id="klotho_ss_83bd8a40_loop" style="
#         width: 28px;
#         height: 28px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#         opacity: 0.5;
#     ">
#         <svg id="klotho_ss_83bd8a40_loop_svg" width="16" height="16" viewBox="0 0 24 24" fill="none" stroke="#a0a0a0" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path>
#             <path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path>
#             <path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
#     <span id="klotho_ss_83bd8a40_status" style="
#         color: #666;
#         font-size: 10px;
#         min-width: 60px;
#     ">ready</span>
# </div>
#
# <script>
#
# // SuperSonic standalone playback widget.
# // Python replaces: klotho_ss_83bd8a40, [{"type": "new", "id": "3aa347d865524e9bbc86ff3f0fa41f0b", "defName": "kl_tri", "start": 0, "pfields": {"freq": 66.4284, "amp": 0.3194124043530338}, "_stepIndex": 0}, {"type": "release", "id": "3aa347d865524e9bbc86ff3f0fa41f0b", "start": 0.2, "_stepIndex": 0}, {"type": "new", "id": "b7998759d13c400a82c02c9708e20d23", "defName": "kl_tri", "start": 0.2, "pfields": {"freq": 79.2031, "amp": 0.3320006038063629}, "_stepIndex": 1}, {"type": "release", "id": "b7998759d13c400a82c02c9708e20d23", "start": 0.4, "_stepIndex": 1}, {"type": "new", "id": "aed4bc7c320e4d87a85630081b9d30a4", "defName": "kl_tri", "start": 0.4, "pfields": {"freq": 81.758, "amp": 0.33433332784005887}, "_stepIndex": 2}, {"type": "release", "id": "aed4bc7c320e4d87a85630081b9d30a4", "start": 0.6000000000000001, "_stepIndex": 2}, {"type": "new", "id": "4a372e3d01e346a3bc24d1311a350a81", "defName": "kl_tri", "start": 0.6000000000000001, "pfields": {"freq": 102.964, "amp": 0.35247390066678075}, "_stepIndex": 3}, {"type": "release", "id": "4a372e3d01e346a3bc24d1311a350a81", "start": 0.8, "_stepIndex": 3}, {"type": "new", "id": "b2b10d6005b647e283ff5294ee06b021", "defName": "kl_tri", "start": 0.8, "pfields": {"freq": 106.2854, "amp": 0.3552416343620657}, "_stepIndex": 4}, {"type": "release", "id": "b2b10d6005b647e283ff5294ee06b021", "start": 1.0, "_stepIndex": 4}, {"type": "new", "id": "eb2e46ad49a14fbb8664e6a6d9b45f6f", "defName": "kl_tri", "start": 1.0, "pfields": {"freq": 126.7249, "amp": 0.37207877481243334}, "_stepIndex": 5}, {"type": "release", "id": "eb2e46ad49a14fbb8664e6a6d9b45f6f", "start": 1.2, "_stepIndex": 5}, {"type": "new", "id": "c15866cb9d7842df86d97a9121750de0", "defName": "kl_tri", "start": 1.2, "pfields": {"freq": 132.8567, "amp": 0.37703019514576214}, "_stepIndex": 6}, {"type": "release", "id": "c15866cb9d7842df86d97a9121750de0", "start": 1.4, "_stepIndex": 6}, {"type": "new", "id": "71e258d33e4242188ff963d7d82a4493", "defName": "kl_tri", "start": 1.4, "pfields": {"freq": 158.4061, "amp": 0.39686978016413765}, "_stepIndex": 7}, {"type": "release", "id": "71e258d33e4242188ff963d7d82a4493", "start": 1.5999999999999999, "_stepIndex": 7}, {"type": "new", "id": "1eddfae868cb4dc5aeed29a8cd1e8355", "defName": "kl_tri", "start": 1.5999999999999999, "pfields": {"freq": 163.516, "amp": 0.4006440314150796}, "_stepIndex": 8}, {"type": "release", "id": "1eddfae868cb4dc5aeed29a8cd1e8355", "start": 1.7999999999999998, "_stepIndex": 8}, {"type": "new", "id": "025b67665eab46c080e35662ea35c30a", "defName": "kl_tri", "start": 1.7999999999999998, "pfields": {"freq": 205.928, "amp": 0.42844615064914254}, "_stepIndex": 9}, {"type": "release", "id": "025b67665eab46c080e35662ea35c30a", "start": 1.9999999999999998, "_stepIndex": 9}, {"type": "new", "id": "d1626267380240aa95935a20fa362162", "defName": "kl_tri", "start": 1.9999999999999998, "pfields": {"freq": 212.5708, "amp": 0.43212370490865454}, "_stepIndex": 10}, {"type": "release", "id": "d1626267380240aa95935a20fa362162", "start": 2.1999999999999997, "_stepIndex": 10}, {"type": "new", "id": "a915fafab2db431ba78d55dc56502337", "defName": "kl_tri", "start": 2.1999999999999997, "pfields": {"freq": 253.4498, "amp": 0.45075847271437913}, "_stepIndex": 11}, {"type": "release", "id": "a915fafab2db431ba78d55dc56502337", "start": 2.4, "_stepIndex": 11}, {"type": "new", "id": "b6d217a1d56f4e1f9a6f6ecb11c18fbb", "defName": "kl_tri", "start": 2.4, "pfields": {"freq": 265.7135, "amp": 0.4551159190197478}, "_stepIndex": 12}, {"type": "release", "id": "b6d217a1d56f4e1f9a6f6ecb11c18fbb", "start": 2.6, "_stepIndex": 12}, {"type": "new", "id": "872eeed7a67e401aa8ad5256afd6f136", "defName": "kl_tri", "start": 2.6, "pfields": {"freq": 316.8122, "amp": 0.46808001079316197}, "_stepIndex": 13}, {"type": "release", "id": "872eeed7a67e401aa8ad5256afd6f136", "start": 2.8000000000000003, "_stepIndex": 13}, {"type": "new", "id": "3e419f5dbb5142c7b0950ed7b018aef5", "defName": "kl_tri", "start": 2.80000000000000 ...

# %% [markdown]
# Compare it to the one above. The graph structure will be the same since the same abstract algebraic relationships remain intact, but their specific values are different. Thus, the resultant "tone world" will be different.
#
# Let's do another one...

# %%
hx3 = Hexany((3, 17, 23, 53))
print('Ratios: ', *[str(r) for r in hx3.ratios])
plot(hx3, figsize=(7,7))
pc = PC.from_degrees(list(hx3.ratios), equave='2/1')
idx = list(range(-len(hx3.ratios)*2, len(hx3.ratios)*2))
play(pc.root('C4')[idx + idx[-2::-1]], dur=0.2)
# Out:
# Ratios:  69/64 1219/1024 159/128 391/256 51/32 901/512
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><rect width="700" height="700" fill="black"/>
# <text x="350.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D]</text>
# <line x1="140.16" y1="486.15" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <circle id="svgcps_c7406e3e_nd1" cx="140.16" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_c7406e3e"/>
# <text x="140.16" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AB</text>
# <circle id="svgcps_c7406e3e_nd2" cx="350.00" cy="607.31" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_c7406e3e"/>
# <text x="350.00" y="607.31" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AC</text>
# <circle id="svgcps_c7406e3e_nd3" cx="140.16" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_c7406e3e"/>
# <text x="140.16" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AD</text>
# <circle id="svgcps_c7406e3e_nd4" cx="559.84" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgcps_c7406e3e"/>
# <text x="559.84" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BC</text>
# <circle id="svgcps_c7406e3e_nd5" cx="350.00" cy="122.69" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgcps_c7406e3e"/>
# <text x="350.00" y="122.69" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BD</text>
# <circle id="svgcps_c7406e3e_nd6" cx="559.84" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgcps_c7406e3e"/>
# <text x="559.84" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">CD</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
# <div id="klotho_ss_a3fbe478" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 6px 10px;
#     background: #1a1a2e;
#     border-radius: 6px;
#     user-select: none;
# ">
#     <button id="klotho_ss_a3fbe478_toggle" style="
#         width: 32px;
#         height: 32px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#     ">
#         <span id="klotho_ss_a3fbe478_icon" style="
#             width: 0;
#             height: 0;
#             border-top: 7px solid transparent;
#             border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80;
#             margin-left: 3px;
#         "></span>
#     </button>
#     <button id="klotho_ss_a3fbe478_loop" style="
#         width: 28px;
#         height: 28px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#         opacity: 0.5;
#     ">
#         <svg id="klotho_ss_a3fbe478_loop_svg" width="16" height="16" viewBox="0 0 24 24" fill="none" stroke="#a0a0a0" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path>
#             <path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path>
#             <path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
#     <span id="klotho_ss_a3fbe478_status" style="
#         color: #666;
#         font-size: 10px;
#         min-width: 60px;
#     ">ready</span>
# </div>
#
# <script>
#
# // SuperSonic standalone playback widget.
# // Python replaces: klotho_ss_a3fbe478, [{"type": "new", "id": "39a0a8e519b8492ab9633923403dcb6f", "defName": "kl_tri", "start": 0, "pfields": {"freq": 70.5163, "amp": 0.3236333802338282}, "_stepIndex": 0}, {"type": "release", "id": "39a0a8e519b8492ab9633923403dcb6f", "start": 0.2, "_stepIndex": 0}, {"type": "new", "id": "aff9a8b682ed49a9841c94201e0a1007", "defName": "kl_tri", "start": 0.2, "pfields": {"freq": 77.8617, "amp": 0.33075494382807474}, "_stepIndex": 1}, {"type": "release", "id": "aff9a8b682ed49a9841c94201e0a1007", "start": 0.4, "_stepIndex": 1}, {"type": "new", "id": "46ede5de5b9c468f9604d020a0425f11", "defName": "kl_tri", "start": 0.4, "pfields": {"freq": 81.247, "amp": 0.3338707205350856}, "_stepIndex": 2}, {"type": "release", "id": "46ede5de5b9c468f9604d020a0425f11", "start": 0.6000000000000001, "_stepIndex": 2}, {"type": "new", "id": "db9bad6204364de0940d17dd881cb7f2", "defName": "kl_tri", "start": 0.6000000000000001, "pfields": {"freq": 99.8981, "amp": 0.34991489626920064}, "_stepIndex": 3}, {"type": "release", "id": "db9bad6204364de0940d17dd881cb7f2", "start": 0.8, "_stepIndex": 3}, {"type": "new", "id": "9573af93551d4faabad639e196679c6f", "defName": "kl_tri", "start": 0.8, "pfields": {"freq": 104.2414, "amp": 0.3535389992710421}, "_stepIndex": 4}, {"type": "release", "id": "9573af93551d4faabad639e196679c6f", "start": 1.0, "_stepIndex": 4}, {"type": "new", "id": "bf5d78500cfc4278a776aa937a0ed25c", "defName": "kl_tri", "start": 1.0, "pfields": {"freq": 115.0999, "amp": 0.3625525339135989}, "_stepIndex": 5}, {"type": "release", "id": "bf5d78500cfc4278a776aa937a0ed25c", "start": 1.2, "_stepIndex": 5}, {"type": "new", "id": "09f9190034114c73a28dcf2f3df03809", "defName": "kl_tri", "start": 1.2, "pfields": {"freq": 141.0326, "amp": 0.3835321080518373}, "_stepIndex": 6}, {"type": "release", "id": "09f9190034114c73a28dcf2f3df03809", "start": 1.4, "_stepIndex": 6}, {"type": "new", "id": "90dd13a334284ab59a4cc15eb0b527f7", "defName": "kl_tri", "start": 1.4, "pfields": {"freq": 155.7234, "amp": 0.3948590945014346}, "_stepIndex": 7}, {"type": "release", "id": "90dd13a334284ab59a4cc15eb0b527f7", "start": 1.5999999999999999, "_stepIndex": 7}, {"type": "new", "id": "67feae1fee0b41aa9415c68e2219d135", "defName": "kl_tri", "start": 1.5999999999999999, "pfields": {"freq": 162.494, "amp": 0.3998952009622652}, "_stepIndex": 8}, {"type": "release", "id": "67feae1fee0b41aa9415c68e2219d135", "start": 1.7999999999999998, "_stepIndex": 8}, {"type": "new", "id": "149eeca062c9469498ae5539eba96fa7", "defName": "kl_tri", "start": 1.7999999999999998, "pfields": {"freq": 199.7961, "amp": 0.42487866483714026}, "_stepIndex": 9}, {"type": "release", "id": "149eeca062c9469498ae5539eba96fa7", "start": 1.9999999999999998, "_stepIndex": 9}, {"type": "new", "id": "0c7ce01992ef453c957cc6d1b44f3bf6", "defName": "kl_tri", "start": 1.9999999999999998, "pfields": {"freq": 208.4829, "amp": 0.4298833668171688}, "_stepIndex": 10}, {"type": "release", "id": "0c7ce01992ef453c957cc6d1b44f3bf6", "start": 2.1999999999999997, "_stepIndex": 10}, {"type": "new", "id": "0b8127669f434edcbaa2e26e80e1b62c", "defName": "kl_tri", "start": 2.1999999999999997, "pfields": {"freq": 230.1999, "amp": 0.4409756537862877}, "_stepIndex": 11}, {"type": "release", "id": "0b8127669f434edcbaa2e26e80e1b62c", "start": 2.4, "_stepIndex": 11}, {"type": "new", "id": "369ea6ef882e4677986598dc8cd19263", "defName": "kl_tri", "start": 2.4, "pfields": {"freq": 282.0651, "amp": 0.4601305630107781}, "_stepIndex": 12}, {"type": "release", "id": "369ea6ef882e4677986598dc8cd19263", "start": 2.6, "_stepIndex": 12}, {"type": "new", "id": "4cfc851a9ddb4043ad45251bda861e9b", "defName": "kl_tri", "start": 2.6, "pfields": {"freq": 311.4469, "amp": 0.4670729092669841}, "_stepIndex": 13}, {"type": "release", "id": "4cfc851a9ddb4043ad45251bda861e9b", "start": 2.8000000000000003, "_stepIndex": 13}, {"type": "new", "id": "52977809bd374798bf5dd9143aa17f6e", "defName": "kl_tri", "start": 2.8000000000000003, " ...

# %% [markdown]
# Interesting...
#
# Ok, let's go back to the initial Hexany we created. It gets cooler.

# %%
print('Ratios: ', *[str(r) for r in hx.ratios])
plot(hx, figsize=(7,7))
pc = PC.from_degrees(list(hx.ratios), equave='2/1')
idx = list(range(-len(hx.ratios)*2, len(hx.ratios)*2))
play(pc.root('C4')[idx + idx[-2::-1]], dur=0.2)
# Out:
# Ratios:  35/32 5/4 21/16 3/2 7/4 15/8
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><rect width="700" height="700" fill="black"/>
# <text x="350.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D]</text>
# <line x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <circle id="svgcps_14570d99_nd1" cx="140.16" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_14570d99"/>
# <text x="140.16" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AB</text>
# <circle id="svgcps_14570d99_nd2" cx="350.00" cy="607.31" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_14570d99"/>
# <text x="350.00" y="607.31" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AC</text>
# <circle id="svgcps_14570d99_nd3" cx="140.16" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_14570d99"/>
# <text x="140.16" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AD</text>
# <circle id="svgcps_14570d99_nd4" cx="559.84" cy="243.85" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgcps_14570d99"/>
# <text x="559.84" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BC</text>
# <circle id="svgcps_14570d99_nd5" cx="350.00" cy="122.69" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgcps_14570d99"/>
# <text x="350.00" y="122.69" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BD</text>
# <circle id="svgcps_14570d99_nd6" cx="559.84" cy="486.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgcps_14570d99"/>
# <text x="559.84" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">CD</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
# <div id="klotho_ss_82694308" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 6px 10px;
#     background: #1a1a2e;
#     border-radius: 6px;
#     user-select: none;
# ">
#     <button id="klotho_ss_82694308_toggle" style="
#         width: 32px;
#         height: 32px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#     ">
#         <span id="klotho_ss_82694308_icon" style="
#             width: 0;
#             height: 0;
#             border-top: 7px solid transparent;
#             border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80;
#             margin-left: 3px;
#         "></span>
#     </button>
#     <button id="klotho_ss_82694308_loop" style="
#         width: 28px;
#         height: 28px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#         opacity: 0.5;
#     ">
#         <svg id="klotho_ss_82694308_loop_svg" width="16" height="16" viewBox="0 0 24 24" fill="none" stroke="#a0a0a0" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path>
#             <path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path>
#             <path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
#     <span id="klotho_ss_82694308_status" style="
#         color: #666;
#         font-size: 10px;
#         min-width: 60px;
#     ">ready</span>
# </div>
#
# <script>
#
# // SuperSonic standalone playback widget.
# // Python replaces: klotho_ss_82694308, [{"type": "new", "id": "d2e2b2a1cd2c404b9c6a9ceff9d2bb73", "defName": "kl_tri", "start": 0, "pfields": {"freq": 71.5382, "amp": 0.32465768312924875}, "_stepIndex": 0}, {"type": "release", "id": "d2e2b2a1cd2c404b9c6a9ceff9d2bb73", "start": 0.2, "_stepIndex": 0}, {"type": "new", "id": "188ecef0a1b84441928c788e1bed83b9", "defName": "kl_tri", "start": 0.2, "pfields": {"freq": 81.758, "amp": 0.33433332784005887}, "_stepIndex": 1}, {"type": "release", "id": "188ecef0a1b84441928c788e1bed83b9", "start": 0.4, "_stepIndex": 1}, {"type": "new", "id": "3be3f14f5e5f4d0fad53aeb1f402e5e7", "defName": "kl_tri", "start": 0.4, "pfields": {"freq": 85.8459, "amp": 0.33797075387458925}, "_stepIndex": 2}, {"type": "release", "id": "3be3f14f5e5f4d0fad53aeb1f402e5e7", "start": 0.6000000000000001, "_stepIndex": 2}, {"type": "new", "id": "0a9aaec2105142e3a9f6878f4fc6f99f", "defName": "kl_tri", "start": 0.6000000000000001, "pfields": {"freq": 98.1096, "amp": 0.34842026788607267}, "_stepIndex": 3}, {"type": "release", "id": "0a9aaec2105142e3a9f6878f4fc6f99f", "start": 0.8, "_stepIndex": 3}, {"type": "new", "id": "e6b25edb455a4f869ece276e141dd8b6", "defName": "kl_tri", "start": 0.8, "pfields": {"freq": 114.4612, "amp": 0.3620248787580148}, "_stepIndex": 4}, {"type": "release", "id": "e6b25edb455a4f869ece276e141dd8b6", "start": 1.0, "_stepIndex": 4}, {"type": "new", "id": "bdfef36b4da5468289b9c1843466e097", "defName": "kl_tri", "start": 1.0, "pfields": {"freq": 122.637, "amp": 0.3687474438592235}, "_stepIndex": 5}, {"type": "release", "id": "bdfef36b4da5468289b9c1843466e097", "start": 1.2, "_stepIndex": 5}, {"type": "new", "id": "7383161788ac435aa839f4a5d51ee288", "defName": "kl_tri", "start": 1.2, "pfields": {"freq": 143.0765, "amp": 0.3851372505985531}, "_stepIndex": 6}, {"type": "release", "id": "7383161788ac435aa839f4a5d51ee288", "start": 1.4, "_stepIndex": 6}, {"type": "new", "id": "9a72722383ce4edda13cf21bae3f2128", "defName": "kl_tri", "start": 1.4, "pfields": {"freq": 163.516, "amp": 0.4006440314150796}, "_stepIndex": 7}, {"type": "release", "id": "9a72722383ce4edda13cf21bae3f2128", "start": 1.5999999999999999, "_stepIndex": 7}, {"type": "new", "id": "46c11d9d74f547f79724bd1c1636ae18", "defName": "kl_tri", "start": 1.5999999999999999, "pfields": {"freq": 171.6918, "amp": 0.40651889163039745}, "_stepIndex": 8}, {"type": "release", "id": "46c11d9d74f547f79724bd1c1636ae18", "start": 1.7999999999999998, "_stepIndex": 8}, {"type": "new", "id": "f77e1621173d4810bc901de9336fe5e0", "defName": "kl_tri", "start": 1.7999999999999998, "pfields": {"freq": 196.2192, "amp": 0.4227200184411173}, "_stepIndex": 9}, {"type": "release", "id": "f77e1621173d4810bc901de9336fe5e0", "start": 1.9999999999999998, "_stepIndex": 9}, {"type": "new", "id": "7466d9539b5f4326a3f601b093d63fd5", "defName": "kl_tri", "start": 1.9999999999999998, "pfields": {"freq": 228.9224, "amp": 0.44037718222926503}, "_stepIndex": 10}, {"type": "release", "id": "7466d9539b5f4326a3f601b093d63fd5", "start": 2.1999999999999997, "_stepIndex": 10}, {"type": "new", "id": "89a8cea070dd4ba491c5ccd75ba8a5cc", "defName": "kl_tri", "start": 2.1999999999999997, "pfields": {"freq": 245.274, "amp": 0.4475524738657926}, "_stepIndex": 11}, {"type": "release", "id": "89a8cea070dd4ba491c5ccd75ba8a5cc", "start": 2.4, "_stepIndex": 11}, {"type": "new", "id": "77e95469d32e491f9a23e5349fe0a90c", "defName": "kl_tri", "start": 2.4, "pfields": {"freq": 286.153, "amp": 0.46124976648817834}, "_stepIndex": 12}, {"type": "release", "id": "77e95469d32e491f9a23e5349fe0a90c", "start": 2.6, "_stepIndex": 12}, {"type": "new", "id": "55530921bd0d41b2bb5a56e41df6c813", "defName": "kl_tri", "start": 2.6, "pfields": {"freq": 327.032, "amp": 0.4697954849148101}, "_stepIndex": 13}, {"type": "release", "id": "55530921bd0d41b2bb5a56e41df6c813", "start": 2.8000000000000003, "_stepIndex": 13}, {"type": "new", "id": "916f3f1497644e45b5272c512689e66d", "defName": "kl_tri", "start": 2.8000000000000003, " ...

# %% [markdown]
# This is a geometric form. Which means, yes, we have points (individual notes), but we also have *faces*. I.e., we can select multiple nodes and create a surface. What does that give us?
#
# Well, if a single point is a single note, then multiple points are multiple notes—i.e., chords...

# %%
shape = [0, 4, 3]
print('Target Shape:')
matches = match_pattern(hx, shape, sort_by='position', include_target=True)
plot(hx, shape=matches, figsize=(7,7)).play(dur=2, releaseTime=2)
# Out:
# Target Shape:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><rect width="700" height="700" fill="black"/>
# <text x="350.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D]</text>
# <line x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line id="svgcps_3e2ffc2f_se1" x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_3e2ffc2f_se2" x1="140.16" y1="243.85" x2="559.84" y2="243.85" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_3e2ffc2f_se3" x1="350.00" y1="122.69" x2="559.84" y2="243.85" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_3e2ffc2f_se4" x1="350.00" y1="122.69" x2="559.84" y2="243.85" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_3e2ffc2f_se5" x1="350.00" y1="122.69" x2="559.84" y2="486.15" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_3e2ffc2f_se6" x1="559.84" y1="243.85" x2="559.84" y2="486.15" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_3e2ffc2f_se7" x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_3e2ffc2f_se8" x1="350.00" y1="607.31" x2="559.84" y2="243.85" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_3e2ffc2f_se9" x1="559.84" y1="486.15" x2="559.84" y2="243.85" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_3e2ffc2f_se10" x1="140.16" y1="486.15" x2="350.00" y2="607.31" stroke="#87CEEB" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_3e2ffc2f_se11" x1="140.16" y1="486.15" x2="559.84" y2="486.15" stroke="#87CEEB" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_3e2ffc2f_se12" x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#87CEEB" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_3e2ffc2f_se13" x1="140.16" y1="243.85" x2="140.16" y2="486.15" stroke="#DDA0DD" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_3e2ffc2f_se14" x1="140.16" y1="243.85" x2="350.00" y2="607.31" stroke="#DDA0DD" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_3e2ffc2f_se15" x1="140.16" y1="486.15" x2="350.00" y2="607.31" stroke="#DDA0DD" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_3e2ffc2f_se16" x1="140.16" y1="486.15" x2="140.16" y2="243.85" stroke="#FFA07A" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_3e2ffc2f_se17" x1="140.16" y1="486.15" x2="350.00" y2="122.69" stroke="#FFA07A" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_3e2ffc2f_se18" x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#FFA07A" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <circle id="svgcps_3e2ffc2f_nd19" cx="140.16" cy="243.85" r="15.0" fill="#FFA07A" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_3e2ffc2f"/>
# <text x="140.16" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AB</text>
# <circle id="svgcps_3e2ffc2f_nd20" cx="350.00" cy="607.31" r="15.0" fill="#DDA0DD" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_3e2ffc2f"/>
# <text x="350.00" y="607.31" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AC</text>
# <circle id="svgcps_3e2ffc2f_nd21" cx="140.16" cy="486.15" r="15.0" fill="#FFA07A" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_3e2ffc2f"/>
# <text x="140.16" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AD</text>
# <circle id="svgcps_3e2ffc2f_nd22" cx="559.84" cy="243.85" r="15.0" fill="#FF6B6B" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgcps_3e2ffc2f"/>
# <text x="559.84" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BC</text>
# <circle id="svgcps_3e2ffc2f_nd23" cx="350.00" cy="122.69" r="15.0" fill="#FFA07A" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgcps_3e2ffc2f"/>
# <text x="350.00" y="122.69" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BD</text>
# <circle id="svgcps_3e2ffc2f_nd24" cx="559.84" cy="486.15" r="15.0" fill="#87CEEB" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgcps_3e2ffc2f"/>
# <text x="559.84" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">CD</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _raw

# %% [markdown]
# That's a pretty cool sequence of chords. And we didn't really need to work that hard to get it. All we did was find some pattern in the Hexany, find every other instance of that pattern elsewhere in the Hexany, then just... play them in order. That's it.
#
# I consider this the "reward" for going through all the abstract algebraic geometry earlier.
#
# That triangle shape produces chords of a certain quality. What about other shapes?

# %%
shape = [1, 5, 0, 4]
print('Target Shape:')
matches = match_pattern(hx, shape, sort_by='rotation', include_target=True)
plot(hx, shape=matches, figsize=(7,7)).play(dur=1, pause=0)
# Out:
# Target Shape:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="700" height="700" style="display:block;background:black"><rect width="700" height="700" fill="black"/>
# <text x="350.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D]</text>
# <line x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="607.31" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="350.00" y1="122.69" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="486.15" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="486.15" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="140.16" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="140.16" y1="243.85" x2="559.84" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="607.31" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="350.00" y2="122.69" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="559.84" y2="486.15" stroke="#808080" stroke-width="1"/>
# <line x1="559.84" y1="243.85" x2="140.16" y2="243.85" stroke="#808080" stroke-width="1"/>
# <line id="svgcps_fa828341_se1" x1="350.00" y1="607.31" x2="559.84" y2="486.15" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_fa828341_se2" x1="350.00" y1="607.31" x2="140.16" y2="243.85" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_fa828341_se3" x1="559.84" y1="486.15" x2="350.00" y2="122.69" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_fa828341_se4" x1="140.16" y1="243.85" x2="350.00" y2="122.69" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_fa828341_se5" x1="350.00" y1="607.31" x2="140.16" y2="486.15" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_fa828341_se6" x1="350.00" y1="607.31" x2="559.84" y2="243.85" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_fa828341_se7" x1="140.16" y1="486.15" x2="350.00" y2="122.69" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_fa828341_se8" x1="559.84" y1="243.85" x2="350.00" y2="122.69" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_fa828341_se9" x1="140.16" y1="243.85" x2="140.16" y2="486.15" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_fa828341_se10" x1="140.16" y1="243.85" x2="559.84" y2="243.85" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_fa828341_se11" x1="140.16" y1="486.15" x2="559.84" y2="486.15" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_fa828341_se12" x1="559.84" y1="243.85" x2="559.84" y2="486.15" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <circle id="svgcps_fa828341_nd13" cx="140.16" cy="243.85" r="15.0" fill="#FF6B6B" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_fa828341"/>
# <text x="140.16" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AB</text>
# <circle id="svgcps_fa828341_nd14" cx="350.00" cy="607.31" r="15.0" fill="#FFD700" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_fa828341"/>
# <text x="350.00" y="607.31" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AC</text>
# <circle id="svgcps_fa828341_nd15" cx="140.16" cy="486.15" r="15.0" fill="#FF6B6B" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_fa828341"/>
# <text x="140.16" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">AD</text>
# <circle id="svgcps_fa828341_nd16" cx="559.84" cy="243.85" r="15.0" fill="#FF6B6B" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgcps_fa828341"/>
# <text x="559.84" y="243.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BC</text>
# <circle id="svgcps_fa828341_nd17" cx="350.00" cy="122.69" r="15.0" fill="#FFD700" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgcps_fa828341"/>
# <text x="350.00" y="122.69" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">BD</text>
# <circle id="svgcps_fa828341_nd18" cx="559.84" cy="486.15" r="15.0" fill="#FF6B6B" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgcps_fa828341"/>
# <text x="559.84" y="486.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">CD</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_s

# %% [markdown]
# ## Eikosany
#
# There are other types of CPS structures (in fact, there are *a lot* of them). After the Hexany, the most common is the ***Eikosany***.
#
# This one is a little different. Instead of finding all possible `2`-wise groups (i.e., pairs), we find all `3`-wise groupings. We also use a different generating geometry to build the resultant graph.
#
# The result is a more complex geometry and, thus, a more complex tone world:

# %%
print("GENERATING GEOMETRY")
plot(MasterSet.asterisk(), figsize=(6,6))

print("\nCPS")
ek = Eikosany(master_set='asterisk')
plot(ek, node_size=25, text_size=10, figsize=(8,8))
pc = PC.from_degrees(list(ek.ratios), equave='2/1')
idx = list(range(-len(ek.ratios)*2, len(ek.ratios)*2))
play(pc.root('C4')[idx + idx[-2::-1]], dur=0.15)
# Out:
# GENERATING GEOMETRY
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="600" height="600" style="display:block;background:black"><text x="300.0" y="18" text-anchor="middle" font-family="Arial" font-size="14" fill="white">MasterSet: asterisk</text>
# <line x1="300.00" y1="276.83" x2="300.00" y2="519.47" stroke="#808080" stroke-width="1.5"/>
# <line x1="300.00" y1="276.83" x2="69.23" y2="351.81" stroke="#808080" stroke-width="1.5"/>
# <line x1="300.00" y1="276.83" x2="157.38" y2="80.53" stroke="#808080" stroke-width="1.5"/>
# <line x1="300.00" y1="276.83" x2="442.62" y2="80.53" stroke="#808080" stroke-width="1.5"/>
# <line x1="300.00" y1="276.83" x2="530.77" y2="351.81" stroke="#808080" stroke-width="1.5"/>
# <circle cx="300.00" cy="276.83" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgms_a7a99d6a"/>
# <text x="300.00" y="277.83" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">A</text>
# <circle cx="300.00" cy="519.47" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgms_a7a99d6a"/>
# <text x="300.00" y="520.47" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">B</text>
# <circle cx="69.23" cy="351.81" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgms_a7a99d6a"/>
# <text x="69.23" y="352.81" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">C</text>
# <circle cx="157.38" cy="80.53" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgms_a7a99d6a"/>
# <text x="157.38" y="81.53" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">D</text>
# <circle cx="442.62" cy="80.53" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgms_a7a99d6a"/>
# <text x="442.62" y="81.53" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">E</text>
# <circle cx="530.77" cy="351.81" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgms_a7a99d6a"/>
# <text x="530.77" y="352.81" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">F</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
#     }
#
#     function reorderEventsFrom(allEvents, startGi, total, gap) {
#       var gapSec = typeof gap === "number" ? Math.max(0, gap) : _pause;
#       var buckets = [];
#       for (var g = 0; g < total; g++) buckets.push([]);
#       for (var i = 0; i < allEvents.length; i++) {
#         var si = allEvents[i]._stepIndex;
#         if (si >= 0 && si < total) buckets[si].push(allEvents[i]);
#       }
#       var groupStarts = [];
#       for (var g1 = 0; g1 < total; g1++) {
#         var mn = Infinity;
#         for (var i1 = 0; i1 < buckets[g1].length; i1++) {
#           if (buckets[g1][i1].start < mn) mn = buckets[g1][i1].start;
#         }
#         groupStarts.push(mn === Infinity ? 0 : mn);
#       }
#       var groupDurs = [];
#       for (var g2 = 0; g2 < total; g2++) {
#         var mx = 0;
#         for (var i2 = 0; i2 < buckets[g2].length; i2++) {
#           var end = eventEnd(buckets[g2][i2]);
#           if (end > mx) mx = end;
#         }
#         groupDurs.push(mx - groupStarts[g2]);
#       }
#       var result = [];
#       var cursor = 0;
#       var seqMap = [];
#       for (var step = 0; step < total; step++) {
#         var gi = (startGi + step) % total;
#         seqMap.push(gi);
#         var base = groupStarts[gi];
#         for (var i3 = 0; i3 < buckets[gi].length; i3++) {
#           var e2 = {};
#           for (var k2 in buckets[gi][i3]) e2[k2] = buckets[gi][i3][k2];
#           e2.start = cursor + (buckets[gi][i3].start - base);
#           e2._stepIndex = step;
#           result.push(e2);
#         }
#         cursor += groupDurs[gi] + gapSec;
#       }
#       return { events: result, seqMap: seqMap };
#     }
#
#     function isPlaying() {
#       if (engine === "supersonic") return !!(_ssScheduler && _ssScheduler.isPlaying);
#       return !!(_aPlayer && _aPlayer.isPlaying());
#     }
#
#     async function stop() {
#       if (engine === "supersonic") {
#         if (_ssScheduler && _ssScheduler.isPlaying) await _ssScheduler.stop();
#         return;
#       }
#       if (_aPlayer && _aPlaye
# CPS
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="800" height="800" style="display:block;background:black"><rect width="800" height="800" fill="black"/>
# <text x="400.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D E F]</text>
# <line x1="132.97" y1="328.24" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="328.24" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="328.24" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="501.76" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="501.76" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="501.76" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <circle id="svgcps_5935cfbb_nd1" cx="234.97" cy="642.15" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_5935cfbb"/>
# <text x="234.97" y="642.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABC</text>
# <circle id="svgcps_5935cfbb_nd2" cx="298.00" cy="448.14" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_5935cfbb"/>
# <text x="298.00" y="448.14" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABD</text>
# <circle id="svgcps_5935cfbb_nd3" cx="502.00" cy="448.14" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_5935cfbb"/>
# <text x="502.00" y="448.14" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABE</text>
# <circle id="svgcps_5935cfbb_nd4" cx="565.03" cy="642.15" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgcps_5935cfbb"/>
# <text x="565.03" y="642.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABF</text>
# <circle id="svgcps_5935cfbb_nd5" cx="132.97" cy="328.24" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgcps_5935cfbb"/>
# <text x="132.97" y="328.24" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ACD</text>
# <circle id="svgcps_5935cfbb_nd6" cx="336.96" cy="328.24" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgcps_5935cfbb"/>
# <text x="336.96" y="328.24" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ACE</text>
# <circle id="svgcps_5935cfbb_nd7" cx="400.00" cy="522.24" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="6" data-tip-uid="svgcps_5935cfbb"/>
# <text x="400.00" y="522.
# <div id="klotho_ss_ddcb0254" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 6px 10px;
#     background: #1a1a2e;
#     border-radius: 6px;
#     user-select: none;
# ">
#     <button id="klotho_ss_ddcb0254_toggle" style="
#         width: 32px;
#         height: 32px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#     ">
#         <span id="klotho_ss_ddcb0254_icon" style="
#             width: 0;
#             height: 0;
#             border-top: 7px solid transparent;
#             border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80;
#             margin-left: 3px;
#         "></span>
#     </button>
#     <button id="klotho_ss_ddcb0254_loop" style="
#         width: 28px;
#         height: 28px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#         opacity: 0.5;
#     ">
#         <svg id="klotho_ss_ddcb0254_loop_svg" width="16" height="16" viewBox="0 0 24 24" fill="none" stroke="#a0a0a0" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path>
#             <path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path>
#             <path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
#     <span id="klotho_ss_ddcb0254_status" style="
#         color: #666;
#         font-size: 10px;
#         min-width: 60px;
#     ">ready</span>
# </div>
#
# <script>
#
# // SuperSonic standalone playback widget.
# // Python replaces: klotho_ss_ddcb0254, [{"type": "new", "id": "58ad719d30ff4116bbb6e69fa3f1f3d5", "defName": "kl_tri", "start": 0, "pfields": {"freq": 67.4504, "amp": 0.32048700060925006}, "_stepIndex": 0}, {"type": "release", "id": "58ad719d30ff4116bbb6e69fa3f1f3d5", "start": 0.15, "_stepIndex": 0}, {"type": "new", "id": "8034a7aa07f34b72a1d89bfa39a99459", "defName": "kl_tri", "start": 0.15, "pfields": {"freq": 68.9833, "amp": 0.32207425551811875}, "_stepIndex": 1}, {"type": "release", "id": "8034a7aa07f34b72a1d89bfa39a99459", "start": 0.3, "_stepIndex": 1}, {"type": "new", "id": "a8940e8c19e446d7a8c41243e3e989b8", "defName": "kl_tri", "start": 0.3, "pfields": {"freq": 71.5382, "amp": 0.32465768312924875}, "_stepIndex": 2}, {"type": "release", "id": "a8940e8c19e446d7a8c41243e3e989b8", "start": 0.44999999999999996, "_stepIndex": 2}, {"type": "new", "id": "012989f202a648c18fca2bc5127aa887", "defName": "kl_tri", "start": 0.44999999999999996, "pfields": {"freq": 75.8816, "amp": 0.3288874252764311}, "_stepIndex": 3}, {"type": "release", "id": "012989f202a648c18fca2bc5127aa887", "start": 0.6, "_stepIndex": 3}, {"type": "new", "id": "0f7ca8b59dee4fb0ad08625a528b30eb", "defName": "kl_tri", "start": 0.6, "pfields": {"freq": 78.6921, "amp": 0.33152785500850146}, "_stepIndex": 4}, {"type": "release", "id": "0f7ca8b59dee4fb0ad08625a528b30eb", "start": 0.75, "_stepIndex": 4}, {"type": "new", "id": "5726a2de892d4733bf39277446ff58b2", "defName": "kl_tri", "start": 0.75, "pfields": {"freq": 80.4805, "amp": 0.33317317961507}, "_stepIndex": 5}, {"type": "release", "id": "5726a2de892d4733bf39277446ff58b2", "start": 0.9, "_stepIndex": 5}, {"type": "new", "id": "5b01aa9846e64ac0867c3568c9c23094", "defName": "kl_tri", "start": 0.9, "pfields": {"freq": 84.3129, "amp": 0.33661912609210914}, "_stepIndex": 6}, {"type": "release", "id": "5b01aa9846e64ac0867c3568c9c23094", "start": 1.05, "_stepIndex": 6}, {"type": "new", "id": "a8b7bbab78ff487eb97bad484db3bc4d", "defName": "kl_tri", "start": 1.05, "pfields": {"freq": 85.8459, "amp": 0.33797075387458925}, "_stepIndex": 7}, {"type": "release", "id": "a8b7bbab78ff487eb97bad484db3bc4d", "start": 1.2, "_stepIndex": 7}, {"type": "new", "id": "e9de691158564c389d2021d11d2126ca", "defName": "kl_tri", "start": 1.2, "pfields": {"freq": 88.5286, "amp": 0.3403049571710779}, "_stepIndex": 8}, {"type": "release", "id": "e9de691158564c389d2021d11d2126ca", "start": 1.3499999999999999, "_stepIndex": 8}, {"type": "new", "id": "eb1e913578874e82bafeafcb30d1bc80", "defName": "kl_tri", "start": 1.3499999999999999, "pfields": {"freq": 91.9777, "amp": 0.34325804568693724}, "_stepIndex": 9}, {"type": "release", "id": "eb1e913578874e82bafeafcb30d1bc80", "start": 1.4999999999999998, "_stepIndex": 9}, {"type": "new", "id": "bd7055d826ea486d8fdd2dbd90eb7eaa", "defName": "kl_tri", "start": 1.4999999999999998, "pfields": {"freq": 96.5766, "amp": 0.34713666216187933}, "_stepIndex": 10}, {"type": "release", "id": "bd7055d826ea486d8fdd2dbd90eb7eaa", "start": 1.6499999999999997, "_stepIndex": 10}, {"type": "new", "id": "283bae97d6714448a45521ac969165b5", "defName": "kl_tri", "start": 1.6499999999999997, "pfields": {"freq": 98.3651, "amp": 0.34863393410065163}, "_stepIndex": 11}, {"type": "release", "id": "283bae97d6714448a45521ac969165b5", "start": 1.7999999999999996, "_stepIndex": 11}, {"type": "new", "id": "6c6c2d128aa248b18d0302a1ee2de92c", "defName": "kl_tri", "start": 1.7999999999999996, "pfields": {"freq": 101.1755, "amp": 0.3509815050788694}, "_stepIndex": 12}, {"type": "release", "id": "6c6c2d128aa248b18d0302a1ee2de92c", "start": 1.9499999999999995, "_stepIndex": 12}, {"type": "new", "id": "3237147ae30042ee9d0a457831cd7b1e", "defName": "kl_tri", "start": 1.9499999999999995, "pfields": {"freq": 107.3074, "amp": 0.35609209194991875}, "_stepIndex": 13}, {"type": "release", "id": "3237147ae30042ee9d0a457831cd7b1e", "start": 2.0999999999999996, "_stepIndex": 13}, {"type": "new", "id": "7a4bb65b231b43ec9fd9eca6f99a9cd9", "defName": "kl ...

# %% [markdown]
# We can do all the same operations with shapes. These do not necessarily need to be *faces*, we can specify any configuration of nodes and find all matching instances:

# %%
shape = [7, 16, 19, 13]
print('Target Shape:')
matches = match_pattern(ek, shape, sort_by='rotation', include_target=True)
plot(ek, shape=matches, node_size=20, text_size=8, figsize=(8,8)).play(dur=1)
# Out:
# Target Shape:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="800" height="800" style="display:block;background:black"><rect width="800" height="800" fill="black"/>
# <text x="400.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D E F]</text>
# <line x1="132.97" y1="328.24" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="328.24" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="328.24" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="501.76" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="501.76" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="501.76" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line id="svgcps_1c7d02f6_se1" x1="400.00" y1="134.23" x2="234.97" y2="187.85" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_1c7d02f6_se2" x1="400.00" y1="134.23" x2="565.03" y2="187.85" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_1c7d02f6_se3" x1="400.00" y1="134.23" x2="400.00" y2="307.76" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_1c7d02f6_se4" x1="400.00" y1="695.77" x2="234.97" y2="642.15" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_1c7d02f6_se5" x1="400.00" y1="695.77" x2="565.03" y2="642.15" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_1c7d02f6_se6" x1="400.00" y1="695.77" x2="400.00" y2="522.24" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_1c7d02f6_se7" x1="234.97" y1="642.15" x2="132.97" y2="501.76" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_1c7d02f6_se8" x1="234.97" y1="642.15" x2="400.00" y2="695.77" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_1c7d02f6_se9" x1="234.97" y1="642.15" x2="336.96" y2="501.76" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_1c7d02f6_se10" x1="565.03" y1="187.85" x2="400.00" y2="134.23" stroke="#87CEEB" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_1c7d02f6_se11" x1="565.03" y1="187.85" x2="667.03" y2="328.24" stroke="#87CEEB" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_1c7d02f6_se12" x1="565.03" y1="187.85" x2="463.04" y2="328.24" stroke="#87CEEB" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_1c7d02f6_se13" x1="667.03" y1="328.24" x2="667.03" y2="501.76" stroke="#DDA0DD" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_1c7d02f6_se14" x1="667.03" y1="328.24" x2="565.03" y2="187.85" stroke="#DDA0DD" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_1c7d02f6_se15" x1="667.03" y1="328.24" x2="502.00" y2="381.86" stroke="#DDA0DD" str

# %% [markdown]
# Eikosany also has other forms. We can derive them by using a different generating geometry:

# %%
plot(MasterSet.centered_pentagon(), figsize=(6,6))
# Out:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="600" height="600" style="display:block;background:black"><text x="300.0" y="18" text-anchor="middle" font-family="Arial" font-size="14" fill="white">MasterSet: centered_pentagon</text>
# <line x1="300.00" y1="80.53" x2="69.23" y2="248.19" stroke="#808080" stroke-width="1.5"/>
# <line x1="300.00" y1="80.53" x2="530.77" y2="248.19" stroke="#808080" stroke-width="1.5"/>
# <line x1="69.23" y1="248.19" x2="157.38" y2="519.47" stroke="#808080" stroke-width="1.5"/>
# <line x1="530.77" y1="248.19" x2="442.62" y2="519.47" stroke="#808080" stroke-width="1.5"/>
# <line x1="157.38" y1="519.47" x2="442.62" y2="519.47" stroke="#808080" stroke-width="1.5"/>
# <circle cx="300.00" cy="323.17" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgms_03b51516"/>
# <text x="300.00" y="324.17" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">A</text>
# <circle cx="300.00" cy="80.53" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgms_03b51516"/>
# <text x="300.00" y="81.53" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">B</text>
# <circle cx="530.77" cy="248.19" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgms_03b51516"/>
# <text x="530.77" y="249.19" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">C</text>
# <circle cx="442.62" cy="519.47" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgms_03b51516"/>
# <text x="442.62" y="520.47" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">D</text>
# <circle cx="157.38" cy="519.47" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgms_03b51516"/>
# <text x="157.38" y="520.47" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">E</text>
# <circle cx="69.23" cy="248.19" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgms_03b51516"/>
# <text x="69.23" y="249.19" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">F</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
#     }
#
#     function reorderEventsFrom(allEvents, startGi, total, gap) {
#       var gapSec = typeof gap === "number" ? Math.max(0, gap) : _pause;
#       var buckets = [];
#       for (var g = 0; g < total; g++) buckets.push([]);
#       for (var i = 0; i < allEvents.length; i++) {
#         var si = allEvents[i]._stepIndex;
#         if (si >= 0 && si < total) buckets[si].push(allEvents[i]);
#       }
#       var groupStarts = [];
#       for (var g1 = 0; g1 < total; g1++) {
#         var mn = Infinity;
#         for (var i1 = 0; i1 < buckets[g1].length; i1++) {
#           if (buckets[g1][i1].start < mn) mn = buckets[g1][i1].start;
#         }
#         groupStarts.push(mn === Infinity ? 0 : mn);
#       }
#       var groupDurs = [];
#       for (var g2 = 0; g2 < total; g2++) {
#         var mx = 0;
#         for (var i2 = 0; i2 < buckets[g2].length; i2++) {
#           var end = eventEnd(buckets[g2][i2]);
#           if (end > mx) mx = end;
#         }
#         groupDurs.push(mx - groupStarts[g2]);
#       }
#       var result = [];
#       var cursor = 0;
#       var seqMap = [];
#       for (var step = 0; step < total; step++) {
#         var gi = (startGi + step) % total;
#         seqMap.push(gi);
#         var base = groupStarts[gi];
#         for (var i3 = 0; i3 < buckets[gi].length; i3++) {
#           var e2 = {};
#           for (var k2 in buckets[gi][i3]) e2[k2] = buckets[gi][i3][k2];
#           e2.start = cursor + (buckets[gi][i3].start - base);
#           e2._stepIndex = step;
#           result.push(e2);
#         }
#         cursor += groupDurs[gi] + gapSec;
#       }
#       return { events: result, seqMap: seqMap };
#     }
#
#     function isPlaying() {
#       if (engine === "supersonic") return !!(_ssScheduler && _ssScheduler.isPlaying);
#       return !!(_aPlayer && _aPlayer.isPlaying());
#     }
#
#     async function stop() {
#       if (engine === "supersonic") {
#         if (_ssScheduler && _ssScheduler.isPlaying) await _ssScheduler.stop();
#         return;
#       }
#       if (_aPlayer

# %%
ek = Eikosany(master_set='centered_pentagon')
print('Ratios: ', *[str(r) for r in ek.ratios])
plot(ek, node_size=25, text_size=10, figsize=(8,8))
pc = PC.from_degrees(list(ek.ratios), equave='2/1')
idx = list(range(-len(ek.ratios)*2, len(ek.ratios)*2))
play(pc.root('C4')[idx + idx[-2::-1]], dur=0.15)
# Out:
# Ratios:  33/32 135/128 35/32 297/256 77/64 315/256 165/128 21/16 693/512 45/32 189/128 385/256 99/64 105/64 27/16 55/32 231/128 15/8 495/256 63/32
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="800" height="800" style="display:block;background:black"><rect width="800" height="800" fill="black"/>
# <text x="400.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D E F]</text>
# <line x1="667.03" y1="501.76" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="501.76" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="328.24" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="328.24" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <circle id="svgcps_4a79e67a_nd1" cx="565.03" cy="187.85" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_4a79e67a"/>
# <text x="565.03" y="187.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABC</text>
# <circle id="svgcps_4a79e67a_nd2" cx="502.00" cy="381.86" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_4a79e67a"/>
# <text x="502.00" y="381.86" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABD</text>
# <circle id="svgcps_4a79e67a_nd3" cx="298.00" cy="381.86" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_4a79e67a"/>
# <text x="298.00" y="381.86" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABE</text>
# <circle id="svgcps_4a79e67a_nd4" cx="234.97" cy="187.85" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgcps_4a79e67a"/>
# <text x="234.97" y="187.85" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABF</text>
# <circle id="svgcps_4a79e67a_nd5" cx="667.03" cy="501.76" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgcps_4a79e67a"/>
# <text x="667.03" y="501.76" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ACD</text>
# <circle id="svgcps_4a79e67a_nd6" cx="463.04" cy="501.76" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgcps_4a79e67a"/>
# <text x="463.04" y="501.76" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ACE</text>
# <circle id="svgcps_4a79e67a_nd7" cx="400.00" cy="307.76" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="6" data-tip-uid="svgcps_4a79e67a"/>
# <text x="400.00" y="307.
# <div id="klotho_ss_2a5a5393" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 6px 10px;
#     background: #1a1a2e;
#     border-radius: 6px;
#     user-select: none;
# ">
#     <button id="klotho_ss_2a5a5393_toggle" style="
#         width: 32px;
#         height: 32px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#     ">
#         <span id="klotho_ss_2a5a5393_icon" style="
#             width: 0;
#             height: 0;
#             border-top: 7px solid transparent;
#             border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80;
#             margin-left: 3px;
#         "></span>
#     </button>
#     <button id="klotho_ss_2a5a5393_loop" style="
#         width: 28px;
#         height: 28px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#         opacity: 0.5;
#     ">
#         <svg id="klotho_ss_2a5a5393_loop_svg" width="16" height="16" viewBox="0 0 24 24" fill="none" stroke="#a0a0a0" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path>
#             <path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path>
#             <path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
#     <span id="klotho_ss_2a5a5393_status" style="
#         color: #666;
#         font-size: 10px;
#         min-width: 60px;
#     ">ready</span>
# </div>
#
# <script>
#
# // SuperSonic standalone playback widget.
# // Python replaces: klotho_ss_2a5a5393, [{"type": "new", "id": "6cdfc7f7d55841ea851137dba3421519", "defName": "kl_tri", "start": 0, "pfields": {"freq": 67.4504, "amp": 0.32048700060925006}, "_stepIndex": 0}, {"type": "release", "id": "6cdfc7f7d55841ea851137dba3421519", "start": 0.15, "_stepIndex": 0}, {"type": "new", "id": "d2549aff281e4aba97a22fa3ab8b0e3d", "defName": "kl_tri", "start": 0.15, "pfields": {"freq": 68.9833, "amp": 0.32207425551811875}, "_stepIndex": 1}, {"type": "release", "id": "d2549aff281e4aba97a22fa3ab8b0e3d", "start": 0.3, "_stepIndex": 1}, {"type": "new", "id": "bf605218e5194e49bbc0c1442fcdad2a", "defName": "kl_tri", "start": 0.3, "pfields": {"freq": 71.5382, "amp": 0.32465768312924875}, "_stepIndex": 2}, {"type": "release", "id": "bf605218e5194e49bbc0c1442fcdad2a", "start": 0.44999999999999996, "_stepIndex": 2}, {"type": "new", "id": "3bf296e9565c407c896f73d805e2bd77", "defName": "kl_tri", "start": 0.44999999999999996, "pfields": {"freq": 75.8816, "amp": 0.3288874252764311}, "_stepIndex": 3}, {"type": "release", "id": "3bf296e9565c407c896f73d805e2bd77", "start": 0.6, "_stepIndex": 3}, {"type": "new", "id": "2a1a177ac5434d719bd37de6a2a26d23", "defName": "kl_tri", "start": 0.6, "pfields": {"freq": 78.6921, "amp": 0.33152785500850146}, "_stepIndex": 4}, {"type": "release", "id": "2a1a177ac5434d719bd37de6a2a26d23", "start": 0.75, "_stepIndex": 4}, {"type": "new", "id": "19879ae1e883472ca29a50fad9416b75", "defName": "kl_tri", "start": 0.75, "pfields": {"freq": 80.4805, "amp": 0.33317317961507}, "_stepIndex": 5}, {"type": "release", "id": "19879ae1e883472ca29a50fad9416b75", "start": 0.9, "_stepIndex": 5}, {"type": "new", "id": "79a31653990f473e8c2a1b43f3dde407", "defName": "kl_tri", "start": 0.9, "pfields": {"freq": 84.3129, "amp": 0.33661912609210914}, "_stepIndex": 6}, {"type": "release", "id": "79a31653990f473e8c2a1b43f3dde407", "start": 1.05, "_stepIndex": 6}, {"type": "new", "id": "d76687c38adf48ecb4af7961f546542f", "defName": "kl_tri", "start": 1.05, "pfields": {"freq": 85.8459, "amp": 0.33797075387458925}, "_stepIndex": 7}, {"type": "release", "id": "d76687c38adf48ecb4af7961f546542f", "start": 1.2, "_stepIndex": 7}, {"type": "new", "id": "5db4500f40d6471a90790fe4246cf061", "defName": "kl_tri", "start": 1.2, "pfields": {"freq": 88.5286, "amp": 0.3403049571710779}, "_stepIndex": 8}, {"type": "release", "id": "5db4500f40d6471a90790fe4246cf061", "start": 1.3499999999999999, "_stepIndex": 8}, {"type": "new", "id": "84b48dfb198b4b388cc47530893aa354", "defName": "kl_tri", "start": 1.3499999999999999, "pfields": {"freq": 91.9777, "amp": 0.34325804568693724}, "_stepIndex": 9}, {"type": "release", "id": "84b48dfb198b4b388cc47530893aa354", "start": 1.4999999999999998, "_stepIndex": 9}, {"type": "new", "id": "4ed3fdbe8f814041aa67fb9126c8953f", "defName": "kl_tri", "start": 1.4999999999999998, "pfields": {"freq": 96.5766, "amp": 0.34713666216187933}, "_stepIndex": 10}, {"type": "release", "id": "4ed3fdbe8f814041aa67fb9126c8953f", "start": 1.6499999999999997, "_stepIndex": 10}, {"type": "new", "id": "cfc7edc1c2ab417b9927fcb9b469fe40", "defName": "kl_tri", "start": 1.6499999999999997, "pfields": {"freq": 98.3651, "amp": 0.34863393410065163}, "_stepIndex": 11}, {"type": "release", "id": "cfc7edc1c2ab417b9927fcb9b469fe40", "start": 1.7999999999999996, "_stepIndex": 11}, {"type": "new", "id": "52854708a5f9427dbc7b9d052cc06a2c", "defName": "kl_tri", "start": 1.7999999999999996, "pfields": {"freq": 101.1755, "amp": 0.3509815050788694}, "_stepIndex": 12}, {"type": "release", "id": "52854708a5f9427dbc7b9d052cc06a2c", "start": 1.9499999999999995, "_stepIndex": 12}, {"type": "new", "id": "e4508f650ae4479293e13c4ee2add3a4", "defName": "kl_tri", "start": 1.9499999999999995, "pfields": {"freq": 107.3074, "amp": 0.35609209194991875}, "_stepIndex": 13}, {"type": "release", "id": "e4508f650ae4479293e13c4ee2add3a4", "start": 2.0999999999999996, "_stepIndex": 13}, {"type": "new", "id": "937cd6ba29174178b2f832a50ecaf25f", "defName": "kl ...

# %%
shape = [12, 14, 11, 13]
print('Target Shape:')
matches = match_pattern(ek, shape, sort_by='position', include_target=True)
plot(ek, shape=matches, node_size=20, text_size=8, figsize=(8,8)).play(dur=0.667, pause=0, sustainLevel=0.5)
# Out:
# Target Shape:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="800" height="800" style="display:block;background:black"><rect width="800" height="800" fill="black"/>
# <text x="400.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D E F]</text>
# <line x1="667.03" y1="501.76" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="501.76" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="328.24" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="522.24" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="381.86" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="642.15" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="463.04" y1="501.76" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="134.23" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="695.77" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="400.00" y2="134.23" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="328.24" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="400.00" y2="522.24" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="642.15" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="565.03" y1="187.85" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="234.97" y1="187.85" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="565.03" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="667.03" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="448.14" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="328.24" x2="336.96" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="328.24" x2="298.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="463.04" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="234.97" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="307.76" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="667.03" y1="328.24" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="400.00" y2="695.77" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="400.00" y2="307.76" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="502.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="336.96" y1="501.76" x2="132.97" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="463.04" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="234.97" y2="642.15" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="502.00" y2="448.14" stroke="#808080" stroke-width="1"/>
# <line x1="298.00" y1="448.14" x2="132.97" y2="328.24" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="667.03" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="565.03" y2="187.85" stroke="#808080" stroke-width="1"/>
# <line x1="502.00" y1="381.86" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="298.00" y2="381.86" stroke="#808080" stroke-width="1"/>
# <line x1="132.97" y1="501.76" x2="336.96" y2="501.76" stroke="#808080" stroke-width="1"/>
# <line id="svgcps_cb32de14_se1" x1="400.00" y1="134.23" x2="336.96" y2="328.24" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_cb32de14_se2" x1="400.00" y1="134.23" x2="463.04" y2="328.24" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_cb32de14_se3" x1="336.96" y1="328.24" x2="400.00" y2="522.24" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_cb32de14_se4" x1="463.04" y1="328.24" x2="400.00" y2="522.24" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_cb32de14_se5" x1="565.03" y1="187.85" x2="502.00" y2="381.86" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_cb32de14_se6" x1="565.03" y1="187.85" x2="400.00" y2="307.76" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_cb32de14_se7" x1="502.00" y1="381.86" x2="336.96" y2="501.76" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_cb32de14_se8" x1="400.00" y1="307.76" x2="336.96" y2="501.76" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_cb32de14_se9" x1="667.03" y1="328.24" x2="463.04" y2="328.24" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_cb32de14_se10" x1="667.03" y1="328.24" x2="502.00" y2="448.14" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_cb32de14_se11" x1="463.04" y1="328.24" x2="298.00" y2="448.14" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_cb32de14_se12" x1="502.00" y1="448.14" x2="298.00" y2="448.14" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_cb32de14_se13" x1="298.00" y1="381.86" x2="502.00" y2="381.86" stroke="#87CEEB" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_cb32de14_se14" x1="298.00" y1="381.86" x2="463.04" y2="501.76" stroke="#87CEEB" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_cb32de14_se15" x1="502.00" y1="381.86" x2="667.03" y2="501.76" stroke="#87CEEB" str

# %% [markdown]
# Eikosany can also be built from a "distorted" hexagon. This form, devised by Erv Wilson, uses a slight
# geometric distortion to prevent two nodes from overlapping in the resultant CPS graph:

# %%
print('GENERATING GEOMETRY')
plot(MasterSet.irregular_hexagon(), figsize=(6,6))

print('\nCPS')
ek_ih = Eikosany(master_set='irregular_hexagon')
plot(ek_ih, node_size=25, text_size=10, figsize=(8,8))
pc = PC.from_degrees(list(ek_ih.ratios), equave='2/1')
idx = list(range(-len(ek_ih.ratios)*2, len(ek_ih.ratios)*2))
play(pc.root('C4')[idx + idx[-2::-1]], dur=0.15)
# Out:
# GENERATING GEOMETRY
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="600" height="600" style="display:block;background:black"><text x="300.0" y="18" text-anchor="middle" font-family="Arial" font-size="14" fill="white">MasterSet: irregular_hexagon</text>
# <line x1="300.00" y1="97.02" x2="468.93" y2="265.95" stroke="#808080" stroke-width="1.5"/>
# <line x1="468.93" y1="265.95" x2="530.77" y2="441.15" stroke="#808080" stroke-width="1.5"/>
# <line x1="530.77" y1="441.15" x2="300.00" y2="502.98" stroke="#808080" stroke-width="1.5"/>
# <line x1="300.00" y1="502.98" x2="69.23" y2="441.15" stroke="#808080" stroke-width="1.5"/>
# <line x1="69.23" y1="441.15" x2="131.07" y2="265.95" stroke="#808080" stroke-width="1.5"/>
# <line x1="131.07" y1="265.95" x2="300.00" y2="97.02" stroke="#808080" stroke-width="1.5"/>
# <circle cx="530.77" cy="441.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgms_ee916836"/>
# <text x="530.77" y="442.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">A</text>
# <circle cx="69.23" cy="441.15" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgms_ee916836"/>
# <text x="69.23" y="442.15" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">B</text>
# <circle cx="300.00" cy="97.02" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgms_ee916836"/>
# <text x="300.00" y="98.02" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">C</text>
# <circle cx="131.07" cy="265.95" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="3" data-tip-uid="svgms_ee916836"/>
# <text x="131.07" y="266.95" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">D</text>
# <circle cx="300.00" cy="502.98" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="4" data-tip-uid="svgms_ee916836"/>
# <text x="300.00" y="503.98" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">E</text>
# <circle cx="468.93" cy="265.95" r="15.0" fill="white" stroke="white" stroke-width="2" data-idx="5" data-tip-uid="svgms_ee916836"/>
# <text x="468.93" y="266.95" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="12" font-weight="bold" fill="black" pointer-events="none">F</text></svg></div><script>(() => {
#   if (typeof globalThis.KlothoPlaybackBridge !== "undefined") return;
#
#   function buildBridge(config) {
#     var engine = config.engine || "tone";
#     var audioPayload = config.audioPayload || null;
#     var ringTime = config.ringTime != null ? config.ringTime : 5;
#
#     var _aPlayer = null;
#     var _aInstruments = null;
#     var _ssScheduler = null;
#     var _ssSonic = null;
#     var _ssReady = false;
#     var _pause = 0.0;
#
#     if (audioPayload && typeof audioPayload === "object" && audioPayload.pause != null) {
#       var pauseVal = Number(audioPayload.pause);
#       if (!Number.isNaN(pauseVal) && pauseVal > 0) _pause = pauseVal;
#     }
#
#     function _rawEvents() {
#       if (!audioPayload) return [];
#       if (Array.isArray(audioPayload)) return audioPayload;
#       return Array.isArray(audioPayload.events) ? audioPayload.events : [];
#     }
#
#     function _toneEvents() {
#       return _rawEvents();
#     }
#
#     function _scEvents() {
#       return _rawEvents().filter(function(e) {
#         return e && (e.type === "new" || e.type === "set" || e.type === "release");
#       });
#     }
#
#     function _hasToneAudio() {
#       if (_aPlayer) return true;
#       if (typeof Tone === "undefined"
#           || typeof globalThis.KLOTHO_BUILD_INSTRUMENTS !== "function"
#           || typeof globalThis.KlothoPlayer === "undefined") return false;
#       _aInstruments = globalThis.KLOTHO_BUILD_INSTRUMENTS((audioPayload && audioPayload.instruments) || {});
#       _aPlayer = globalThis.KlothoPlayer.create();
#       return true;
#     }
#
#     async function _ensureSSReady() {
#       if (_ssReady) return true;
#       if (typeof globalThis.__ensureSuperSonic !== "function") return false;
#       try {
#         var sonic = await globalThis.__ensureSuperSonic();
#         if (!sonic) return false;
#         _ssSonic = sonic;
#         _ssScheduler = new globalThis.BrowserScheduler({
#           sonic: sonic,
#           manifest: (typeof globalThis.__klothoManifest !== "undefined") ? globalThis.__klothoManifest : { synths: {}, inserts: {} },
#           ringTime: ringTime,
#         });
#         _ssReady = true;
#         return true;
#       } catch(e) {
#         return false;
#       }
#     }
#
#     async function ensureReady() {
#       if (engine === "supersonic") return _ensureSSReady();
#       return _hasToneAudio();
#     }
#
#     function hasPlayableEvents() {
#       if (engine === "supersonic") return _scEvents().length > 0;
#       return _toneEvents().length > 0;
#     }
#
#     function eventEnd(ev) {
#       var pf = ev && ev.pfields ? ev.pfields : {};
#       if (ev && ev.duration != null) return ev.start + ev.duration;
#       if (pf.dur != null) return ev.start + pf.dur;
#       if (ev && ev.type === "release") return ev.start;
#       return ev && ev.start ? ev.start : 0;
#     }
#
#     function filterEventsForGroup(allEvents, gi) {
#       var filtered = [];
#       var minStart = Infinity;
#       for (var i = 0; i < allEvents.length; i++) {
#         if (allEvents[i]._stepIndex === gi) {
#           if (allEvents[i].start < minStart) minStart = allEvents[i].start;
#           filtered.push(allEvents[i]);
#         }
#       }
#       if (minStart === Infinity) minStart = 0;
#       var result = [];
#       for (var j = 0; j < filtered.length; j++) {
#         var e = {};
#         for (var k in filtered[j]) e[k] = filtered[j][k];
#         e.start = filtered[j].start - minStart;
#         e._stepIndex = 0;
#         result.push(e);
#       }
#       return result;
#     }
#
#     function reorderEventsFrom(allEvents, startGi, total, gap) {
#       var gapSec = typeof gap === "number" ? Math.max(0, gap) : _pause;
#       var buckets = [];
#       for (var g = 0; g < total; g++) buckets.push([]);
#       for (var i = 0; i < allEvents.length; i++) {
#         var si = allEvents[i]._stepIndex;
#         if (si >= 0 && si < total) buckets[si].push(allEvents[i]);
#       }
#       var groupStarts = [];
#       for (var g1 = 0; g1 < total; g1++) {
#         var mn = Infinity;
#         for (var i1 = 0; i1 < buckets[g1].length; i1++) {
#           if (buckets[g1][i1].start < mn) mn = buckets[g1][i1].start;
#         }
#         groupStarts.push(mn === Infinity ? 0 : mn);
#       }
#       var groupDurs = [];
#       for (var g2 = 0; g2 < total; g2++) {
#         var mx = 0;
#         for (var i2 = 0; i2 < buckets[g2].length; i2++) {
#           var end = eventEnd(buckets[g2][i2]);
#           if (end > mx) mx = end;
#         }
#         groupDurs.push(mx - groupStarts[g2]);
#       }
#       var result = [];
#       var cursor = 0;
#       var seqMap = [];
#       for (var step = 0; step < total; step++) {
#         var gi = (startGi + step) % total;
#         seqMap.push(gi);
#         var base = groupStarts[gi];
#         for (var i3 = 0; i3 < buckets[gi].length; i3++) {
#           var e2 = {};
#           for (var k2 in buckets[gi][i3]) e2[k2] = buckets[gi][i3][k2];
#           e2.start = cursor + (buckets[gi][i3].start - base);
#           e2._stepIndex = step;
#           result.push(e2);
#         }
#         cursor += groupDurs[gi] + gapSec;
#       }
#       return { events: result, seqMap: seqMap };
#     }
#
#     function isPlaying() {
#       if (engine === "supersonic") return !!(_ssScheduler && _ssScheduler.isPlaying);
#       return !!(_aPlayer && _aPlayer.isPlaying());
#     }
#
#     async function stop() {
#       if (engine === "supersonic") {
#         if (_ssScheduler && _s
# CPS
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="800" height="800" style="display:block;background:black"><rect width="800" height="800" fill="black"/>
# <text x="400.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D E F]</text>
# <line x1="445.22" y1="261.10" x2="276.46" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="261.10" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="261.10" x2="400.00" y2="132.97" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="261.10" x2="568.76" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="434.44" x2="107.69" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="434.44" x2="276.46" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="434.44" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="434.44" x2="354.78" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="107.69" y1="557.99" x2="231.24" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="107.69" y1="557.99" x2="276.46" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="686.11" x2="445.22" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="686.11" x2="354.78" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="306.32" x2="445.22" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="306.32" x2="231.24" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="306.32" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="306.32" x2="107.69" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="434.44" x2="445.22" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="434.44" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="434.44" x2="523.54" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="434.44" x2="692.31" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="261.10" x2="231.24" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="261.10" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="261.10" x2="400.00" y2="132.97" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="261.10" x2="523.54" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="557.99" x2="400.00" y2="686.11" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="557.99" x2="568.76" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="557.99" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="557.99" x2="276.46" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="384.64" x2="354.78" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="384.64" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="384.64" x2="107.69" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="384.64" x2="276.46" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="276.46" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="445.22" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="231.24" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="354.78" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="568.76" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="523.54" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="445.22" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="231.24" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="568.76" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="354.78" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="523.54" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="276.46" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="512.77" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="512.77" x2="354.78" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="512.77" x2="568.76" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="512.77" x2="692.31" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="132.97" x2="445.22" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="132.97" x2="354.78" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="557.99" x2="231.24" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="557.99" x2="400.00" y2="686.11" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="557.99" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="557.99" x2="523.54" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="692.31" y1="261.10" x2="568.76" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="692.31" y1="261.10" x2="523.54" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="107.69" y1="261.10" x2="276.46" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="107.69" y1="261.10" x2="231.24" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="384.64" x2="445.22" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="384.64" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="384.64" x2="523.54" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="384.64" x2="692.31" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="306.32" x2="568.76" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="306.32" x2="354.78" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="306.32" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="306.32" x2="692.31" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="512.77" x2="107.69" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="512.77" x2="445.22" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="512.77" x2="231.24" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="512.77" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="692.31" y1="557.99" x2="568.76" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="692.31" y1="557.99" x2="523.54" y2="512.77" stroke="#808080" stroke-width="1"/>
# <circle id="svgcps_97c0c96d_nd1" cx="400.00" cy="389.22" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="0" data-tip-uid="svgcps_97c0c96d"/>
# <text x="400.00" y="389.22" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABC</text>
# <circle id="svgcps_97c0c96d_nd2" cx="276.46" cy="512.77" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="1" data-tip-uid="svgcps_97c0c96d"/>
# <text x="276.46" y="512.77" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABD</text>
# <circle id="svgcps_97c0c96d_nd3" cx="400.00" cy="686.11" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="2" data-tip-uid="svgcps_97c0c96d"/>
# <text x="400.00" y="686.11" text-anchor="middle" dominant-baseline="central" font-family="Arial Black" font-size="10" font-weight="bold" fill="black" pointer-events="none">ABE</text>
# <circle id="svgcps_97c0c96d_nd4" cx="523.54" cy="512.77" r="12.5" fill="white" stroke="white" stroke-width="2" data-idx="
# <div id="klotho_ss_e08da62e" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex;
#     align-items: center;
#     gap: 6px;
#     padding: 6px 10px;
#     background: #1a1a2e;
#     border-radius: 6px;
#     user-select: none;
# ">
#     <button id="klotho_ss_e08da62e_toggle" style="
#         width: 32px;
#         height: 32px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#     ">
#         <span id="klotho_ss_e08da62e_icon" style="
#             width: 0;
#             height: 0;
#             border-top: 7px solid transparent;
#             border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80;
#             margin-left: 3px;
#         "></span>
#     </button>
#     <button id="klotho_ss_e08da62e_loop" style="
#         width: 28px;
#         height: 28px;
#         border: none;
#         border-radius: 4px;
#         background: #16213e;
#         cursor: pointer;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         padding: 0;
#         opacity: 0.5;
#     ">
#         <svg id="klotho_ss_e08da62e_loop_svg" width="16" height="16" viewBox="0 0 24 24" fill="none" stroke="#a0a0a0" stroke-width="2.5" stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path>
#             <path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path>
#             <path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
#     <span id="klotho_ss_e08da62e_status" style="
#         color: #666;
#         font-size: 10px;
#         min-width: 60px;
#     ">ready</span>
# </div>
#
# <script>
#
# // SuperSonic standalone playback widget.
# // Python replaces: klotho_ss_e08da62e, [{"type": "new", "id": "99b6912dcb0f4c0f9ae9e029fa34aa24", "defName": "kl_tri", "start": 0, "pfields": {"freq": 67.4504, "amp": 0.32048700060925006}, "_stepIndex": 0}, {"type": "release", "id": "99b6912dcb0f4c0f9ae9e029fa34aa24", "start": 0.15, "_stepIndex": 0}, {"type": "new", "id": "7e233b5b22734e03841219c3ee68c36a", "defName": "kl_tri", "start": 0.15, "pfields": {"freq": 68.9833, "amp": 0.32207425551811875}, "_stepIndex": 1}, {"type": "release", "id": "7e233b5b22734e03841219c3ee68c36a", "start": 0.3, "_stepIndex": 1}, {"type": "new", "id": "7dcff05e91e247e4b1bd5030c2edf24c", "defName": "kl_tri", "start": 0.3, "pfields": {"freq": 71.5382, "amp": 0.32465768312924875}, "_stepIndex": 2}, {"type": "release", "id": "7dcff05e91e247e4b1bd5030c2edf24c", "start": 0.44999999999999996, "_stepIndex": 2}, {"type": "new", "id": "2c3790fd2f0145ea9d13edd6d7be4904", "defName": "kl_tri", "start": 0.44999999999999996, "pfields": {"freq": 75.8816, "amp": 0.3288874252764311}, "_stepIndex": 3}, {"type": "release", "id": "2c3790fd2f0145ea9d13edd6d7be4904", "start": 0.6, "_stepIndex": 3}, {"type": "new", "id": "7c4d424b36774a6ca294335611adae58", "defName": "kl_tri", "start": 0.6, "pfields": {"freq": 78.6921, "amp": 0.33152785500850146}, "_stepIndex": 4}, {"type": "release", "id": "7c4d424b36774a6ca294335611adae58", "start": 0.75, "_stepIndex": 4}, {"type": "new", "id": "c336bc7e301c4a439d5c065d4afa9934", "defName": "kl_tri", "start": 0.75, "pfields": {"freq": 80.4805, "amp": 0.33317317961507}, "_stepIndex": 5}, {"type": "release", "id": "c336bc7e301c4a439d5c065d4afa9934", "start": 0.9, "_stepIndex": 5}, {"type": "new", "id": "c92d4bb67aee4de899be7c588fe7083a", "defName": "kl_tri", "start": 0.9, "pfields": {"freq": 84.3129, "amp": 0.33661912609210914}, "_stepIndex": 6}, {"type": "release", "id": "c92d4bb67aee4de899be7c588fe7083a", "start": 1.05, "_stepIndex": 6}, {"type": "new", "id": "2b44546ac3a54d13992efd1b6538a77c", "defName": "kl_tri", "start": 1.05, "pfields": {"freq": 85.8459, "amp": 0.33797075387458925}, "_stepIndex": 7}, {"type": "release", "id": "2b44546ac3a54d13992efd1b6538a77c", "start": 1.2, "_stepIndex": 7}, {"type": "new", "id": "f81b396d35e04e569e1d954cb57adf10", "defName": "kl_tri", "start": 1.2, "pfields": {"freq": 88.5286, "amp": 0.3403049571710779}, "_stepIndex": 8}, {"type": "release", "id": "f81b396d35e04e569e1d954cb57adf10", "start": 1.3499999999999999, "_stepIndex": 8}, {"type": "new", "id": "c0b768e0b957432db0b6abdd96cf5982", "defName": "kl_tri", "start": 1.3499999999999999, "pfields": {"freq": 91.9777, "amp": 0.34325804568693724}, "_stepIndex": 9}, {"type": "release", "id": "c0b768e0b957432db0b6abdd96cf5982", "start": 1.4999999999999998, "_stepIndex": 9}, {"type": "new", "id": "76b422b7b13f456584b093903f88378f", "defName": "kl_tri", "start": 1.4999999999999998, "pfields": {"freq": 96.5766, "amp": 0.34713666216187933}, "_stepIndex": 10}, {"type": "release", "id": "76b422b7b13f456584b093903f88378f", "start": 1.6499999999999997, "_stepIndex": 10}, {"type": "new", "id": "64d81924351a4528b4021c779f5adfe0", "defName": "kl_tri", "start": 1.6499999999999997, "pfields": {"freq": 98.3651, "amp": 0.34863393410065163}, "_stepIndex": 11}, {"type": "release", "id": "64d81924351a4528b4021c779f5adfe0", "start": 1.7999999999999996, "_stepIndex": 11}, {"type": "new", "id": "f50cc356feea41248e7c1eed432321e1", "defName": "kl_tri", "start": 1.7999999999999996, "pfields": {"freq": 101.1755, "amp": 0.3509815050788694}, "_stepIndex": 12}, {"type": "release", "id": "f50cc356feea41248e7c1eed432321e1", "start": 1.9499999999999995, "_stepIndex": 12}, {"type": "new", "id": "fff89248fae240ea9092a312910e1731", "defName": "kl_tri", "start": 1.9499999999999995, "pfields": {"freq": 107.3074, "amp": 0.35609209194991875}, "_stepIndex": 13}, {"type": "release", "id": "fff89248fae240ea9092a312910e1731", "start": 2.0999999999999996, "_stepIndex": 13}, {"type": "new", "id": "d37d11efd2f5487a9b4eb4f7aa852f1d", "defName": "kl ...

# %%
target_shapes = [[11, 16, 4, 0], [18, 6, 8, 19], [0, 12, 4], [12, 18, 5]]
print('Target Shape:')
matches = [match for shape in target_shapes for match in match_pattern(ek_ih, shape, include_target=True)]
np.random.shuffle(matches)
plot(ek_ih, shape=matches, node_size=20, text_size=8, figsize=(8,8)).play(dur=2, pause=0.5, strum=0.5, releaseTime=2)
# Out:
# Target Shape:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="800" height="800" style="display:block;background:black"><rect width="800" height="800" fill="black"/>
# <text x="400.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D E F]</text>
# <line x1="445.22" y1="261.10" x2="276.46" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="261.10" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="261.10" x2="400.00" y2="132.97" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="261.10" x2="568.76" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="434.44" x2="107.69" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="434.44" x2="276.46" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="434.44" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="434.44" x2="354.78" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="107.69" y1="557.99" x2="231.24" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="107.69" y1="557.99" x2="276.46" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="686.11" x2="445.22" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="686.11" x2="354.78" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="306.32" x2="445.22" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="306.32" x2="231.24" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="306.32" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="306.32" x2="107.69" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="434.44" x2="445.22" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="434.44" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="434.44" x2="523.54" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="434.44" x2="692.31" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="261.10" x2="231.24" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="261.10" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="261.10" x2="400.00" y2="132.97" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="261.10" x2="523.54" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="557.99" x2="400.00" y2="686.11" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="557.99" x2="568.76" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="557.99" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="445.22" y1="557.99" x2="276.46" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="384.64" x2="354.78" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="384.64" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="384.64" x2="107.69" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="231.24" y1="384.64" x2="276.46" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="276.46" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="445.22" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="231.24" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="354.78" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="568.76" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="429.86" x2="523.54" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="445.22" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="231.24" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="568.76" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="354.78" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="523.54" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="389.22" x2="276.46" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="512.77" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="512.77" x2="354.78" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="512.77" x2="568.76" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="512.77" x2="692.31" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="132.97" x2="445.22" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="400.00" y1="132.97" x2="354.78" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="557.99" x2="231.24" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="557.99" x2="400.00" y2="686.11" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="557.99" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="354.78" y1="557.99" x2="523.54" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="692.31" y1="261.10" x2="568.76" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="692.31" y1="261.10" x2="523.54" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="107.69" y1="261.10" x2="276.46" y2="306.32" stroke="#808080" stroke-width="1"/>
# <line x1="107.69" y1="261.10" x2="231.24" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="384.64" x2="445.22" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="384.64" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="384.64" x2="523.54" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line x1="568.76" y1="384.64" x2="692.31" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="306.32" x2="568.76" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="306.32" x2="354.78" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="306.32" x2="400.00" y2="429.86" stroke="#808080" stroke-width="1"/>
# <line x1="523.54" y1="306.32" x2="692.31" y2="261.10" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="512.77" x2="107.69" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="512.77" x2="445.22" y2="557.99" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="512.77" x2="231.24" y2="384.64" stroke="#808080" stroke-width="1"/>
# <line x1="276.46" y1="512.77" x2="400.00" y2="389.22" stroke="#808080" stroke-width="1"/>
# <line x1="692.31" y1="557.99" x2="568.76" y2="434.44" stroke="#808080" stroke-width="1"/>
# <line x1="692.31" y1="557.99" x2="523.54" y2="512.77" stroke="#808080" stroke-width="1"/>
# <line id="svgcps_770b8239_se1" x1="231.24" y1="434.44" x2="276.46" y2="306.32" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_770b8239_se2" x1="231.24" y1="434.44" x2="400.00" y2="389.22" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_770b8239_se3" x1="276.46" y1="306.32" x2="445.22" y2="261.10" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_770b8239_se4" x1="445.22" y1="261.10" x2="400.00" y2="389.22" stroke="#90EE90" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_770b8239_se5" x1="400.00" y1="686.11" x2="445.22" y2="557.99" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_770b8239_se6" x1="400.00" y1="686.11" x2="354.78" y2="557.99" stroke="#FFD700" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_770b8239_se7" x1="400.00" y1="389.22" x2="354.78" y2="261.10" stroke="#FF6B6B" stroke-width="3" opacity="0.8" pointer-events="none"/>
# <line id="svgcps_770b8239_se8" x1="400.00" y1="389.22" x2="445.22" y2="261.10" str

# %% [markdown]
# ## Hebdomekontany

# %%
heb = Hebdomekontany()
plot(heb, node_size=15, text_size=5, figsize=(10,10))
# Out:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1000" height="1000" style="display:block;background:black"><rect width="1000" height="1000" fill="black"/>
# <text x="500.0" y="25.0" text-anchor="middle" dominant-baseline="central" font-family="Arial" font-size="14" fill="white">CombinationProductSet [A B C D E F G H]</text>
# <line x1="624.46" y1="702.59" x2="469.26" y2="738.02" stroke="#808080" stroke-width="1"/>
# <line x1="624.46" y1="702.59" x2="624.46" y2="543.41" stroke="#808080" stroke-width="1"/>
# <line x1="624.46" y1="702.59" x2="500.00" y2="603.34" stroke="#808080" stroke-width="1"/>
# <line x1="624.46" y1="702.59" x2="779.66" y2="738.02" stroke="#808080" stroke-width="1"/>
# <line x1="569.07" y1="459.92" x2="500.00" y2="603.34" stroke="#808080" stroke-width="1"/>
# <line x1="569.07" y1="459.92" x2="413.87" y2="495.34" stroke="#808080" stroke-width="1"/>
# <line x1="569.07" y1="459.92" x2="569.07" y2="300.73" stroke="#808080" stroke-width="1"/>
# <line x1="569.07" y1="459.92" x2="724.27" y2="495.34" stroke="#808080" stroke-width="1"/>
# <line x1="375.54" y1="702.59" x2="530.74" y2="738.02" stroke="#808080" stroke-width="1"/>
# <line x1="375.54" y1="702.59" x2="375.54" y2="543.41" stroke="#808080" stroke-width="1"/>
# <line x1="375.54" y1="702.59" x2="500.00" y2="603.34" stroke="#808080" stroke-width="1"/>
# <line x1="375.54" y1="702.59" x2="220.34" y2="738.02" stroke="#808080" stroke-width="1"/>
# <line x1="530.74" y1="738.02" x2="375.54" y2="702.59" stroke="#808080" stroke-width="1"/>
# <line x1="530.74" y1="738.02" x2="655.20" y2="837.27" stroke="#808080" stroke-width="1"/>
# <line x1="530.74" y1="738.02" x2="599.81" y2="594.59" stroke="#808080" stroke-width="1"/>
# <line x1="530.74" y1="738.02" x2="461.67" y2="594.59" stroke="#808080" stroke-width="1"/>
# <line x1="693.53" y1="630.02" x2="624.46" y2="486.59" stroke="#808080" stroke-width="1"/>
# <line x1="693.53" y1="630.02" x2="538.33" y2="594.59" stroke="#808080" stroke-width="1"/>
# <line x1="693.53" y1="630.02" x2="569.07" y2="729.27" stroke="#808080" stroke-width="1"/>
# <line x1="693.53" y1="630.02" x2="848.72" y2="594.59" stroke="#808080" stroke-width="1"/>
# <line x1="289.41" y1="594.59" x2="444.61" y2="630.02" stroke="#808080" stroke-width="1"/>
# <line x1="289.41" y1="594.59" x2="413.87" y2="495.34" stroke="#808080" stroke-width="1"/>
# <line x1="289.41" y1="594.59" x2="289.41" y2="435.41" stroke="#808080" stroke-width="1"/>
# <line x1="289.41" y1="594.59" x2="220.34" y2="738.02" stroke="#808080" stroke-width="1"/>
# <line x1="848.72" y1="435.41" x2="779.66" y2="291.98" stroke="#808080" stroke-width="1"/>
# <line x1="848.72" y1="435.41" x2="848.72" y2="594.59" stroke="#808080" stroke-width="1"/>
# <line x1="848.72" y1="435.41" x2="693.53" y2="399.98" stroke="#808080" stroke-width="1"/>
# <line x1="848.72" y1="435.41" x2="724.27" y2="534.66" stroke="#808080" stroke-width="1"/>
# <line x1="555.39" y1="399.98" x2="710.59" y2="435.41" stroke="#808080" stroke-width="1"/>
# <line x1="555.39" y1="399.98" x2="624.46" y2="543.41" stroke="#808080" stroke-width="1"/>
# <line x1="555.39" y1="399.98" x2="400.19" y2="435.41" stroke="#808080" stroke-width="1"/>
# <line x1="555.39" y1="399.98" x2="430.93" y2="300.73" stroke="#808080" stroke-width="1"/>
# <line x1="500.00" y1="157.31" x2="655.20" y2="192.73" stroke="#808080" stroke-width="1"/>
# <line x1="500.00" y1="157.31" x2="569.07" y2="300.73" stroke="#808080" stroke-width="1"/>
# <line x1="500.00" y1="157.31" x2="430.93" y2="300.73" stroke="#808080" stroke-width="1"/>
# <line x1="500.00" y1="157.31" x2="344.80" y2="192.73" stroke="#808080" stroke-width="1"/>
# <line x1="655.20" y1="837.27" x2="530.74" y2="738.02" stroke="#808080" stroke-width="1"/>
# <line x1="655.20" y1="837.27" x2="500.00" y2="872.69" stroke="#808080" stroke-width="1"/>
# <line x1="655.20" y1="837.27" x2="655.20" y2="678.08" stroke="#808080" stroke-width="1"/>
# <line x1="655.20" y1="837.27" x2="779.66" y2="738.02" stroke="#808080" stroke-width="1"/>
# <line x1="430.93" y1="570.08" x2="586.13" y2="534.66" stroke="#808080" stroke-width="1"/>
# <line x1="430.93" y1="570.08" x2="500.00" y2="426.66" stroke="#808080" stroke-width="1"/>
# <line x1="430.93" y1="570.08" x2="430.93" y2="729.27" stroke="#808080" stroke-width="1"/>
# <line x1="430.93" y1="570.08" x2="275.73" y2="534.66" stroke="#808080" stroke-width="1"/>
# <line x1="599.81" y1="594.59" x2="530.74" y2="738.02" stroke="#808080" stroke-width="1"/>
# <line x1="599.81" y1="594.59" x2="444.61" y2="630.02" stroke="#808080" stroke-width="1"/>
# <line x1="599.81" y1="594.59" x2="599.81" y2="435.41" stroke="#808080" stroke-width="1"/>
# <line x1="599.81" y1="594.59" x2="724.27" y2="495.34" stroke="#808080" stroke-width="1"/>
# <line x1="151.28" y1="594.59" x2="306.47" y2="630.02" stroke="#808080" stroke-width="1"/>
# <line x1="151.28" y1="594.59" x2="151.28" y2="435.41" stroke="#808080" stroke-width="1"/>
# <line x1="151.28" y1="594.59" x2="220.34" y2="738.02" stroke="#808080" stroke-width="1"/>
# <line x1="151.28" y1="594.59" x2="275.73" y2="495.34" stroke="#808080" stroke-width="1"/>
# <line x1="430.93" y1="459.92" x2="500.00" y2="603.34" stroke="#808080" stroke-width="1"/>
# <line x1="430.93" y1="459.92" x2="430.93" y2="300.73" stroke="#808080" stroke-width="1"/>
# <line x1="430.93" y1="459.92" x2="275.73" y2="495.34" stroke="#808080" stroke-width="1"/>
# <line x1="430.93" y1="459.92" x2="586.13" y2="495.34" stroke="#808080" stroke-width="1"/>
# <line x1="344.80" y1="351.92" x2="413.87" y2="495.34" stroke="#808080" stroke-width="1"/>
# <line x1="344.80" y1="351.92" x2="275.73" y2="495.34" stroke="#808080" stroke-width="1"/>
# <line x1="344.80" y1="351.92" x2="344.80" y2="192.73" stroke="#808080" stroke-width="1"/>
# <line x1="344.80" y1="351.92" x2="500.00" y2="387.34" stroke="#808080" stroke-width="1"/>
# <line x1="555.39" y1="630.02" x2="624.46" y2="486.59" stroke="#808080" stroke-width="1"/>
# <line x1="555.39" y1="630.02" x2="400.19" y2="594.59" stroke="#808080" stroke-width="1"/>
# <line x1="555.39" y1="630.02" x2="430.93" y2="729.27" stroke="#808080" stroke-width="1"/>
# <line x1="555.39" y1="630.02" x2="710.59" y2="594.59" stroke="#808080" stroke-width="1"/>
# <line x1="586.13" y1="534.66" x2="430.93" y2="570.08" stroke="#808080" stroke-width="1"/>
# <line x1="586.13" y1="534.66" x2="710.59" y2="435.41" stroke="#808080" stroke-width="1"/>
# <line x1="586.13" y1="534.66" x2="655.20" y2="678.08" stroke="#808080" stroke-width="1"/>
# <line x1="586.13" y1="534.66" x2="461.67" y2="435.41" stroke="#808080" stroke-width="1"/>
# <line x1="530.74" y1="291.98" x2="655.20" y2="192.73" stroke="#808080" stroke-width="1"/>
# <line x1="530.74" y1="291.98" x2="599.81" y2="435.41" stroke="#808080" stroke-width="1"/>
# <line x1="530.74" y1="291.98" x2="461.67" y2="435.41" stroke="#808080" stroke-width="1"/>
# <line x1="530.74" y1="291.98" x2="375.54" y2="327.41" stroke="#808080" stroke-width="1"/>
# <line x1="444.61" y1="630.02" x2="289.41" y2="594.59" stroke="#808080" stroke-width="1"/>
# <line x1="444.61" y1="630.02" x2="599.81" y2="594.59" stroke="#808080" stroke-width="1"/>
# <line x1="444.61" y1="630.02" x2="375.54" y2="486.59" stroke="#808080" stroke-width="1"/>
# <line x1="444.61" y1="630.02" x2="569.07" y2="729.27" stroke="#808080" stroke-width="1"/>
# <line x1="624.46" y1="486.59" x2="693.53" y2="630.02" stroke="#808080" stroke-width="1"/>
# <line x1="624.46" y1="486.59" x2="555.39" y2="630.02" stroke="#808080" stroke-width="1"/>
# <line x1="624.46" y1="486.59" x2="624.46" y2="327.41" stroke="#808080" stroke-width="1"/>
# <line x1="624.46" y1="486.59" x2="500.00" y2="387.34" stroke="#808080" stroke-width="1"/>
# <line x1="500.00" y1="642.66" x2="375.54" y2="543.41" stroke="#808080" stroke-width="1"/>
# <line x1="500.00" y1="642.66" x2="624.46" y2="543.41" stroke="#808080" stroke-width="1"/>
# <line x1="500.00" y1="642.66" x2="655.20" y2="678.08" stroke="#808080" stroke-width="1"/>
# <line x1="500.00" y1="642.66" x2="344.80" y2="678.08" stroke="#808080" stroke-width="1"/>
# <line x1="444.61" y1="399.98" x2="375.54" y2="543.41"

# %% [markdown]
# ...and so on...
#
# Again, these are just a few CPS lattices. There are many, *many* more.
