# %% [markdown]
# ---
# jupyter: false
# ---
#
# # 02 | Tones | 05 | Higher-Dimensional CPS

# %%
from klotho import plot
from klotho.tonos import CombinationProductSet, MasterSet
# Out:
# <script>
# if (!globalThis.__klothoSonic) {
#     globalThis.__klothoSonic = { instance: null, promise: null, loadedDefs: new Set() };
#     globalThis.__klothoSonic.promise = (async function() {
#         try {
#             var config = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
#             var mod = await import("https://unpkg.com/supersonic-scsynth@latest");
#             globalThis.SuperSonic = mod.SuperSonic;
#             var sonic = new mod.SuperSonic(config);
#             await sonic.init();
#             try { await sonic.loadSynthDef("sonic-pi-beep"); } catch(e) {}
#             globalThis.__klothoSonic.instance = sonic;
#             return sonic;
#         } catch(e) {
#             console.warn("[Klotho] SuperSonic session boot failed:", e);
#             globalThis.__klothoSonic.promise = null;
#             return null;
#         }
#     })();
# }
# </script>

# %% [markdown]
# # Higher-Dimensional Interpretations
#
# Several CPS structures have natural interpretations in 3 or more dimensions. The **Hexany**’s generating tetrad is actually a 2D projection of a tetrahedron. The asterisk-based master sets represent orthogonal axes in N-dimensional space.
#
# 3D views start oriented to match the 2D projection; rotate to reveal depth.

# %% [markdown]
# ## 3D Tetrad / Hexany

# %% [markdown]
# ### Tetrad 3D
#
# Regular tetrahedron. The Hexany’s generating geometry lifted into 3D.

# %%
print('GENERATING GEOMETRY: Tetrad 3D')
plot(MasterSet.tetrad_3d(), figsize=(7,7))
# Out:
# GENERATING GEOMETRY: Tetrad 3D
# <div id="klotho_3d_static_689a456b_wrap" style="position:relative;width:700px;background:black;">
#     <div id="klotho_3d_static_689a456b_title" style="
#         color:white;font-family:Arial,sans-serif;font-size:14px;
#         text-align:center;padding:8px 0 4px 0;pointer-events:none;
#         display:block;
#     ">MasterSet: tetrad_3d</div>
#     <canvas id="klotho_3d_static_689a456b_canvas" style="display:block;width:700px;height:700px;"></canvas>
#     <div id="klotho_3d_static_689a456b_tooltip" style="
#         display:none;position:absolute;pointer-events:none;top:0;left:0;
#         background:rgba(30,30,30,0.92);color:white;font-family:monospace;
#         font-size:11px;padding:6px 10px;border-radius:4px;
#         white-space:pre;max-width:300px;z-index:10;
#     "></div>
#     <div id="klotho_3d_static_689a456b_transport" style="
#         display:flex;align-items:center;gap:12px;
#         background:#1a1a1a;padding:4px 10px;font-family:Arial,sans-serif;
#         font-size:11px;color:#aaa;width:700px;box-sizing:border-box;
#     ">
#         <label style="display:flex;align-items:center;gap:4px;white-space:nowrap;">
#             Node size
#             <input id="klotho_3d_static_689a456b_nodeSize" type="range" min="0.5" max="10" step="0.5" value="2"
#                    style="width:80px;accent-color:#666;">
#         </label>
#         <span style="flex:1;"></span>
#         <button id="klotho_3d_static_689a456b_btnReset" style="
#             background:#222;color:#aaa;border:1px solid #444;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Reset</button>
#         <button id="klotho_3d_static_689a456b_btnOrbit" style="
#             background:#444;color:white;border:1px solid #666;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Orbit</button>
#         <button id="klotho_3d_static_689a456b_btnTrackball" style="
#             background:#222;color:#888;border:1px solid #444;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Trackball</button>
#     </div>
# </div>
# <script>
# (function _klotho3dStaticInit() {
#     if (typeof THREE === "undefined") {
#         if (!document.querySelector('script[data-klotho-three]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/build/three.min.js";
#             s.setAttribute("data-klotho-three", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#     if (!THREE.OrbitControls) {
#         if (!document.querySelector('script[data-klotho-orbit]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/examples/js/controls/OrbitControls.js";
#             s.setAttribute("data-klotho-orbit", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#     if (!THREE.TrackballControls) {
#         if (!document.querySelector('script[data-klotho-trackball]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/examples/js/controls/TrackballControls.js";
#             s.setAttribute("data-klotho-trackball", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#
#     var canvas = document.getElementById("klotho_3d_static_689a456b_canvas");
#     if (!canvas) { setTimeout(_klotho3dStaticInit, 50); return; }
#     var container = document.getElementById("klotho_3d_static_689a456b_wrap");
#     var tooltip   = document.getElementById("klotho_3d_static_689a456b_tooltip");
#
#     var sceneData = {"gridEdges": [[0.0, 0.0, 2.449489742783178, -1.5, -0.8660254037844386, 0.0], [0.0, 0.0, 2.449489742783178, 0.0, 1.7320508075688772, 0.0], [0.0, 0.0, 2.449489742783178, 1.5, -0.8660254037844386, 0.0], [-1.5, -0.8660254037844386, 0.0, 0.0, 1.7320508075688772, 0.0], [0.0, 1.7320508075688772, 0.0, 1.5, -0.8660254037844386, 0.0], [1.5, -0.8660254037844386, 0.0, -1.5, -0.8660254037844386, 0.0]], "gridEdgeColor": "#808080", "highlightEdges": [], "nodes": [[-1.5, -0.8660254037844386, 0.0], [0.0, 1.7320508075688772, 0.0], [1.5, -0.8660254037844386, 0.0], [0.0, 0.0, 2.449489742783178]], "nodeColors": ["#ffffff", "#ffffff", "#ffffff", "#ffffff"], "nodeSize": 2, "dimmedNodeColor": "#555555", "pathNodeIndices": [], "pathNodeColors": [], "hoverData": ["Alias: A", "Alias: B", "Alias: C", "Alias: D"], "axisConfig": {"xRange": [-1.95, 1.95], "yRange": [-1.2557368354874359, 2.1217622392718747], "zRange": [-0.36742346141747667, 2.8169132042006546], "xTicks": [], "yTicks": [], "zTicks": [], "labels": ["", "", ""]}};
#     var pathSteps = [];
#     var haloData  = null;
#
#     var W = 700, H = 700;
#     var scene = new THREE.Scene();
#     scene.background = new THREE.Color(0x000000);
#     var camera = new THREE.PerspectiveCamera(50, W / H, 0.01, 1000);
#
#     var axCfg = sceneData.axisConfig;
#     var cx = (axCfg.xRange[0] + axCfg.xRange[1]) / 2;
#     var cy = (axCfg.yRange[0] + axCfg.yRange[1]) / 2;
#     var cz = (axCfg.zRange[0] + axCfg.zRange[1]) / 2;
#     var span = Math.max(
#         axCfg.xRange[1] - axCfg.xRange[0],
#         axCfg.yRange[1] - axCfg.yRange[0],
#         axCfg.zRange[1] - axCfg.zRange[0]
#     );
#     var dist = (span / 2) / Math.tan(THREE.MathUtils.degToRad(camera.fov / 2));
#     dist *= 1.3;
#     camera.position.set(cx + dist * 0.6, cy + dist * 0.4, cz + dist);
#     camera.lookAt(cx, cy, cz);
#
#     var initPos = camera.position.clone();
#     var initUp = camera.up.clone();
#     var initTarget = new THREE.Vector3(cx, cy, cz);
#
#     if (canvas._klothoRenderer) {
#         try { canvas._klothoRenderer.dispose(); } catch(_) {}
#     }
#     var renderer = new THREE.WebGLRenderer({ canvas: canvas, antialias: true });
#     renderer.setSize(W, H);
#     renderer.setPixelRatio(Math.min(window.devicePixelRatio || 1, 2));
#     canvas._klothoRenderer = renderer;
#
#     function makeOrbitControls() {
#         var c = new THREE.OrbitControls(camera, renderer.domElement);
#         c.target.set(cx, cy, cz);
#         c.enableDamping = true;
#         c.dampingFactor = 0.12;
#         c.update();
#         return c;
#     }
#     function makeTrackballControls() {
#         var c = new THREE.TrackballControls(camera, renderer.domElement);
#         c.target.set(cx, cy, cz);
#         c.rotateSpeed = 2.0;
#         c.zoomSpeed = 1.2;
#         c.panSpeed = 0.8;
#         c.staticMoving = false;
#         c.dynamicDampingFactor = 0.12;
#         c.update();
#         return c;
#     }
#
#     var controls = makeOrbitControls();
#     var controlsMode = "orbit";
#
#     function switchControls(mode) {
#         if (mode === controlsMode) return;
#         var oldTarget = controls.target.clone();
#         controls.dispose();
#         if (mode === "trackball") {
#             controls = makeTrackballControls();
#         } else {
#             controls = makeOrbitControls();
#         }
#         controls.target.copy(oldTarget);
#         controls.update();
#         controlsMode = mode;
#         btnOrbit.style.background = mode === "orbit" ? "#444" : "#222";
#         btnOrbit.style.color = mode === "orbit" ? "white" : "#888";
#         btnOrbit.style.borderColor = mode === "orbit" ? "#666" : "#444";
#         btnTrackball.style.background = mode === "trackball" ? "#444" : "#222";
#         btnTrackball.style.color = mode === "trackball" ? "white" : "#888";
#         btnTrackball.style.borderColor = mode === "trackball" ? "#666" : "#444";
#     }
#
#     var btnOrbit = document.getElementById("klotho_3d_static_689a456b_btnOrbit");
#     var btnTrackball = document.getElementById("klotho_3d_static_689a456b_btnTrackball");
#     var btnReset = document.getElementById("klotho_3d_static_689a456b_btnReset");
#     btnOrbit.addEventListener("click", function() { switchControls("orbit"); });
#     btnTrackball.addEventListener("click", function() { switchControls("t

# %%
factors = (1, 3, 5, 7)

for r in (2,):
    cps = CombinationProductSet(factors, r=r, master_set='tetrad_3d')
    n = len(cps.ratios)
    print(f'Tetrad 3D CPS  r={r}  ({n} notes)')
    if r == 2: print('  (= Hexany with this master set)')
    print('Ratios:', *[str(x) for x in cps.ratios])
    plot(cps, node_size=25, text_size=9, figsize=(8,8))
    print()
# Out:
# Tetrad 3D CPS  r=2  (6 notes)
#   (= Hexany with this master set)
# Ratios: 35/32 5/4 21/16 3/2 7/4 15/8
# <div id="klotho_3d_static_8211f31a_wrap" style="position:relative;width:800px;background:black;">
#     <div id="klotho_3d_static_8211f31a_title" style="
#         color:white;font-family:Arial,sans-serif;font-size:14px;
#         text-align:center;padding:8px 0 4px 0;pointer-events:none;
#         display:block;
#     ">CombinationProductSet [A B C D] (3D)</div>
#     <canvas id="klotho_3d_static_8211f31a_canvas" style="display:block;width:800px;height:800px;"></canvas>
#     <div id="klotho_3d_static_8211f31a_tooltip" style="
#         display:none;position:absolute;pointer-events:none;top:0;left:0;
#         background:rgba(30,30,30,0.92);color:white;font-family:monospace;
#         font-size:11px;padding:6px 10px;border-radius:4px;
#         white-space:pre;max-width:300px;z-index:10;
#     "></div>
#     <div id="klotho_3d_static_8211f31a_transport" style="
#         display:flex;align-items:center;gap:12px;
#         background:#1a1a1a;padding:4px 10px;font-family:Arial,sans-serif;
#         font-size:11px;color:#aaa;width:800px;box-sizing:border-box;
#     ">
#         <label style="display:flex;align-items:center;gap:4px;white-space:nowrap;">
#             Node size
#             <input id="klotho_3d_static_8211f31a_nodeSize" type="range" min="0.5" max="10" step="0.5" value="2"
#                    style="width:80px;accent-color:#666;">
#         </label>
#         <span style="flex:1;"></span>
#         <button id="klotho_3d_static_8211f31a_btnReset" style="
#             background:#222;color:#aaa;border:1px solid #444;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Reset</button>
#         <button id="klotho_3d_static_8211f31a_btnOrbit" style="
#             background:#444;color:white;border:1px solid #666;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Orbit</button>
#         <button id="klotho_3d_static_8211f31a_btnTrackball" style="
#             background:#222;color:#888;border:1px solid #444;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Trackball</button>
#     </div>
# </div>
# <script>
# (function _klotho3dStaticInit() {
#     if (typeof THREE === "undefined") {
#         if (!document.querySelector('script[data-klotho-three]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/build/three.min.js";
#             s.setAttribute("data-klotho-three", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#     if (!THREE.OrbitControls) {
#         if (!document.querySelector('script[data-klotho-orbit]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/examples/js/controls/OrbitControls.js";
#             s.setAttribute("data-klotho-orbit", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#     if (!THREE.TrackballControls) {
#         if (!document.querySelector('script[data-klotho-trackball]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/examples/js/controls/TrackballControls.js";
#             s.setAttribute("data-klotho-trackball", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#
#     var canvas = document.getElementById("klotho_3d_static_8211f31a_canvas");
#     if (!canvas) { setTimeout(_klotho3dStaticInit, 50); return; }
#     var container = document.getElementById("klotho_3d_static_8211f31a_wrap");
#     var tooltip   = document.getElementById("klotho_3d_static_8211f31a_tooltip");
#
#     var sceneData = {"gridEdges": [[0.0, -1.0, -0.7071067811865475, 0.8660254037844387, -0.5000000000000001, 0.7071067811865475], [0.0, -1.0, -0.7071067811865475, -0.8660254037844387, -0.49999999999999994, 0.7071067811865475], [0.0, -1.0, -0.7071067811865475, -0.8660254037844387, 0.5000000000000001, -0.7071067811865475], [0.0, -1.0, -0.7071067811865475, 0.8660254037844387, 0.5000000000000001, -0.7071067811865475], [0.0, 1.0, 0.7071067811865475, 0.8660254037844387, -0.5000000000000001, 0.7071067811865475], [0.0, 1.0, 0.7071067811865475, -0.8660254037844387, -0.49999999999999994, 0.7071067811865475], [0.0, 1.0, 0.7071067811865475, -0.8660254037844387, 0.5000000000000001, -0.7071067811865475], [0.0, 1.0, 0.7071067811865475, 0.8660254037844387, 0.5000000000000001, -0.7071067811865475], [0.8660254037844387, -0.5000000000000001, 0.7071067811865475, 0.0, -1.0, -0.7071067811865475], [0.8660254037844387, -0.5000000000000001, 0.7071067811865475, 0.0, 1.0, 0.7071067811865475], [0.8660254037844387, -0.5000000000000001, 0.7071067811865475, -0.8660254037844387, -0.49999999999999994, 0.7071067811865475], [0.8660254037844387, -0.5000000000000001, 0.7071067811865475, 0.8660254037844387, 0.5000000000000001, -0.7071067811865475], [-0.8660254037844387, -0.49999999999999994, 0.7071067811865475, 0.0, -1.0, -0.7071067811865475], [-0.8660254037844387, -0.49999999999999994, 0.7071067811865475, 0.0, 1.0, 0.7071067811865475], [-0.8660254037844387, -0.49999999999999994, 0.7071067811865475, 0.8660254037844387, -0.5000000000000001, 0.7071067811865475], [-0.8660254037844387, -0.49999999999999994, 0.7071067811865475, -0.8660254037844387, 0.5000000000000001, -0.7071067811865475], [-0.8660254037844387, 0.5000000000000001, -0.7071067811865475, 0.0, -1.0, -0.7071067811865475], [-0.8660254037844387, 0.5000000000000001, -0.7071067811865475, 0.0, 1.0, 0.7071067811865475], [-0.8660254037844387, 0.5000000000000001, -0.7071067811865475, -0.8660254037844387, -0.49999999999999994, 0.7071067811865475], [-0.8660254037844387, 0.5000000000000001, -0.7071067811865475, 0.8660254037844387, 0.5000000000000001, -0.7071067811865475], [0.8660254037844387, 0.5000000000000001, -0.7071067811865475, 0.0, -1.0, -0.7071067811865475], [0.8660254037844387, 0.5000000000000001, -0.7071067811865475, 0.0, 1.0, 0.7071067811865475], [0.8660254037844387, 0.5000000000000001, -0.7071067811865475, 0.8660254037844387, -0.5000000000000001, 0.7071067811865475], [0.8660254037844387, 0.5000000000000001, -0.7071067811865475, -0.8660254037844387, 0.5000000000000001, -0.7071067811865475]], "gridEdgeColor": "#808080", "highlightEdges": [], "nodes": [[-0.8660254037844387, 0.5000000000000001, -0.7071067811865475], [0.0, -1.0, -0.7071067811865475], [-0.8660254037844387, -0.49999999999999994, 0.7071067811865475], [0.8660254037844387, 0.5000000000000001, -0.7071067811865475], [0.0, 1.0, 0.7071067811865475], [0.8660254037844387, -0.5000000000000001, 0.7071067811865475]], "nodeColors": ["#ffffff", "#ffffff", "#ffffff", "#ffffff", "#ffffff", "#ffffff"], "nodeSize": 2, "dimmedNodeColor": "#555555", "pathNodeIndices": [], "pathNodeColors": [], "hoverData": ["Node: 0\nAlias: AB\nCombo: (1 3)\nProduct: 3\nRatio: 3/2", "Node: 1\nAlias: AC\nCombo: (1 5)\nProduct: 5\nRatio: 5/4", "Node: 2\nAlias: AD\nCombo: (1 7)\nProduct: 7\nRatio: 7/4", "Node: 3\nAlias: BC\nCombo: (3 5)\nProduct: 15\nRatio: 15/8", "Node: 4\nAlias: BD\nCombo: (3 7)\nProduct: 21\nRatio: 21/16", "Node: 5\nAlias: CD\nCombo: (5 7)\nProduct: 35\nRatio: 35/32"], "nodeFreqs": null, "isActive": null, "axisConfig": {"xRange": [-1.1258330249197703, 1.1258330249197703], "yRange": [-1.3, 1.3], "zRange": [-0.9192388155425117, 0.9192388155425117], "xTicks": [], "yTicks": [], "zTicks": [], "labels": ["", "", ""]}};
#     var pathSteps = [];
#     var haloData  = null;
#
#     var W = 800, H = 800;
#     var scene = new THREE.Scene();
#     scene.background = new THREE.Color(0x000000);
#     var camera = new THREE.PerspectiveCamera(50, W / H, 0.01, 1000);
#
#     var axCfg = sceneData.axisConfig;
#     var cx = (axCfg.xRange[0] + axCfg.xRange[1]) / 2;
#     var cy = (axCfg.yRange[0] + axCfg.yRange[1]) / 2;
#     var cz = (axCfg.zRange[0] + axCfg.zRange[1]) / 2;
#     var span = Math.max(

# %% [markdown]
# ## N-D Asterisk / Eikosany

# %% [markdown]
# Each spoke of the asterisk is an orthogonal axis in 5D space. MDS projects to 3D for visualization.

# %% [markdown]
# ### Asterisk N-D
#
# 5D asterisk—each spoke is an orthogonal axis.

# %%
print('GENERATING GEOMETRY: Asterisk N-D')
plot(MasterSet.asterisk_nd(), figsize=(7,7))
# Out:
# GENERATING GEOMETRY: Asterisk N-D
# <div id="klotho_3d_static_37c42b4a_wrap" style="position:relative;width:700px;background:black;">
#     <div id="klotho_3d_static_37c42b4a_title" style="
#         color:white;font-family:Arial,sans-serif;font-size:14px;
#         text-align:center;padding:8px 0 4px 0;pointer-events:none;
#         display:block;
#     ">MasterSet: asterisk_nd</div>
#     <canvas id="klotho_3d_static_37c42b4a_canvas" style="display:block;width:700px;height:700px;"></canvas>
#     <div id="klotho_3d_static_37c42b4a_tooltip" style="
#         display:none;position:absolute;pointer-events:none;top:0;left:0;
#         background:rgba(30,30,30,0.92);color:white;font-family:monospace;
#         font-size:11px;padding:6px 10px;border-radius:4px;
#         white-space:pre;max-width:300px;z-index:10;
#     "></div>
#     <div id="klotho_3d_static_37c42b4a_transport" style="
#         display:flex;align-items:center;gap:12px;
#         background:#1a1a1a;padding:4px 10px;font-family:Arial,sans-serif;
#         font-size:11px;color:#aaa;width:700px;box-sizing:border-box;
#     ">
#         <label style="display:flex;align-items:center;gap:4px;white-space:nowrap;">
#             Node size
#             <input id="klotho_3d_static_37c42b4a_nodeSize" type="range" min="0.5" max="10" step="0.5" value="2"
#                    style="width:80px;accent-color:#666;">
#         </label>
#         <span style="flex:1;"></span>
#         <button id="klotho_3d_static_37c42b4a_btnReset" style="
#             background:#222;color:#aaa;border:1px solid #444;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Reset</button>
#         <button id="klotho_3d_static_37c42b4a_btnOrbit" style="
#             background:#444;color:white;border:1px solid #666;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Orbit</button>
#         <button id="klotho_3d_static_37c42b4a_btnTrackball" style="
#             background:#222;color:#888;border:1px solid #444;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Trackball</button>
#     </div>
# </div>
# <script>
# (function _klotho3dStaticInit() {
#     if (typeof THREE === "undefined") {
#         if (!document.querySelector('script[data-klotho-three]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/build/three.min.js";
#             s.setAttribute("data-klotho-three", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#     if (!THREE.OrbitControls) {
#         if (!document.querySelector('script[data-klotho-orbit]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/examples/js/controls/OrbitControls.js";
#             s.setAttribute("data-klotho-orbit", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#     if (!THREE.TrackballControls) {
#         if (!document.querySelector('script[data-klotho-trackball]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/examples/js/controls/TrackballControls.js";
#             s.setAttribute("data-klotho-trackball", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#
#     var canvas = document.getElementById("klotho_3d_static_37c42b4a_canvas");
#     if (!canvas) { setTimeout(_klotho3dStaticInit, 50); return; }
#     var container = document.getElementById("klotho_3d_static_37c42b4a_wrap");
#     var tooltip   = document.getElementById("klotho_3d_static_37c42b4a_tooltip");
#
#     var sceneData = {"gridEdges": [[-0.022269368426736495, -0.08680421842596577, 0.22144661958906944, -2.3773304326965676, -1.1797103723482372, 0.7251748486388696], [-0.022269368426736495, -0.08680421842596577, 0.22144661958906944, -1.1086834792247886, 2.439515776740254, 0.12190282803309357], [-0.022269368426736495, -0.08680421842596577, 0.22144661958906944, 0.47900593220991944, 0.5172680905820638, -2.591263437435817], [-0.022269368426736495, -0.08680421842596577, 0.22144661958906944, 1.1947288619502756, -2.3930252430598116, -0.4031668530764557], [-0.022269368426736495, -0.08680421842596577, 0.22144661958906944, 1.834548486187898, 0.7027559665116965, 1.92590599425124]], "gridEdgeColor": "#808080", "highlightEdges": [], "nodes": [[-0.022269368426736495, -0.08680421842596577, 0.22144661958906944], [-2.3773304326965676, -1.1797103723482372, 0.7251748486388696], [-1.1086834792247886, 2.439515776740254, 0.12190282803309357], [0.47900593220991944, 0.5172680905820638, -2.591263437435817], [1.1947288619502756, -2.3930252430598116, -0.4031668530764557], [1.834548486187898, 0.7027559665116965, 1.92590599425124]], "nodeColors": ["#ffffff", "#ffffff", "#ffffff", "#ffffff", "#ffffff", "#ffffff"], "nodeSize": 2, "dimmedNodeColor": "#555555", "pathNodeIndices": [], "pathNodeColors": [], "hoverData": ["Alias: A", "Alias: B", "Alias: C", "Alias: D", "Alias: E", "Alias: F"], "axisConfig": {"xRange": [-3.0091122705292372, 2.466330324020568], "yRange": [-3.1179063960298214, 3.164396929710264], "zRange": [-3.2688388521888756, 2.6034814090042984], "xTicks": [], "yTicks": [], "zTicks": [], "labels": ["", "", ""]}};
#     var pathSteps = [];
#     var haloData  = null;
#
#     var W = 700, H = 700;
#     var scene = new THREE.Scene();
#     scene.background = new THREE.Color(0x000000);
#     var camera = new THREE.PerspectiveCamera(50, W / H, 0.01, 1000);
#
#     var axCfg = sceneData.axisConfig;
#     var cx = (axCfg.xRange[0] + axCfg.xRange[1]) / 2;
#     var cy = (axCfg.yRange[0] + axCfg.yRange[1]) / 2;
#     var cz = (axCfg.zRange[0] + axCfg.zRange[1]) / 2;
#     var span = Math.max(
#         axCfg.xRange[1] - axCfg.xRange[0],
#         axCfg.yRange[1] - axCfg.yRange[0],
#         axCfg.zRange[1] - axCfg.zRange[0]
#     );
#     var dist = (span / 2) / Math.tan(THREE.MathUtils.degToRad(camera.fov / 2));
#     dist *= 1.3;
#     camera.position.set(cx + dist * 0.6, cy + dist * 0.4, cz + dist);
#     camera.lookAt(cx, cy, cz);
#
#     var initPos = camera.position.clone();
#     var initUp = camera.up.clone();
#     var initTarget = new THREE.Vector3(cx, cy, cz);
#
#     if (canvas._klothoRenderer) {
#         try { canvas._klothoRenderer.dispose(); } catch(_) {}
#     }
#     var renderer = new THREE.WebGLRenderer({ canvas: canvas, antialias: true });
#     renderer.setSize(W, H);
#     renderer.setPixelRatio(Math.min(window.devicePixelRatio || 1, 2));
#     canvas._klothoRenderer = renderer;
#
#     function makeOrbitControls() {
#         var c = new THREE.OrbitControls(camera, renderer.domElement);
#         c.target.set(cx, cy, cz);
#         c.enableDamping = true;
#         c.dampingFactor = 0.12;
#         c.update();
#         return c;
#     }
#     function makeTrackballControls() {
#         var c = new THREE.TrackballControls(camera, renderer.domElement);
#         c.target.set(cx, cy, cz);
#         c.rotateSpeed = 2.0;
#         c.zoomSpeed = 1.2;
#         c.panSpeed = 0.8;
#         c.staticMoving = false;
#         c.dynamicDampingFactor = 0.12;
#         c.update();
#         return c;
#     }
#
#     var controls = makeOrbitControls();
#     var controlsMode = "orbit";
#
#     function switchControls(mode) {
#         if (mode === controlsMode) return;
#         var oldTarget = controls.target.clone();
#         controls.dispose();
#         if (mode === "trackball") {
#             controls = makeTrackballControls();
#         } else {
#             controls = makeOrbitControls();
#         }
#         controls.target.copy(oldTarget);
#         controls.update();
#         controlsMode = mode;
#         btnOrbit.style.background = mode === "orbit" ? "#444" : "#222";
#         btnOrbit.style.color = mode === "orbit" ? "white" : "#888";
#         btnOrbit.style.borderColor = mode === "orbit" ? "#666" : "#444";
#         btnTrackball.style.background = mode === "trackball" ?

# %%
factors = (1, 3, 5, 7, 9, 11)

for r in (2, 3):
    cps = CombinationProductSet(factors, r=r, master_set='asterisk_nd')
    n = len(cps.ratios)
    print(f'Asterisk N-D CPS  r={r}  ({n} notes)')
    if r == 2: print('  (= Pentadekany with this master set)')
    if r == 3: print('  (= Eikosany with this master set)')
    print('Ratios:', *[str(x) for x in cps.ratios])
    plot(cps, node_size=20, text_size=8, figsize=(8,8))
    print()
# Out:
# Asterisk N-D CPS  r=2  (15 notes)
#   (= Pentadekany with this master set)
# Ratios: 33/32 35/32 9/8 77/64 5/4 21/16 11/8 45/32 3/2 99/64 27/16 55/32 7/4 15/8 63/32
# <div id="klotho_3d_static_331d3e6e_wrap" style="position:relative;width:800px;background:black;">
#     <div id="klotho_3d_static_331d3e6e_title" style="
#         color:white;font-family:Arial,sans-serif;font-size:14px;
#         text-align:center;padding:8px 0 4px 0;pointer-events:none;
#         display:block;
#     ">CombinationProductSet [A B C D E F] (3D)</div>
#     <canvas id="klotho_3d_static_331d3e6e_canvas" style="display:block;width:800px;height:800px;"></canvas>
#     <div id="klotho_3d_static_331d3e6e_tooltip" style="
#         display:none;position:absolute;pointer-events:none;top:0;left:0;
#         background:rgba(30,30,30,0.92);color:white;font-family:monospace;
#         font-size:11px;padding:6px 10px;border-radius:4px;
#         white-space:pre;max-width:300px;z-index:10;
#     "></div>
#     <div id="klotho_3d_static_331d3e6e_transport" style="
#         display:flex;align-items:center;gap:12px;
#         background:#1a1a1a;padding:4px 10px;font-family:Arial,sans-serif;
#         font-size:11px;color:#aaa;width:800px;box-sizing:border-box;
#     ">
#         <label style="display:flex;align-items:center;gap:4px;white-space:nowrap;">
#             Node size
#             <input id="klotho_3d_static_331d3e6e_nodeSize" type="range" min="0.5" max="10" step="0.5" value="2"
#                    style="width:80px;accent-color:#666;">
#         </label>
#         <span style="flex:1;"></span>
#         <button id="klotho_3d_static_331d3e6e_btnReset" style="
#             background:#222;color:#aaa;border:1px solid #444;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Reset</button>
#         <button id="klotho_3d_static_331d3e6e_btnOrbit" style="
#             background:#444;color:white;border:1px solid #666;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Orbit</button>
#         <button id="klotho_3d_static_331d3e6e_btnTrackball" style="
#             background:#222;color:#888;border:1px solid #444;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Trackball</button>
#     </div>
# </div>
# <script>
# (function _klotho3dStaticInit() {
#     if (typeof THREE === "undefined") {
#         if (!document.querySelector('script[data-klotho-three]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/build/three.min.js";
#             s.setAttribute("data-klotho-three", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#     if (!THREE.OrbitControls) {
#         if (!document.querySelector('script[data-klotho-orbit]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/examples/js/controls/OrbitControls.js";
#             s.setAttribute("data-klotho-orbit", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#     if (!THREE.TrackballControls) {
#         if (!document.querySelector('script[data-klotho-trackball]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/examples/js/controls/TrackballControls.js";
#             s.setAttribute("data-klotho-trackball", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#
#     var canvas = document.getElementById("klotho_3d_static_331d3e6e_canvas");
#     if (!canvas) { setTimeout(_klotho3dStaticInit, 50); return; }
#     var container = document.getElementById("klotho_3d_static_331d3e6e_wrap");
#     var tooltip   = document.getElementById("klotho_3d_static_331d3e6e_tooltip");
#
#     var sceneData = {"gridEdges": [[-0.3076151052585053, -1.6595101014394193, 0.18010553474976376, -0.06995397154977134, -0.8343423041848337, 0.9826003301361603], [-0.3076151052585053, -1.6595101014394193, 0.18010553474976376, -0.5544238687331531, -1.070869574582939, -0.6016025770993756], [-0.06995397154977134, -0.8343423041848337, 0.9826003301361603, -0.3076151052585053, -1.6595101014394193, 0.18010553474976376], [-0.06995397154977134, -0.8343423041848337, 0.9826003301361603, -1.0115752510413463, 0.011178856728477505, 1.312831935509848], [-0.06995397154977134, -0.8343423041848337, 0.9826003301361603, 0.7796532375775623, -0.3261314077710059, -1.2636469675975834], [-0.06995397154977134, -0.8343423041848337, 0.9826003301361603, 1.0309384235071726, -0.32339623125830497, 1.2892814160790755], [-0.5544238687331531, -1.070869574582939, -0.6016025770993756, -0.3076151052585053, -1.6595101014394193, 0.18010553474976376], [-0.5544238687331531, -1.070869574582939, -0.6016025770993756, -0.4216711048131002, -0.2624805890315543, -1.6019569282591537], [-0.5544238687331531, -1.070869574582939, -0.6016025770993756, -1.6230905583444928, -0.25875304605081717, -0.16234749610720425], [-0.5544238687331531, -1.070869574582939, -0.6016025770993756, 1.249962268694129, -0.9787062208056404, 0.01367278862804527], [0.12492825320355247, 1.2921183998335075, 1.0386786195355446, -1.0301368386203626, 0.8189229495224429, 0.4727202073614132], [0.12492825320355247, 1.2921183998335075, 1.0386786195355446, 1.154648354598858, 0.47929835255946607, 0.5758098674546593], [-0.4216711048131002, -0.2624805890315543, -1.6019569282591537, -0.5544238687331531, -1.070869574582939, -0.6016025770993756], [-0.4216711048131002, -0.2624805890315543, -1.6019569282591537, 0.2004990665096163, 0.7581890202576098, -1.1335564227672432], [-1.0115752510413463, 0.011178856728477505, 1.312831935509848, -0.06995397154977134, -0.8343423041848337, 0.9826003301361603], [-1.0115752510413463, 0.011178856728477505, 1.312831935509848, -1.0301368386203626, 0.8189229495224429, 0.4727202073614132], [-0.7878623651933753, 1.3565619033687863, -0.603595862657994, -1.0301368386203626, 0.8189229495224429, 0.4727202073614132], [-0.7878623651933753, 1.3565619033687863, -0.603595862657994, 0.2004990665096163, 0.7581890202576098, -1.1335564227672432], [-1.0301368386203626, 0.8189229495224429, 0.4727202073614132, 0.12492825320355247, 1.2921183998335075, 1.0386786195355446], [-1.0301368386203626, 0.8189229495224429, 0.4727202073614132, -1.0115752510413463, 0.011178856728477505, 1.312831935509848], [-1.0301368386203626, 0.8189229495224429, 0.4727202073614132, -0.7878623651933753, 1.3565619033687863, -0.603595862657994], [-1.0301368386203626, 0.8189229495224429, 0.4727202073614132, -1.6230905583444928, -0.25875304605081717, -0.16234749610720425], [1.2656994594632165, 0.9979199928542246, -0.4989944449659548, 1.154648354598858, 0.47929835255946607, 0.5758098674546593], [1.2656994594632165, 0.9979199928542246, -0.4989944449659548, 0.2004990665096163, 0.7581890202576098, -1.1335564227672432], [0.7796532375775623, -0.3261314077710059, -1.2636469675975834, -0.06995397154977134, -0.8343423041848337, 0.9826003301361603], [0.7796532375775623, -0.3261314077710059, -1.2636469675975834, 0.2004990665096163, 0.7581890202576098, -1.1335564227672432], [-1.6230905583444928, -0.25875304605081717, -0.16234749610720425, -0.5544238687331531, -1.070869574582939, -0.6016025770993756], [-1.6230905583444928, -0.25875304605081717, -0.16234749610720425, -1.0301368386203626, 0.8189229495224429, 0.4727202073614132], [1.154648354598858, 0.47929835255946607, 0.5758098674546593, 0.12492825320355247, 1.2921183998335075, 1.0386786195355446], [1.154648354598858, 0.47929835255946607, 0.5758098674546593, 1.2656994594632165, 0.9979199928542246, -0.4989944449659548], [1.154648354598858, 0.47929835255946607, 0.5758098674546593, 1.0309384235071726, -0.32339623125830497, 1.2892814160790755], [1.154648354598858, 0.47929835255946607, 0.5758098674546593, 1.249 ...
# Asterisk N-D CPS  r=3  (20 notes)
#   (= Eikosany with this master set)
# Ratios: 33/32 135/128 35/32 297/256 77/64 315/256 165/128 21/16 693/512 45/32 189/128 385/256 99/64 105/64 27/16 55/32 231/128 15/8 495/256 63/32
# <div id="klotho_3d_static_4dfb6e95_wrap" style="position:relative;width:800px;background:black;">
#     <div id="klotho_3d_static_4dfb6e95_title" style="
#         color:white;font-family:Arial,sans-serif;font-size:14px;
#         text-align:center;padding:8px 0 4px 0;pointer-events:none;
#         display:block;
#     ">CombinationProductSet [A B C D E F] (3D)</div>
#     <canvas id="klotho_3d_static_4dfb6e95_canvas" style="display:block;width:800px;height:800px;"></canvas>
#     <div id="klotho_3d_static_4dfb6e95_tooltip" style="
#         display:none;position:absolute;pointer-events:none;top:0;left:0;
#         background:rgba(30,30,30,0.92);color:white;font-family:monospace;
#         font-size:11px;padding:6px 10px;border-radius:4px;
#         white-space:pre;max-width:300px;z-index:10;
#     "></div>
#     <div id="klotho_3d_static_4dfb6e95_transport" style="
#         display:flex;align-items:center;gap:12px;
#         background:#1a1a1a;padding:4px 10px;font-family:Arial,sans-serif;
#         font-size:11px;color:#aaa;width:800px;box-sizing:border-box;
#     ">
#         <label style="display:flex;align-items:center;gap:4px;white-space:nowrap;">
#             Node size
#             <input id="klotho_3d_static_4dfb6e95_nodeSize" type="range" min="0.5" max="10" step="0.5" value="2"
#                    style="width:80px;accent-color:#666;">
#         </label>
#         <span style="flex:1;"></span>
#         <button id="klotho_3d_static_4dfb6e95_btnReset" style="
#             background:#222;color:#aaa;border:1px solid #444;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Reset</button>
#         <button id="klotho_3d_static_4dfb6e95_btnOrbit" style="
#             background:#444;color:white;border:1px solid #666;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Orbit</button>
#         <button id="klotho_3d_static_4dfb6e95_btnTrackball" style="
#             background:#222;color:#888;border:1px solid #444;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Trackball</button>
#     </div>
# </div>
# <script>
# (function _klotho3dStaticInit() {
#     if (typeof THREE === "undefined") {
#         if (!document.querySelector('script[data-klotho-three]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/build/three.min.js";
#             s.setAttribute("data-klotho-three", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#     if (!THREE.OrbitControls) {
#         if (!document.querySelector('script[data-klotho-orbit]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/examples/js/controls/OrbitControls.js";
#             s.setAttribute("data-klotho-orbit", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#     if (!THREE.TrackballControls) {
#         if (!document.querySelector('script[data-klotho-trackball]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/examples/js/controls/TrackballControls.js";
#             s.setAttribute("data-klotho-trackball", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#
#     var canvas = document.getElementById("klotho_3d_static_4dfb6e95_canvas");
#     if (!canvas) { setTimeout(_klotho3dStaticInit, 50); return; }
#     var container = document.getElementById("klotho_3d_static_4dfb6e95_wrap");
#     var tooltip   = document.getElementById("klotho_3d_static_4dfb6e95_tooltip");
#
#     var sceneData = {"gridEdges": [[0.3238725475288471, 0.6577776569382062, 2.0358906783716586, 0.9929522587570183, 1.7802138971121675, 0.7990959229093744], [0.3238725475288471, 0.6577776569382062, 2.0358906783716586, -0.9368805964548866, -1.3948135135981756, 1.2581164356227699], [0.3238725475288471, 0.6577776569382062, 2.0358906783716586, -0.13432304872924652, -0.04738666391587137, 2.252421606008136], [2.141436257383799, 0.2808063120163192, 0.44035618821040123, 1.011786280552818, 1.4153881720936976, -1.176948797728164], [2.141436257383799, 0.2808063120163192, 0.44035618821040123, 2.144231389938628, 0.4517493875043835, -0.4656188323065605], [2.141436257383799, 0.2808063120163192, 0.44035618821040123, 1.3933246006926543, -0.8907219516298875, 1.4792342412935493], [-0.7634147846669543, 2.0409967957148667, 0.2902497453110037, 1.011786280552818, 1.4153881720936976, -1.176948797728164], [-0.7634147846669543, 2.0409967957148667, 0.2902497453110037, -0.4720584341909224, 2.1088562436575367, -0.6056273505756454], [-0.7634147846669543, 2.0409967957148667, 0.2902497453110037, -1.5093625792250414, 0.8832833648321583, 1.3595020823506898], [1.011786280552818, 1.4153881720936976, -1.176948797728164, 2.141436257383799, 0.2808063120163192, 0.44035618821040123], [1.011786280552818, 1.4153881720936976, -1.176948797728164, -0.7634147846669543, 2.0409967957148667, 0.2902497453110037], [1.011786280552818, 1.4153881720936976, -1.176948797728164, -0.31208100884138595, -0.674843207206772, -2.032700036414524], [0.9929522587570183, 1.7802138971121675, 0.7990959229093744, 0.3238725475288471, 0.6577776569382062, 2.0358906783716586], [0.9929522587570183, 1.7802138971121675, 0.7990959229093744, 2.144231389938628, 0.4517493875043835, -0.4656188323065605], [0.9929522587570183, 1.7802138971121675, 0.7990959229093744, -0.4720584341909224, 2.1088562436575367, -0.6056273505756454], [2.144231389938628, 0.4517493875043835, -0.4656188323065605, 2.141436257383799, 0.2808063120163192, 0.44035618821040123], [2.144231389938628, 0.4517493875043835, -0.4656188323065605, 0.9929522587570183, 1.7802138971121675, 0.7990959229093744], [2.144231389938628, 0.4517493875043835, -0.4656188323065605, 1.482918783828605, -0.902751566107246, -1.375087455740061], [0.4185770677080014, -2.131716078116021, 0.5649800034497118, 1.3933246006926543, -0.8907219516298875, 1.4792342412935493], [0.4185770677080014, -2.131716078116021, 0.5649800034497118, -1.0403574908471869, -1.75449429113216, -0.8048378147087313], [0.4185770677080014, -2.131716078116021, 0.5649800034497118, 0.778121007908211, -2.0374429728114154, -0.2721256509901563], [-0.4720584341909224, 2.1088562436575367, -0.6056273505756454, -0.7634147846669543, 2.0409967957148667, 0.2902497453110037], [-0.4720584341909224, 2.1088562436575367, -0.6056273505756454, 0.9929522587570183, 1.7802138971121675, 0.7990959229093744], [-0.4720584341909224, 2.1088562436575367, -0.6056273505756454, -1.3645188220660553, 0.9024379441458588, -1.498858687821723], [-2.1300193802112717, -0.5583493196443382, 0.42885030421116027, -1.0403574908471869, -1.75449429113216, -0.8048378147087313], [-2.1300193802112717, -0.5583493196443382, 0.42885030421116027, -2.1486484320848223, -0.20940688588415524, -0.42530772055065874], [-2.1300193802112717, -0.5583493196443382, 0.42885030421116027, -1.5093625792250414, 0.8832833648321583, 1.3595020823506898], [-1.3645188220660553, 0.9024379441458588, -1.498858687821723, -0.4720584341909224, 2.1088562436575367, -0.6056273505756454], [-1.3645188220660553, 0.9024379441458588, -1.498858687821723, -2.1486484320848223, -0.20940688588415524, -0.42530772055065874], [-1.3645188220660553, 0.9024379441458588, -1.498858687821723, 0.12444438301919306, 0.08041667603084911, -2.2515848609022298], [1.3933246006926543, -0.8907219516298875, 1.4792342412935493, 2.141436257383799, 0.2808063120163192, 0.44035618821040123], [1.3933246006926543, -0.8907219516298875, 1.4792342412935493, 0.4185770677080014, -2.131716078116021, 0.5649800034497118], [1.39332 ...

# %% [markdown]
# ## N-D Ogdoad / Hebdomekontany

# %% [markdown]
# ### Ogdoad N-D
#
# 7D ogdoad—each spoke is an orthogonal axis.

# %%
print('GENERATING GEOMETRY: Ogdoad N-D')
plot(MasterSet.ogdoad_nd(), figsize=(7,7))
# Out:
# GENERATING GEOMETRY: Ogdoad N-D
# <div id="klotho_3d_static_2b299c63_wrap" style="position:relative;width:700px;background:black;">
#     <div id="klotho_3d_static_2b299c63_title" style="
#         color:white;font-family:Arial,sans-serif;font-size:14px;
#         text-align:center;padding:8px 0 4px 0;pointer-events:none;
#         display:block;
#     ">MasterSet: ogdoad_nd</div>
#     <canvas id="klotho_3d_static_2b299c63_canvas" style="display:block;width:700px;height:700px;"></canvas>
#     <div id="klotho_3d_static_2b299c63_tooltip" style="
#         display:none;position:absolute;pointer-events:none;top:0;left:0;
#         background:rgba(30,30,30,0.92);color:white;font-family:monospace;
#         font-size:11px;padding:6px 10px;border-radius:4px;
#         white-space:pre;max-width:300px;z-index:10;
#     "></div>
#     <div id="klotho_3d_static_2b299c63_transport" style="
#         display:flex;align-items:center;gap:12px;
#         background:#1a1a1a;padding:4px 10px;font-family:Arial,sans-serif;
#         font-size:11px;color:#aaa;width:700px;box-sizing:border-box;
#     ">
#         <label style="display:flex;align-items:center;gap:4px;white-space:nowrap;">
#             Node size
#             <input id="klotho_3d_static_2b299c63_nodeSize" type="range" min="0.5" max="10" step="0.5" value="2"
#                    style="width:80px;accent-color:#666;">
#         </label>
#         <span style="flex:1;"></span>
#         <button id="klotho_3d_static_2b299c63_btnReset" style="
#             background:#222;color:#aaa;border:1px solid #444;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Reset</button>
#         <button id="klotho_3d_static_2b299c63_btnOrbit" style="
#             background:#444;color:white;border:1px solid #666;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Orbit</button>
#         <button id="klotho_3d_static_2b299c63_btnTrackball" style="
#             background:#222;color:#888;border:1px solid #444;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Trackball</button>
#     </div>
# </div>
# <script>
# (function _klotho3dStaticInit() {
#     if (typeof THREE === "undefined") {
#         if (!document.querySelector('script[data-klotho-three]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/build/three.min.js";
#             s.setAttribute("data-klotho-three", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#     if (!THREE.OrbitControls) {
#         if (!document.querySelector('script[data-klotho-orbit]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/examples/js/controls/OrbitControls.js";
#             s.setAttribute("data-klotho-orbit", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#     if (!THREE.TrackballControls) {
#         if (!document.querySelector('script[data-klotho-trackball]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/examples/js/controls/TrackballControls.js";
#             s.setAttribute("data-klotho-trackball", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#
#     var canvas = document.getElementById("klotho_3d_static_2b299c63_canvas");
#     if (!canvas) { setTimeout(_klotho3dStaticInit, 50); return; }
#     var container = document.getElementById("klotho_3d_static_2b299c63_wrap");
#     var tooltip   = document.getElementById("klotho_3d_static_2b299c63_tooltip");
#
#     var sceneData = {"gridEdges": [[0.025665197922065414, 0.09108254793640105, -0.027852364482537643, 0.6453015637225, -1.73881620740174, -2.0252926228362638], [0.025665197922065414, 0.09108254793640105, -0.027852364482537643, -0.8975239458889852, 2.631676683352749, -0.05665034151967744], [0.025665197922065414, 0.09108254793640105, -0.027852364482537643, 1.0387585173327205, -2.192980833148462, 1.2958661730267602], [0.025665197922065414, 0.09108254793640105, -0.027852364482537643, 2.3464262590604634, 1.0221008304329697, -1.1050819431365628], [0.025665197922065414, 0.09108254793640105, -0.027852364482537643, -2.1722421135873606, -0.8987760740195034, 1.4548320745658019], [0.025665197922065414, 0.09108254793640105, -0.027852364482537643, 1.0424446714328146, 1.0664330567543039, 2.3233548333412197], [0.025665197922065414, 0.09108254793640105, -0.027852364482537643, -2.028830149994217, 0.01927999609328122, -1.85917580895874]], "gridEdgeColor": "#808080", "highlightEdges": [], "nodes": [[0.025665197922065414, 0.09108254793640105, -0.027852364482537643], [0.6453015637225, -1.73881620740174, -2.0252926228362638], [-0.8975239458889852, 2.631676683352749, -0.05665034151967744], [1.0387585173327205, -2.192980833148462, 1.2958661730267602], [2.3464262590604634, 1.0221008304329697, -1.1050819431365628], [-2.1722421135873606, -0.8987760740195034, 1.4548320745658019], [1.0424446714328146, 1.0664330567543039, 2.3233548333412197], [-2.028830149994217, 0.01927999609328122, -1.85917580895874]], "nodeColors": ["#ffffff", "#ffffff", "#ffffff", "#ffffff", "#ffffff", "#ffffff", "#ffffff", "#ffffff"], "nodeSize": 2, "dimmedNodeColor": "#555555", "pathNodeIndices": [], "pathNodeColors": [], "hoverData": ["Alias: A", "Alias: B", "Alias: C", "Alias: D", "Alias: E", "Alias: F", "Alias: G", "Alias: H"], "axisConfig": {"xRange": [-2.8500423694845343, 3.024226514957637], "yRange": [-2.916679460623644, 3.355375310827931], "zRange": [-2.677589741262886, 2.9756519517678424], "xTicks": [], "yTicks": [], "zTicks": [], "labels": ["", "", ""]}};
#     var pathSteps = [];
#     var haloData  = null;
#
#     var W = 700, H = 700;
#     var scene = new THREE.Scene();
#     scene.background = new THREE.Color(0x000000);
#     var camera = new THREE.PerspectiveCamera(50, W / H, 0.01, 1000);
#
#     var axCfg = sceneData.axisConfig;
#     var cx = (axCfg.xRange[0] + axCfg.xRange[1]) / 2;
#     var cy = (axCfg.yRange[0] + axCfg.yRange[1]) / 2;
#     var cz = (axCfg.zRange[0] + axCfg.zRange[1]) / 2;
#     var span = Math.max(
#         axCfg.xRange[1] - axCfg.xRange[0],
#         axCfg.yRange[1] - axCfg.yRange[0],
#         axCfg.zRange[1] - axCfg.zRange[0]
#     );
#     var dist = (span / 2) / Math.tan(THREE.MathUtils.degToRad(camera.fov / 2));
#     dist *= 1.3;
#     camera.position.set(cx + dist * 0.6, cy + dist * 0.4, cz + dist);
#     camera.lookAt(cx, cy, cz);
#
#     var initPos = camera.position.clone();
#     var initUp = camera.up.clone();
#     var initTarget = new THREE.Vector3(cx, cy, cz);
#
#     if (canvas._klothoRenderer) {
#         try { canvas._klothoRenderer.dispose(); } catch(_) {}
#     }
#     var renderer = new THREE.WebGLRenderer({ canvas: canvas, antialias: true });
#     renderer.setSize(W, H);
#     renderer.setPixelRatio(Math.min(window.devicePixelRatio || 1, 2));
#     canvas._klothoRenderer = renderer;
#
#     function makeOrbitControls() {
#         var c = new THREE.OrbitControls(camera, renderer.domElement);
#         c.target.set(cx, cy, cz);
#         c.enableDamping = true;
#         c.dampingFactor = 0.12;
#         c.update();
#         return c;
#     }
#     function makeTrackballControls() {
#         var c = new THREE.TrackballControls(camera, renderer.domElement);
#         c.target.set(cx, cy, cz);
#         c.rotateSpeed = 2.0;
#         c.zoomSpeed = 1.2;
#         c.panSpeed = 0.8;
#         c.staticMoving = false;
#         c.dynamicDampingFactor = 0.12;
#         c.update();
#         return c;
#     }
#
#     var controls = makeOrbitControls();
#     var controlsMode = "orbit";
#
#     function switchControls(mode) {
#         if (mode === controlsMode) return;
#         var oldTarget = controls.target.clone();
#         controls.dispose();
#         if (mode === "trackball") {
#             controls = makeTrackballControls();
#         } else {

# %%
factors = (1, 3, 5, 7, 9, 11, 13, 17)

for r in (4,):
    cps = CombinationProductSet(factors, r=r, master_set='ogdoad_nd')
    n = len(cps.ratios)
    print(f'Ogdoad N-D CPS  r={r}  ({n} notes)')
    if r == 4: print('  (= Hebdomekontany with this master set)')
    print('Ratios:', *[str(x) for x in cps.ratios])
    plot(cps, node_size=15, text_size=5, figsize=(8,8))
    print()
# Out:
# Ogdoad N-D CPS  r=4  (70 notes)
#   (= Hebdomekontany with this master set)
# Ratios: 2079/2048 8415/8192 17017/16384 1071/1024 2145/2048 135/128 273/256 1105/1024 561/512 9009/8192 2295/2048 1155/1024 4641/4096 585/512 297/256 595/512 2431/2048 2457/2048 9945/8192 5005/4096 315/256 5049/4096 1287/1024 1309/1024 165/128 663/512 5355/4096 1365/1024 21879/16384 693/512 2805/2048 351/256 357/256 715/512 11781/8192 1485/1024 5967/4096 3003/2048 189/128 12155/8192 765/512 385/256 1547/1024 195/128 3213/2048 6435/4096 6545/4096 819/512 3315/2048 105/64 1683/1024 429/256 3465/2048 13923/8192 1755/1024 1785/1024 455/256 7293/4096 459/256 231/128 935/512 945/512 3861/2048 7735/4096 3927/2048 495/256 1989/1024 1001/512 255/128 4095/2048
# <div id="klotho_3d_static_2b8f963e_wrap" style="position:relative;width:800px;background:black;">
#     <div id="klotho_3d_static_2b8f963e_title" style="
#         color:white;font-family:Arial,sans-serif;font-size:14px;
#         text-align:center;padding:8px 0 4px 0;pointer-events:none;
#         display:block;
#     ">CombinationProductSet [A B C D E F G H] (3D)</div>
#     <canvas id="klotho_3d_static_2b8f963e_canvas" style="display:block;width:800px;height:800px;"></canvas>
#     <div id="klotho_3d_static_2b8f963e_tooltip" style="
#         display:none;position:absolute;pointer-events:none;top:0;left:0;
#         background:rgba(30,30,30,0.92);color:white;font-family:monospace;
#         font-size:11px;padding:6px 10px;border-radius:4px;
#         white-space:pre;max-width:300px;z-index:10;
#     "></div>
#     <div id="klotho_3d_static_2b8f963e_transport" style="
#         display:flex;align-items:center;gap:12px;
#         background:#1a1a1a;padding:4px 10px;font-family:Arial,sans-serif;
#         font-size:11px;color:#aaa;width:800px;box-sizing:border-box;
#     ">
#         <label style="display:flex;align-items:center;gap:4px;white-space:nowrap;">
#             Node size
#             <input id="klotho_3d_static_2b8f963e_nodeSize" type="range" min="0.5" max="10" step="0.5" value="2"
#                    style="width:80px;accent-color:#666;">
#         </label>
#         <span style="flex:1;"></span>
#         <button id="klotho_3d_static_2b8f963e_btnReset" style="
#             background:#222;color:#aaa;border:1px solid #444;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Reset</button>
#         <button id="klotho_3d_static_2b8f963e_btnOrbit" style="
#             background:#444;color:white;border:1px solid #666;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Orbit</button>
#         <button id="klotho_3d_static_2b8f963e_btnTrackball" style="
#             background:#222;color:#888;border:1px solid #444;border-radius:3px;
#             padding:1px 8px;font-size:11px;cursor:pointer;
#         ">Trackball</button>
#     </div>
# </div>
# <script>
# (function _klotho3dStaticInit() {
#     if (typeof THREE === "undefined") {
#         if (!document.querySelector('script[data-klotho-three]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/build/three.min.js";
#             s.setAttribute("data-klotho-three", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#     if (!THREE.OrbitControls) {
#         if (!document.querySelector('script[data-klotho-orbit]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/examples/js/controls/OrbitControls.js";
#             s.setAttribute("data-klotho-orbit", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#     if (!THREE.TrackballControls) {
#         if (!document.querySelector('script[data-klotho-trackball]')) {
#             var s = document.createElement("script");
#             s.src = "https://unpkg.com/three@0.147.0/examples/js/controls/TrackballControls.js";
#             s.setAttribute("data-klotho-trackball", "1");
#             (document.head || document.documentElement).appendChild(s);
#         }
#         setTimeout(_klotho3dStaticInit, 100);
#         return;
#     }
#
#     var canvas = document.getElementById("klotho_3d_static_2b8f963e_canvas");
#     if (!canvas) { setTimeout(_klotho3dStaticInit, 50); return; }
#     var container = document.getElementById("klotho_3d_static_2b8f963e_wrap");
#     var tooltip   = document.getElementById("klotho_3d_static_2b8f963e_tooltip");
#
#     var sceneData = {"gridEdges": [[2.1874825884697993, -1.3296737502651763, -0.6147609873141853, 1.3536739645530254, -2.172291835229724, 0.6895117127170083], [2.1874825884697993, -1.3296737502651763, -0.6147609873141853, 2.4564285289840155, 0.7793460059426635, 0.08000274293545535], [2.1874825884697993, -1.3296737502651763, -0.6147609873141853, 2.32694365562366, -0.8264504282805504, -0.6042165488493643], [2.1874825884697993, -1.3296737502651763, -0.6147609873141853, 1.2481270235014392, -1.3525181329916924, -1.9799091369787598], [2.4799666395626527, -0.19594283880875255, -0.5579944391193595, 2.32694365562366, -0.8264504282805504, -0.6042165488493643], [2.4799666395626527, -0.19594283880875255, -0.5579944391193595, 1.5834133236799153, -1.305201516735973, 1.448520489392269], [2.4799666395626527, -0.19594283880875255, -0.5579944391193595, 1.7282574461095288, 1.9885120598680202, 0.2523563316494313], [2.4799666395626527, -0.19594283880875255, -0.5579944391193595, 1.04540545550696, -0.12338531734171075, -2.4069907134404036], [-0.6649630898993174, -0.6197883542373483, -1.8044446424996161, -1.0895748701547168, -0.38447281747994605, -2.402939032147321], [-0.6649630898993174, -0.6197883542373483, -1.8044446424996161, -0.44071248434585697, 2.469813284088765, 0.0637450733659584], [-0.6649630898993174, -0.6197883542373483, -1.8044446424996161, 2.32694365562366, -0.8264504282805504, -0.6042165488493643], [-0.6649630898993174, -0.6197883542373483, -1.8044446424996161, -1.5231821475599914, -1.6552629535364838, 1.1822499825357518], [-1.0895748701547168, -0.38447281747994605, -2.402939032147321, -0.6649630898993174, -0.6197883542373483, -1.8044446424996161], [-1.0895748701547168, -0.38447281747994605, -2.402939032147321, -0.6876573970429014, -0.9988463525526409, -2.4016993088093943], [-1.0895748701547168, -0.38447281747994605, -2.402939032147321, -0.7745926215108948, 0.2429891001340667, -2.490243851995589], [-1.0895748701547168, -0.38447281747994605, -2.402939032147321, -1.6932955176664524, -0.21753318434466612, -1.9366817424764977], [0.6195696360676572, -2.3421508844360455, -0.7998716874355075, 0.4380719542779894, -2.4713732393808363, -0.040923566352475495], [0.6195696360676572, -2.3421508844360455, -0.7998716874355075, 1.6914766527150042, -1.69261563855071, 1.0272095569554445], [0.6195696360676572, -2.3421508844360455, -0.7998716874355075, -1.6828114426536476, -1.5899780626186082, -1.0795813364214044], [0.6195696360676572, -2.3421508844360455, -0.7998716874355075, 1.6044099430562955, -0.6483828092663532, -2.0286277461527193], [-1.6741358502626524, -1.0552193717590097, 1.3880815540734548, -2.2304926160374134, -0.8565932887861669, -0.933394089963273], [-1.6741358502626524, -1.0552193717590097, 1.3880815540734548, 1.5834133236799153, -1.305201516735973, 1.448520489392269], [-1.6741358502626524, -1.0552193717590097, 1.3880815540734548, -1.0545942833313127, 1.6982873663122842, 1.6345578168233348], [-1.6741358502626524, -1.0552193717590097, 1.3880815540734548, -1.5231821475599914, -1.6552629535364838, 1.1822499825357518], [1.3044681959135618, 1.3898318313846005, -1.8202461732150133, 1.5188826569926586, 1.6458273982451692, -1.1967451981410007], [1.3044681959135618, 1.3898318313846005, -1.8202461732150133, 1.6044099430562955, -0.6483828092663532, -2.0286277461527193], [1.3044681959135618, 1.3898318313846005, -1.8202461732150133, 2.2608064661389666, 1.372946601072045, 0.06174068861614195], [1.3044681959135618, 1.3898318313846005, -1.8202461732150133, -0.3271656923251805, 1.780299366709994, -1.887315285753108], [2.2251963743604857, 0.8653098690497836, 0.9307687491003513, 1.6787258762035677, 1.0448328838180456, -1.3923582328389839], [2.2251963743604857, 0.8653098690497836, 0.9307687491003513, 2.4564285289840155, 0.7793460059426635, 0.08000274293545535], [2.2251963743604857, 0.8653098690497836, 0.9307687491003513, 0.8057144660512033, -0.24794505743647252, 2.492965061842597], [2.2251963743604857, 0.8653098690497836, 0.9307687491003513, 1.6742293040103808,  ...
