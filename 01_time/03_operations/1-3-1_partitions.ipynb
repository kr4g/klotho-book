# %% [markdown]
# ---
# jupyter: false
# ---
#
# # 01 | Rhythm and Time | 04 | Partitions

# %%
from klotho import Tree, RhythmTree as RT, plot, play
from klotho.topos import PartitionSet as PS
from fractions import Fraction
import numpy as np
# Out:
# <script>
# if (!globalThis.__klothoSonic) {
#     globalThis.__klothoSonic = { instance: null, promise: null, loadedDefs: new Set() };
#     globalThis.__klothoSonic.promise = (async function() {
#         try {
#             var config = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
#             var mod = await import("https://unpkg.com/supersonic-scsynth@latest");
#             globalThis.SuperSonic = mod.SuperSonic;
#             var sonic = new mod.SuperSonic(config);
#             await sonic.init();
#             try { await sonic.loadSynthDef("sonic-pi-beep"); } catch(e) {}
#             globalThis.__klothoSonic.instance = sonic;
#             return sonic;
#         } catch(e) {
#             console.warn("[Klotho] SuperSonic session boot failed:", e);
#             globalThis.__klothoSonic.promise = null;
#             return null;
#         }
#     })();
# }
# </script>

# %% [markdown]
# ## Basic Intuitions

# %%
PS(8, 3)
# Out:
# ------------------------------------------
# PS(n=8, k=3) - Graph: feature_distance
# Mean: ~2.6667
# ------------------------------------------
#    partition  unique_count  span  variance
# 0  (6, 1, 1)             2     5    5.5556
# 1  (5, 2, 1)             3     4    2.8889
# 2  (4, 3, 1)             3     3    1.5556
# 3  (4, 2, 2)             2     2    0.8889
# 4  (3, 3, 2)             2     1    0.2222
# ------------------------------------------

# %% [markdown]
# `PS(n, k)` generates all the ways to partition the integer `n` into exactly `k` parts. The table is sorted from most uneven (highest variance) to most even (lowest variance).
#
# So `PS(8, 3)` answers the question: *what are all the ways to divide 8 beats into 3 groups?*
#
# Let's hear what each partition sounds like as a rhythm:

# %% [markdown]
# ### Common Patterns

# %%
for p in PS(8, 3).partitions:
    rt = RT(subdivisions=p)
    print(f"S = {p}")
    print(f"{' + '.join(str(f) for f in rt.durations)} = {sum(rt.durations)}")
    plot(rt, layout='ratios').play(bpm=126, beat='1/4')
    print()
# Out:
# S = (6, 1, 1)
# 3/4 + 1/8 + 1/8 = 1
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_3ebb9008_r0" x="0.00" y="20.00" width="825.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_3ebb9008"/>
# <rect id="svgrt_3ebb9008_r1" x="825.00" y="20.00" width="137.50" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_3ebb9008"/>
# <rect id="svgrt_3ebb9008_r2" x="962.50" y="20.00" width="137.50" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_3ebb9008"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="825.00" y1="10.00" x2="825.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="962.50" y1="10.00" x2="962.50" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_3ebb9008_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_3ebb9008_r0_h" cx="412.5000" cy="25.0000" rx="680.6250" ry="15.0000" fill="url(#svgrt_3ebb9008_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_3ebb9008_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_3ebb9008_r1_h" cx="893.7500" cy="25.0000" rx="113.4375" ry="15.0000" fill="url(#svgrt_3ebb9008_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_3ebb9008_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_3ebb9008_r2_h" cx="1031.2500" cy="25.0000" rx="113.4375" ry="15.0000" fill="url(#svgrt_3ebb9008_r2_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_3ebb9008_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_3ebb9008(){
#     var data=["Node: 1\nProportion: 6\nMetric Onset: 0\nMetric Duration: 3/4", "Node: 2\nProportion: 1\nMetric Onset: 3/4\nMetric Duration: 1/8", "Node: 3\nProportion: 1\nMetric Onset: 7/8\nMetric Duration: 1/8"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_3ebb9008_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_3ebb9008,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_3ebb9008']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_3ebb9008,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_7347754c_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_7347754c_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_7347754c_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_7347754c_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_7347754c_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
# var __klothoManifest = {
#   "synths": {
#     "sonic-pi-beep": { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_synth":      { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_sine":       { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_perc":       { "releaseMode": "free" }
#   },
#   "inserts": {
#     "__busRouter":        { "inParam": "inBus", "outParam": "outBus" },
#     "__busRouterMonitor": { "inParam": "inBus", "outParam": "outBus" }
#   }
# }
# ;
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (state && state.instance) return Promise.resolve(state.instance);
#         if (state && state.promise) return state.promise;
#         if
# S = (5, 2, 1)
# 5/8 + 1/4 + 1/8 = 1
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_d3f301a1_r0" x="0.00" y="20.00" width="687.50" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_d3f301a1"/>
# <rect id="svgrt_d3f301a1_r1" x="687.50" y="20.00" width="275.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_d3f301a1"/>
# <rect id="svgrt_d3f301a1_r2" x="962.50" y="20.00" width="137.50" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_d3f301a1"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="687.50" y1="10.00" x2="687.50" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="962.50" y1="10.00" x2="962.50" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_d3f301a1_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_d3f301a1_r0_h" cx="343.7500" cy="25.0000" rx="567.1875" ry="15.0000" fill="url(#svgrt_d3f301a1_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_d3f301a1_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_d3f301a1_r1_h" cx="825.0000" cy="25.0000" rx="226.8750" ry="15.0000" fill="url(#svgrt_d3f301a1_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_d3f301a1_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_d3f301a1_r2_h" cx="1031.2500" cy="25.0000" rx="113.4375" ry="15.0000" fill="url(#svgrt_d3f301a1_r2_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_d3f301a1_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_d3f301a1(){
#     var data=["Node: 1\nProportion: 5\nMetric Onset: 0\nMetric Duration: 5/8", "Node: 2\nProportion: 2\nMetric Onset: 5/8\nMetric Duration: 1/4", "Node: 3\nProportion: 1\nMetric Onset: 7/8\nMetric Duration: 1/8"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_d3f301a1_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_d3f301a1,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_d3f301a1']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_d3f301a1,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_f12fc397_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_f12fc397_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_f12fc397_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_f12fc397_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_f12fc397_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
# var __klothoManifest = {
#   "synths": {
#     "sonic-pi-beep": { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_synth":      { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_sine":       { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_perc":       { "releaseMode": "free" }
#   },
#   "inserts": {
#     "__busRouter":        { "inParam": "inBus", "outParam": "outBus" },
#     "__busRouterMonitor": { "inParam": "inBus", "outParam": "outBus" }
#   }
# }
# ;
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (state && state.instance) return Promise.resolve(state.instance);
#         if (state && state.promise) return state.promise;
#         if
# S = (4, 3, 1)
# 1/2 + 3/8 + 1/8 = 1
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_049f1f69_r0" x="0.00" y="20.00" width="550.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_049f1f69"/>
# <rect id="svgrt_049f1f69_r1" x="550.00" y="20.00" width="412.50" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_049f1f69"/>
# <rect id="svgrt_049f1f69_r2" x="962.50" y="20.00" width="137.50" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_049f1f69"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="550.00" y1="10.00" x2="550.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="962.50" y1="10.00" x2="962.50" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_049f1f69_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_049f1f69_r0_h" cx="275.0000" cy="25.0000" rx="453.7500" ry="15.0000" fill="url(#svgrt_049f1f69_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_049f1f69_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_049f1f69_r1_h" cx="756.2500" cy="25.0000" rx="340.3125" ry="15.0000" fill="url(#svgrt_049f1f69_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_049f1f69_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_049f1f69_r2_h" cx="1031.2500" cy="25.0000" rx="113.4375" ry="15.0000" fill="url(#svgrt_049f1f69_r2_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_049f1f69_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_049f1f69(){
#     var data=["Node: 1\nProportion: 4\nMetric Onset: 0\nMetric Duration: 1/2", "Node: 2\nProportion: 3\nMetric Onset: 1/2\nMetric Duration: 3/8", "Node: 3\nProportion: 1\nMetric Onset: 7/8\nMetric Duration: 1/8"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_049f1f69_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_049f1f69,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_049f1f69']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_049f1f69,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_f7ed1228_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_f7ed1228_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_f7ed1228_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_f7ed1228_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_f7ed1228_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
# var __klothoManifest = {
#   "synths": {
#     "sonic-pi-beep": { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_synth":      { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_sine":       { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_perc":       { "releaseMode": "free" }
#   },
#   "inserts": {
#     "__busRouter":        { "inParam": "inBus", "outParam": "outBus" },
#     "__busRouterMonitor": { "inParam": "inBus", "outParam": "outBus" }
#   }
# }
# ;
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (state && state.instance) return Promise.resolve(state.instance);
#         if (state && state.promise) return state.promise;
#         if
# S = (4, 2, 2)
# 1/2 + 1/4 + 1/4 = 1
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_bcecfa8e_r0" x="0.00" y="20.00" width="550.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_bcecfa8e"/>
# <rect id="svgrt_bcecfa8e_r1" x="550.00" y="20.00" width="275.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_bcecfa8e"/>
# <rect id="svgrt_bcecfa8e_r2" x="825.00" y="20.00" width="275.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_bcecfa8e"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="550.00" y1="10.00" x2="550.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="825.00" y1="10.00" x2="825.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_bcecfa8e_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_bcecfa8e_r0_h" cx="275.0000" cy="25.0000" rx="453.7500" ry="15.0000" fill="url(#svgrt_bcecfa8e_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_bcecfa8e_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_bcecfa8e_r1_h" cx="687.5000" cy="25.0000" rx="226.8750" ry="15.0000" fill="url(#svgrt_bcecfa8e_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_bcecfa8e_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_bcecfa8e_r2_h" cx="962.5000" cy="25.0000" rx="226.8750" ry="15.0000" fill="url(#svgrt_bcecfa8e_r2_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_bcecfa8e_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_bcecfa8e(){
#     var data=["Node: 1\nProportion: 4\nMetric Onset: 0\nMetric Duration: 1/2", "Node: 2\nProportion: 2\nMetric Onset: 1/2\nMetric Duration: 1/4", "Node: 3\nProportion: 2\nMetric Onset: 3/4\nMetric Duration: 1/4"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_bcecfa8e_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_bcecfa8e,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_bcecfa8e']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_bcecfa8e,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_cc5a28aa_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_cc5a28aa_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_cc5a28aa_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_cc5a28aa_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_cc5a28aa_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
# var __klothoManifest = {
#   "synths": {
#     "sonic-pi-beep": { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_synth":      { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_sine":       { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_perc":       { "releaseMode": "free" }
#   },
#   "inserts": {
#     "__busRouter":        { "inParam": "inBus", "outParam": "outBus" },
#     "__busRouterMonitor": { "inParam": "inBus", "outParam": "outBus" }
#   }
# }
# ;
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (state && state.instance) return Promise.resolve(state.instance);
#         if (state && state.promise) return state.promise;
#         if (
# S = (3, 3, 2)
# 3/8 + 3/8 + 1/4 = 1
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_1080222b_r0" x="0.00" y="20.00" width="412.50" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_1080222b"/>
# <rect id="svgrt_1080222b_r1" x="412.50" y="20.00" width="412.50" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_1080222b"/>
# <rect id="svgrt_1080222b_r2" x="825.00" y="20.00" width="275.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_1080222b"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="412.50" y1="10.00" x2="412.50" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="825.00" y1="10.00" x2="825.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_1080222b_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_1080222b_r0_h" cx="206.2500" cy="25.0000" rx="340.3125" ry="15.0000" fill="url(#svgrt_1080222b_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_1080222b_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_1080222b_r1_h" cx="618.7500" cy="25.0000" rx="340.3125" ry="15.0000" fill="url(#svgrt_1080222b_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_1080222b_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_1080222b_r2_h" cx="962.5000" cy="25.0000" rx="226.8750" ry="15.0000" fill="url(#svgrt_1080222b_r2_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_1080222b_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_1080222b(){
#     var data=["Node: 1\nProportion: 3\nMetric Onset: 0\nMetric Duration: 3/8", "Node: 2\nProportion: 3\nMetric Onset: 3/8\nMetric Duration: 3/8", "Node: 3\nProportion: 2\nMetric Onset: 3/4\nMetric Duration: 1/4"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_1080222b_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_1080222b,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_1080222b']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_1080222b,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_d908f2b6_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_d908f2b6_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_d908f2b6_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_d908f2b6_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_d908f2b6_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
# var __klothoManifest = {
#   "synths": {
#     "sonic-pi-beep": { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_synth":      { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_sine":       { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_perc":       { "releaseMode": "free" }
#   },
#   "inserts": {
#     "__busRouter":        { "inParam": "inBus", "outParam": "outBus" },
#     "__busRouterMonitor": { "inParam": "inBus", "outParam": "outBus" }
#   }
# }
# ;
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (state && state.instance) return Promise.resolve(state.instance);
#         if (state && state.promise) return state.promise;
#         if (

# %% [markdown]
# Notice the last partition, `(3, 3, 2)`. This is the most *even* way to divide 8 into 3. If you've studied rhythm, you might recognize it — this is the classic **3-3-2 clave** pattern, one of the most common rhythmic cells in Afro-Cuban, jazz, and popular music.
#
# It's not a coincidence that this pattern feels so "right". It's the partition of 8 into 3 groups that is closest to equal — the lowest possible variance.

# %%
rt = RT(subdivisions=(3, 3, 2))
plot(rt, layout='ratios').play(bpm=126, beat='1/4')
# Out:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_9cb8ff42_r0" x="0.00" y="20.00" width="412.50" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_9cb8ff42"/>
# <rect id="svgrt_9cb8ff42_r1" x="412.50" y="20.00" width="412.50" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_9cb8ff42"/>
# <rect id="svgrt_9cb8ff42_r2" x="825.00" y="20.00" width="275.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_9cb8ff42"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="412.50" y1="10.00" x2="412.50" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="825.00" y1="10.00" x2="825.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_9cb8ff42_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_9cb8ff42_r0_h" cx="206.2500" cy="25.0000" rx="340.3125" ry="15.0000" fill="url(#svgrt_9cb8ff42_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_9cb8ff42_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_9cb8ff42_r1_h" cx="618.7500" cy="25.0000" rx="340.3125" ry="15.0000" fill="url(#svgrt_9cb8ff42_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_9cb8ff42_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_9cb8ff42_r2_h" cx="962.5000" cy="25.0000" rx="226.8750" ry="15.0000" fill="url(#svgrt_9cb8ff42_r2_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_9cb8ff42_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_9cb8ff42(){
#     var data=["Node: 1\nProportion: 3\nMetric Onset: 0\nMetric Duration: 3/8", "Node: 2\nProportion: 3\nMetric Onset: 3/8\nMetric Duration: 3/8", "Node: 3\nProportion: 2\nMetric Onset: 3/4\nMetric Duration: 1/4"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_9cb8ff42_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_9cb8ff42,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_9cb8ff42']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_9cb8ff42,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_60ccde66_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_60ccde66_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_60ccde66_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_60ccde66_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_60ccde66_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
# var __klothoManifest = {
#   "synths": {
#     "sonic-pi-beep": { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_synth":      { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_sine":       { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_perc":       { "releaseMode": "free" }
#   },
#   "inserts": {
#     "__busRouter":        { "inParam": "inBus", "outParam": "outBus" },
#     "__busRouterMonitor": { "inParam": "inBus", "outParam": "outBus" }
#   }
# }
# ;
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (state && state.instance) return Promise.resolve(state.instance);
#         if (state && state.promise) return state.promise;
#         if (

# %% [markdown]
# ---

# %% [markdown]
# ### Beyond powers of 2
#
# `PS(8, 3)` partitions 8 — and 8 is a very "standard" number of beats. It maps cleanly onto 8th notes in 4/4 time. The same goes for 4, 16, 32, etc. These are familiar subdivisions of familiar meters.
#
# Things get more interesting when `n` is *not* a power of 2. What are all the ways to divide 5 beats into 2 groups? Or 7 into 3? Or 11 into 4?

# %%
PS(5, 2)
# Out:
# -----------------------------------------
# PS(n=5, k=2) - Graph: feature_distance
# Mean: ~2.5
# -----------------------------------------
#   partition  unique_count  span  variance
# 0    (4, 1)             2     3      2.25
# 1    (3, 2)             2     1      0.25
# -----------------------------------------

# %%
for p in PS(5, 2).partitions:
    rt = RT(subdivisions=p)
    print(f"S = {p}")
    print(f"{' + '.join(str(f) for f in rt.durations)} = {sum(rt.durations)}")
    plot(rt, layout='ratios').play(bpm=126, beat='1/4')
    print()
# Out:
# S = (4, 1)
# 4/5 + 1/5 = 1
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_b3e5a165_r0" x="0.00" y="20.00" width="880.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_b3e5a165"/>
# <rect id="svgrt_b3e5a165_r1" x="880.00" y="20.00" width="220.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_b3e5a165"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="880.00" y1="10.00" x2="880.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_b3e5a165_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_b3e5a165_r0_h" cx="440.0000" cy="25.0000" rx="726.0000" ry="15.0000" fill="url(#svgrt_b3e5a165_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_b3e5a165_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_b3e5a165_r1_h" cx="990.0000" cy="25.0000" rx="181.5000" ry="15.0000" fill="url(#svgrt_b3e5a165_r1_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_b3e5a165_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_b3e5a165(){
#     var data=["Node: 1\nProportion: 4\nMetric Onset: 0\nMetric Duration: 4/5", "Node: 2\nProportion: 1\nMetric Onset: 4/5\nMetric Duration: 1/5"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_b3e5a165_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_b3e5a165,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_b3e5a165']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_b3e5a165,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_7fcf6922_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_7fcf6922_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_7fcf6922_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_7fcf6922_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_7fcf6922_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
# var __klothoManifest = {
#   "synths": {
#     "sonic-pi-beep": { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_synth":      { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_sine":       { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_perc":       { "releaseMode": "free" }
#   },
#   "inserts": {
#     "__busRouter":        { "inParam": "inBus", "outParam": "outBus" },
#     "__busRouterMonitor": { "inParam": "inBus", "outParam": "outBus" }
#   }
# }
# ;
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (state && state.instance) return Promise.resolve(state.instance);
#         if (state && state.promise) return state.promise;
#         if (!state) {
#             state = { instance: null, promise: null, loadedDefs: new Set() };
#             globalThis.__klothoSonic = state;
#         }
#         state.promise = (async function() {
#             try {
#                 var mod = await import("https://unpkg.com/supersonic-scsynth@latest");
#                 globalThis.SuperSonic = mod.SuperSonic;
#                 var sonic = new mod.SuperSonic(__ssConfig);
#                 await sonic.init();
#                 try { await sonic.loadSynthDef("sonic-pi-beep"); } catch(e) {}
#                 state.instance = sonic;
#                 return sonic;
#             } catch(e) {
#                 state.promise = null;
#                 return null;
#             }
#         })();
#         return state.promise;
#     };
# }
# va
# S = (3, 2)
# 3/5 + 2/5 = 1
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_3efe5c97_r0" x="0.00" y="20.00" width="660.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_3efe5c97"/>
# <rect id="svgrt_3efe5c97_r1" x="660.00" y="20.00" width="440.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_3efe5c97"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="660.00" y1="10.00" x2="660.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_3efe5c97_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_3efe5c97_r0_h" cx="330.0000" cy="25.0000" rx="544.5000" ry="15.0000" fill="url(#svgrt_3efe5c97_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_3efe5c97_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_3efe5c97_r1_h" cx="880.0000" cy="25.0000" rx="363.0000" ry="15.0000" fill="url(#svgrt_3efe5c97_r1_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_3efe5c97_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_3efe5c97(){
#     var data=["Node: 1\nProportion: 3\nMetric Onset: 0\nMetric Duration: 3/5", "Node: 2\nProportion: 2\nMetric Onset: 3/5\nMetric Duration: 2/5"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_3efe5c97_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_3efe5c97,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_3efe5c97']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_3efe5c97,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_192ae00d_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_192ae00d_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_192ae00d_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_192ae00d_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_192ae00d_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
# var __klothoManifest = {
#   "synths": {
#     "sonic-pi-beep": { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_synth":      { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_sine":       { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_perc":       { "releaseMode": "free" }
#   },
#   "inserts": {
#     "__busRouter":        { "inParam": "inBus", "outParam": "outBus" },
#     "__busRouterMonitor": { "inParam": "inBus", "outParam": "outBus" }
#   }
# }
# ;
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (state && state.instance) return Promise.resolve(state.instance);
#         if (state && state.promise) return state.promise;
#         if (!state) {
#             state = { instance: null, promise: null, loadedDefs: new Set() };
#             globalThis.__klothoSonic = state;
#         }
#         state.promise = (async function() {
#             try {
#                 var mod = await import("https://unpkg.com/supersonic-scsynth@latest");
#                 globalThis.SuperSonic = mod.SuperSonic;
#                 var sonic = new mod.SuperSonic(__ssConfig);
#                 await sonic.init();
#                 try { await sonic.loadSynthDef("sonic-pi-beep"); } catch(e) {}
#                 state.instance = sonic;
#                 return sonic;
#             } catch(e) {
#                 state.promise = null;
#                 return null;
#             }
#         })();
#         return state.promise;
#     };
# }
# va

# %% [markdown]
# Only two options, and neither is equal — 5 can't be evenly divided into 2. The most balanced partition is `(3, 2)`, and you can hear it: a slightly lopsided pair. This is the basic feel of 5/8 time.

# %%
PS(7, 3)
# Out:
# ------------------------------------------
# PS(n=7, k=3) - Graph: feature_distance
# Mean: ~2.3333
# ------------------------------------------
#    partition  unique_count  span  variance
# 0  (5, 1, 1)             2     4    3.5556
# 1  (4, 2, 1)             3     3    1.5556
# 2  (3, 3, 1)             2     2    0.8889
# 3  (3, 2, 2)             2     1    0.2222
# ------------------------------------------

# %%
for p in PS(7, 3).partitions:
    rt = RT(subdivisions=p)
    print(f"S = {p}")
    print(f"{' + '.join(str(f) for f in rt.durations)} = {sum(rt.durations)}")
    plot(rt, layout='ratios').play(bpm=126, beat='1/4')
    print()
# Out:
# S = (5, 1, 1)
# 5/7 + 1/7 + 1/7 = 1
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_88b9bc64_r0" x="0.00" y="20.00" width="785.71" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_88b9bc64"/>
# <rect id="svgrt_88b9bc64_r1" x="785.71" y="20.00" width="157.14" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_88b9bc64"/>
# <rect id="svgrt_88b9bc64_r2" x="942.86" y="20.00" width="157.14" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_88b9bc64"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="785.71" y1="10.00" x2="785.71" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="942.86" y1="10.00" x2="942.86" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_88b9bc64_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_88b9bc64_r0_h" cx="392.8571" cy="25.0000" rx="648.2143" ry="15.0000" fill="url(#svgrt_88b9bc64_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_88b9bc64_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_88b9bc64_r1_h" cx="864.2857" cy="25.0000" rx="129.6429" ry="15.0000" fill="url(#svgrt_88b9bc64_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_88b9bc64_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_88b9bc64_r2_h" cx="1021.4286" cy="25.0000" rx="129.6429" ry="15.0000" fill="url(#svgrt_88b9bc64_r2_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_88b9bc64_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_88b9bc64(){
#     var data=["Node: 1\nProportion: 5\nMetric Onset: 0\nMetric Duration: 5/7", "Node: 2\nProportion: 1\nMetric Onset: 5/7\nMetric Duration: 1/7", "Node: 3\nProportion: 1\nMetric Onset: 6/7\nMetric Duration: 1/7"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_88b9bc64_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_88b9bc64,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_88b9bc64']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_88b9bc64,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_103eecdd_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_103eecdd_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_103eecdd_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_103eecdd_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_103eecdd_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
# var __klothoManifest = {
#   "synths": {
#     "sonic-pi-beep": { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_synth":      { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_sine":       { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_perc":       { "releaseMode": "free" }
#   },
#   "inserts": {
#     "__busRouter":        { "inParam": "inBus", "outParam": "outBus" },
#     "__busRouterMonitor": { "inParam": "inBus", "outParam": "outBus" }
#   }
# }
# ;
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (state && state.instance) return Promise.resolve(state.instance);
#         if (state && state.promise) return state.promise;
#         if
# S = (4, 2, 1)
# 4/7 + 2/7 + 1/7 = 1
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_d745b30e_r0" x="0.00" y="20.00" width="628.57" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_d745b30e"/>
# <rect id="svgrt_d745b30e_r1" x="628.57" y="20.00" width="314.29" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_d745b30e"/>
# <rect id="svgrt_d745b30e_r2" x="942.86" y="20.00" width="157.14" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_d745b30e"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="628.57" y1="10.00" x2="628.57" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="942.86" y1="10.00" x2="942.86" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_d745b30e_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_d745b30e_r0_h" cx="314.2857" cy="25.0000" rx="518.5714" ry="15.0000" fill="url(#svgrt_d745b30e_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_d745b30e_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_d745b30e_r1_h" cx="785.7143" cy="25.0000" rx="259.2857" ry="15.0000" fill="url(#svgrt_d745b30e_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_d745b30e_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_d745b30e_r2_h" cx="1021.4286" cy="25.0000" rx="129.6429" ry="15.0000" fill="url(#svgrt_d745b30e_r2_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_d745b30e_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_d745b30e(){
#     var data=["Node: 1\nProportion: 4\nMetric Onset: 0\nMetric Duration: 4/7", "Node: 2\nProportion: 2\nMetric Onset: 4/7\nMetric Duration: 2/7", "Node: 3\nProportion: 1\nMetric Onset: 6/7\nMetric Duration: 1/7"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_d745b30e_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_d745b30e,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_d745b30e']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_d745b30e,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_21d5d4a8_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_21d5d4a8_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_21d5d4a8_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_21d5d4a8_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_21d5d4a8_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
# var __klothoManifest = {
#   "synths": {
#     "sonic-pi-beep": { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_synth":      { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_sine":       { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_perc":       { "releaseMode": "free" }
#   },
#   "inserts": {
#     "__busRouter":        { "inParam": "inBus", "outParam": "outBus" },
#     "__busRouterMonitor": { "inParam": "inBus", "outParam": "outBus" }
#   }
# }
# ;
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (state && state.instance) return Promise.resolve(state.instance);
#         if (state && state.promise) return state.promise;
#         if
# S = (3, 3, 1)
# 3/7 + 3/7 + 1/7 = 1
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_d22bab6d_r0" x="0.00" y="20.00" width="471.43" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_d22bab6d"/>
# <rect id="svgrt_d22bab6d_r1" x="471.43" y="20.00" width="471.43" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_d22bab6d"/>
# <rect id="svgrt_d22bab6d_r2" x="942.86" y="20.00" width="157.14" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_d22bab6d"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="471.43" y1="10.00" x2="471.43" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="942.86" y1="10.00" x2="942.86" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_d22bab6d_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_d22bab6d_r0_h" cx="235.7143" cy="25.0000" rx="388.9286" ry="15.0000" fill="url(#svgrt_d22bab6d_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_d22bab6d_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_d22bab6d_r1_h" cx="707.1429" cy="25.0000" rx="388.9286" ry="15.0000" fill="url(#svgrt_d22bab6d_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_d22bab6d_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_d22bab6d_r2_h" cx="1021.4286" cy="25.0000" rx="129.6429" ry="15.0000" fill="url(#svgrt_d22bab6d_r2_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_d22bab6d_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_d22bab6d(){
#     var data=["Node: 1\nProportion: 3\nMetric Onset: 0\nMetric Duration: 3/7", "Node: 2\nProportion: 3\nMetric Onset: 3/7\nMetric Duration: 3/7", "Node: 3\nProportion: 1\nMetric Onset: 6/7\nMetric Duration: 1/7"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_d22bab6d_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_d22bab6d,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_d22bab6d']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_d22bab6d,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_ee0d800e_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_ee0d800e_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_ee0d800e_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_ee0d800e_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_ee0d800e_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
# var __klothoManifest = {
#   "synths": {
#     "sonic-pi-beep": { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_synth":      { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_sine":       { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_perc":       { "releaseMode": "free" }
#   },
#   "inserts": {
#     "__busRouter":        { "inParam": "inBus", "outParam": "outBus" },
#     "__busRouterMonitor": { "inParam": "inBus", "outParam": "outBus" }
#   }
# }
# ;
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (state && state.instance) return Promise.resolve(state.instance);
#         if (state && state.promise) return state.promise;
#         if
# S = (3, 2, 2)
# 3/7 + 2/7 + 2/7 = 1
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_1dcfc549_r0" x="0.00" y="20.00" width="471.43" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_1dcfc549"/>
# <rect id="svgrt_1dcfc549_r1" x="471.43" y="20.00" width="314.29" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_1dcfc549"/>
# <rect id="svgrt_1dcfc549_r2" x="785.71" y="20.00" width="314.29" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_1dcfc549"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="471.43" y1="10.00" x2="471.43" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="785.71" y1="10.00" x2="785.71" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_1dcfc549_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_1dcfc549_r0_h" cx="235.7143" cy="25.0000" rx="388.9286" ry="15.0000" fill="url(#svgrt_1dcfc549_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_1dcfc549_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_1dcfc549_r1_h" cx="628.5714" cy="25.0000" rx="259.2857" ry="15.0000" fill="url(#svgrt_1dcfc549_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_1dcfc549_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_1dcfc549_r2_h" cx="942.8571" cy="25.0000" rx="259.2857" ry="15.0000" fill="url(#svgrt_1dcfc549_r2_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_1dcfc549_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_1dcfc549(){
#     var data=["Node: 1\nProportion: 3\nMetric Onset: 0\nMetric Duration: 3/7", "Node: 2\nProportion: 2\nMetric Onset: 3/7\nMetric Duration: 2/7", "Node: 3\nProportion: 2\nMetric Onset: 5/7\nMetric Duration: 2/7"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_1dcfc549_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_1dcfc549,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_1dcfc549']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_1dcfc549,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_8f12d4b1_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_8f12d4b1_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_8f12d4b1_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_8f12d4b1_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_8f12d4b1_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
# var __klothoManifest = {
#   "synths": {
#     "sonic-pi-beep": { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_synth":      { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_sine":       { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_perc":       { "releaseMode": "free" }
#   },
#   "inserts": {
#     "__busRouter":        { "inParam": "inBus", "outParam": "outBus" },
#     "__busRouterMonitor": { "inParam": "inBus", "outParam": "outBus" }
#   }
# }
# ;
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (state && state.instance) return Promise.resolve(state.instance);
#         if (state && state.promise) return state.promise;
#         if (

# %% [markdown]
# 7 into 3 gives us four options. The most balanced, `(3, 2, 2)`, is a common 7/8 grouping — and again, it's not *quite* even. No partition of 7 into 3 can be. That inherent asymmetry is what gives odd meters their characteristic feel.

# %% [markdown]
# Let's push further:

# %%
PS(11, 4)
# Out:
# ----------------------------------------------
# PS(n=11, k=4) - Graph: feature_distance
# Mean: ~2.75
# ----------------------------------------------
#        partition  unique_count  span  variance
# 0   (8, 1, 1, 1)             2     7    9.1875
# 1   (7, 2, 1, 1)             3     6    6.1875
# 2   (6, 3, 1, 1)             3     5    4.1875
# 3   (6, 2, 2, 1)             3     5    3.6875
# 4   (5, 4, 1, 1)             3     4    3.1875
# 5   (5, 3, 2, 1)             4     4    2.1875
# 6   (5, 2, 2, 2)             2     3    1.6875
# 7   (4, 4, 2, 1)             3     3    1.6875
# 8   (4, 3, 3, 1)             3     3    1.1875
# 9   (4, 3, 2, 2)             3     2    0.6875
# 10  (3, 3, 3, 2)             2     1    0.1875
# ----------------------------------------------

# %%
for p in PS(11, 4).partitions:
    rt = RT(subdivisions=p)
    print(f"S = {p}")
    plot(rt, layout='ratios').play(bpm=126, beat='1/4')
    print()
# Out:
# S = (8, 1, 1, 1)
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_aae8a9c4_r0" x="0.00" y="20.00" width="800.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_aae8a9c4"/>
# <rect id="svgrt_aae8a9c4_r1" x="800.00" y="20.00" width="100.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_aae8a9c4"/>
# <rect id="svgrt_aae8a9c4_r2" x="900.00" y="20.00" width="100.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_aae8a9c4"/>
# <rect id="svgrt_aae8a9c4_r3" x="1000.00" y="20.00" width="100.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="3" data-tip-uid="svgrt_aae8a9c4"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="800.00" y1="10.00" x2="800.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="900.00" y1="10.00" x2="900.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1000.00" y1="10.00" x2="1000.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_aae8a9c4_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_aae8a9c4_r0_h" cx="400.0000" cy="25.0000" rx="660.0000" ry="15.0000" fill="url(#svgrt_aae8a9c4_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_aae8a9c4_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_aae8a9c4_r1_h" cx="850.0000" cy="25.0000" rx="82.5000" ry="15.0000" fill="url(#svgrt_aae8a9c4_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_aae8a9c4_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_aae8a9c4_r2_h" cx="950.0000" cy="25.0000" rx="82.5000" ry="15.0000" fill="url(#svgrt_aae8a9c4_r2_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_aae8a9c4_r3_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_aae8a9c4_r3_h" cx="1050.0000" cy="25.0000" rx="82.5000" ry="15.0000" fill="url(#svgrt_aae8a9c4_r3_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_aae8a9c4_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_aae8a9c4(){
#     var data=["Node: 1\nProportion: 8\nMetric Onset: 0\nMetric Duration: 8/11", "Node: 2\nProportion: 1\nMetric Onset: 8/11\nMetric Duration: 1/11", "Node: 3\nProportion: 1\nMetric Onset: 9/11\nMetric Duration: 1/11", "Node: 4\nProportion: 1\nMetric Onset: 10/11\nMetric Duration: 1/11"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_aae8a9c4_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_aae8a9c4,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_aae8a9c4']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_aae8a9c4,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_42954597_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_42954597_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_42954597_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_42954597_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_42954597_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples
# S = (7, 2, 1, 1)
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_2481c425_r0" x="0.00" y="20.00" width="700.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_2481c425"/>
# <rect id="svgrt_2481c425_r1" x="700.00" y="20.00" width="200.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_2481c425"/>
# <rect id="svgrt_2481c425_r2" x="900.00" y="20.00" width="100.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_2481c425"/>
# <rect id="svgrt_2481c425_r3" x="1000.00" y="20.00" width="100.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="3" data-tip-uid="svgrt_2481c425"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="700.00" y1="10.00" x2="700.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="900.00" y1="10.00" x2="900.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1000.00" y1="10.00" x2="1000.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_2481c425_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_2481c425_r0_h" cx="350.0000" cy="25.0000" rx="577.5000" ry="15.0000" fill="url(#svgrt_2481c425_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_2481c425_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_2481c425_r1_h" cx="800.0000" cy="25.0000" rx="165.0000" ry="15.0000" fill="url(#svgrt_2481c425_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_2481c425_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_2481c425_r2_h" cx="950.0000" cy="25.0000" rx="82.5000" ry="15.0000" fill="url(#svgrt_2481c425_r2_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_2481c425_r3_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_2481c425_r3_h" cx="1050.0000" cy="25.0000" rx="82.5000" ry="15.0000" fill="url(#svgrt_2481c425_r3_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_2481c425_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_2481c425(){
#     var data=["Node: 1\nProportion: 7\nMetric Onset: 0\nMetric Duration: 7/11", "Node: 2\nProportion: 2\nMetric Onset: 7/11\nMetric Duration: 2/11", "Node: 3\nProportion: 1\nMetric Onset: 9/11\nMetric Duration: 1/11", "Node: 4\nProportion: 1\nMetric Onset: 10/11\nMetric Duration: 1/11"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_2481c425_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_2481c425,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_2481c425']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_2481c425,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_2b95824d_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_2b95824d_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_2b95824d_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_2b95824d_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_2b95824d_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-sample
# S = (6, 3, 1, 1)
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_5b1d348f_r0" x="0.00" y="20.00" width="600.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_5b1d348f"/>
# <rect id="svgrt_5b1d348f_r1" x="600.00" y="20.00" width="300.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_5b1d348f"/>
# <rect id="svgrt_5b1d348f_r2" x="900.00" y="20.00" width="100.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_5b1d348f"/>
# <rect id="svgrt_5b1d348f_r3" x="1000.00" y="20.00" width="100.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="3" data-tip-uid="svgrt_5b1d348f"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="600.00" y1="10.00" x2="600.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="900.00" y1="10.00" x2="900.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1000.00" y1="10.00" x2="1000.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_5b1d348f_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_5b1d348f_r0_h" cx="300.0000" cy="25.0000" rx="495.0000" ry="15.0000" fill="url(#svgrt_5b1d348f_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_5b1d348f_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_5b1d348f_r1_h" cx="750.0000" cy="25.0000" rx="247.5000" ry="15.0000" fill="url(#svgrt_5b1d348f_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_5b1d348f_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_5b1d348f_r2_h" cx="950.0000" cy="25.0000" rx="82.5000" ry="15.0000" fill="url(#svgrt_5b1d348f_r2_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_5b1d348f_r3_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_5b1d348f_r3_h" cx="1050.0000" cy="25.0000" rx="82.5000" ry="15.0000" fill="url(#svgrt_5b1d348f_r3_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_5b1d348f_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_5b1d348f(){
#     var data=["Node: 1\nProportion: 6\nMetric Onset: 0\nMetric Duration: 6/11", "Node: 2\nProportion: 3\nMetric Onset: 6/11\nMetric Duration: 3/11", "Node: 3\nProportion: 1\nMetric Onset: 9/11\nMetric Duration: 1/11", "Node: 4\nProportion: 1\nMetric Onset: 10/11\nMetric Duration: 1/11"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_5b1d348f_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_5b1d348f,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_5b1d348f']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_5b1d348f,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_b10ac97e_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_b10ac97e_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_b10ac97e_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_b10ac97e_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_b10ac97e_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-sample
# S = (6, 2, 2, 1)
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_bac034dc_r0" x="0.00" y="20.00" width="600.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_bac034dc"/>
# <rect id="svgrt_bac034dc_r1" x="600.00" y="20.00" width="200.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_bac034dc"/>
# <rect id="svgrt_bac034dc_r2" x="800.00" y="20.00" width="200.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_bac034dc"/>
# <rect id="svgrt_bac034dc_r3" x="1000.00" y="20.00" width="100.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="3" data-tip-uid="svgrt_bac034dc"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="600.00" y1="10.00" x2="600.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="800.00" y1="10.00" x2="800.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1000.00" y1="10.00" x2="1000.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_bac034dc_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_bac034dc_r0_h" cx="300.0000" cy="25.0000" rx="495.0000" ry="15.0000" fill="url(#svgrt_bac034dc_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_bac034dc_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_bac034dc_r1_h" cx="700.0000" cy="25.0000" rx="165.0000" ry="15.0000" fill="url(#svgrt_bac034dc_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_bac034dc_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_bac034dc_r2_h" cx="900.0000" cy="25.0000" rx="165.0000" ry="15.0000" fill="url(#svgrt_bac034dc_r2_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_bac034dc_r3_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_bac034dc_r3_h" cx="1050.0000" cy="25.0000" rx="82.5000" ry="15.0000" fill="url(#svgrt_bac034dc_r3_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_bac034dc_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_bac034dc(){
#     var data=["Node: 1\nProportion: 6\nMetric Onset: 0\nMetric Duration: 6/11", "Node: 2\nProportion: 2\nMetric Onset: 6/11\nMetric Duration: 2/11", "Node: 3\nProportion: 2\nMetric Onset: 8/11\nMetric Duration: 2/11", "Node: 4\nProportion: 1\nMetric Onset: 10/11\nMetric Duration: 1/11"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_bac034dc_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_bac034dc,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_bac034dc']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_bac034dc,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_74a9c6bd_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_74a9c6bd_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_74a9c6bd_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_74a9c6bd_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_74a9c6bd_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-sampl
# S = (5, 4, 1, 1)
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_42e0113e_r0" x="0.00" y="20.00" width="500.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_42e0113e"/>
# <rect id="svgrt_42e0113e_r1" x="500.00" y="20.00" width="400.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_42e0113e"/>
# <rect id="svgrt_42e0113e_r2" x="900.00" y="20.00" width="100.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_42e0113e"/>
# <rect id="svgrt_42e0113e_r3" x="1000.00" y="20.00" width="100.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="3" data-tip-uid="svgrt_42e0113e"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="500.00" y1="10.00" x2="500.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="900.00" y1="10.00" x2="900.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1000.00" y1="10.00" x2="1000.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_42e0113e_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_42e0113e_r0_h" cx="250.0000" cy="25.0000" rx="412.5000" ry="15.0000" fill="url(#svgrt_42e0113e_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_42e0113e_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_42e0113e_r1_h" cx="700.0000" cy="25.0000" rx="330.0000" ry="15.0000" fill="url(#svgrt_42e0113e_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_42e0113e_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_42e0113e_r2_h" cx="950.0000" cy="25.0000" rx="82.5000" ry="15.0000" fill="url(#svgrt_42e0113e_r2_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_42e0113e_r3_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_42e0113e_r3_h" cx="1050.0000" cy="25.0000" rx="82.5000" ry="15.0000" fill="url(#svgrt_42e0113e_r3_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_42e0113e_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_42e0113e(){
#     var data=["Node: 1\nProportion: 5\nMetric Onset: 0\nMetric Duration: 5/11", "Node: 2\nProportion: 4\nMetric Onset: 5/11\nMetric Duration: 4/11", "Node: 3\nProportion: 1\nMetric Onset: 9/11\nMetric Duration: 1/11", "Node: 4\nProportion: 1\nMetric Onset: 10/11\nMetric Duration: 1/11"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_42e0113e_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_42e0113e,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_42e0113e']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_42e0113e,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_436f10bf_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_436f10bf_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_436f10bf_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_436f10bf_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_436f10bf_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-sample
# S = (5, 3, 2, 1)
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_6aaea144_r0" x="0.00" y="20.00" width="500.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_6aaea144"/>
# <rect id="svgrt_6aaea144_r1" x="500.00" y="20.00" width="300.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_6aaea144"/>
# <rect id="svgrt_6aaea144_r2" x="800.00" y="20.00" width="200.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_6aaea144"/>
# <rect id="svgrt_6aaea144_r3" x="1000.00" y="20.00" width="100.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="3" data-tip-uid="svgrt_6aaea144"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="500.00" y1="10.00" x2="500.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="800.00" y1="10.00" x2="800.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1000.00" y1="10.00" x2="1000.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_6aaea144_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_6aaea144_r0_h" cx="250.0000" cy="25.0000" rx="412.5000" ry="15.0000" fill="url(#svgrt_6aaea144_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_6aaea144_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_6aaea144_r1_h" cx="650.0000" cy="25.0000" rx="247.5000" ry="15.0000" fill="url(#svgrt_6aaea144_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_6aaea144_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_6aaea144_r2_h" cx="900.0000" cy="25.0000" rx="165.0000" ry="15.0000" fill="url(#svgrt_6aaea144_r2_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_6aaea144_r3_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_6aaea144_r3_h" cx="1050.0000" cy="25.0000" rx="82.5000" ry="15.0000" fill="url(#svgrt_6aaea144_r3_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_6aaea144_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_6aaea144(){
#     var data=["Node: 1\nProportion: 5\nMetric Onset: 0\nMetric Duration: 5/11", "Node: 2\nProportion: 3\nMetric Onset: 5/11\nMetric Duration: 3/11", "Node: 3\nProportion: 2\nMetric Onset: 8/11\nMetric Duration: 2/11", "Node: 4\nProportion: 1\nMetric Onset: 10/11\nMetric Duration: 1/11"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_6aaea144_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_6aaea144,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_6aaea144']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_6aaea144,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_9af2bdc2_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_9af2bdc2_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_9af2bdc2_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_9af2bdc2_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_9af2bdc2_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# ...
# <rect id="svgrt_e10249d2_r0" x="0.00" y="20.00" width="400.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_e10249d2"/>
# <rect id="svgrt_e10249d2_r1" x="400.00" y="20.00" width="300.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_e10249d2"/>
# <rect id="svgrt_e10249d2_r2" x="700.00" y="20.00" width="200.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_e10249d2"/>
# <rect id="svgrt_e10249d2_r3" x="900.00" y="20.00" width="200.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="3" data-tip-uid="svgrt_e10249d2"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="400.00" y1="10.00" x2="400.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="700.00" y1="10.00" x2="700.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="900.00" y1="10.00" x2="900.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_e10249d2_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_e10249d2_r0_h" cx="200.0000" cy="25.0000" rx="330.0000" ry="15.0000" fill="url(#svgrt_e10249d2_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_e10249d2_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_e10249d2_r1_h" cx="550.0000" cy="25.0000" rx="247.5000" ry="15.0000" fill="url(#svgrt_e10249d2_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_e10249d2_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_e10249d2_r2_h" cx="800.0000" cy="25.0000" rx="165.0000" ry="15.0000" fill="url(#svgrt_e10249d2_r2_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_e10249d2_r3_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_e10249d2_r3_h" cx="1000.0000" cy="25.0000" rx="165.0000" ry="15.0000" fill="url(#svgrt_e10249d2_r3_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_e10249d2_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_e10249d2(){
#     var data=["Node: 1\nProportion: 4\nMetric Onset: 0\nMetric Duration: 4/11", "Node: 2\nProportion: 3\nMetric Onset: 4/11\nMetric Duration: 3/11", "Node: 3\nProportion: 2\nMetric Onset: 7/11\nMetric Duration: 2/11", "Node: 4\nProportion: 2\nMetric Onset: 9/11\nMetric Duration: 2/11"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_e10249d2_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_e10249d2,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_e10249d2']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_e10249d2,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_5efedcdc_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_5efedcdc_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_5efedcdc_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_5efedcdc_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_5efedcdc_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@
# S = (3, 3, 3, 2)
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_94fc19f2_r0" x="0.00" y="20.00" width="300.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_94fc19f2"/>
# <rect id="svgrt_94fc19f2_r1" x="300.00" y="20.00" width="300.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_94fc19f2"/>
# <rect id="svgrt_94fc19f2_r2" x="600.00" y="20.00" width="300.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_94fc19f2"/>
# <rect id="svgrt_94fc19f2_r3" x="900.00" y="20.00" width="200.00" height="10.00" fill="#e6e6e6" stroke="none" data-idx="3" data-tip-uid="svgrt_94fc19f2"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="300.00" y1="10.00" x2="300.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="600.00" y1="10.00" x2="600.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="900.00" y1="10.00" x2="900.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_94fc19f2_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_94fc19f2_r0_h" cx="150.0000" cy="25.0000" rx="247.5000" ry="15.0000" fill="url(#svgrt_94fc19f2_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_94fc19f2_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_94fc19f2_r1_h" cx="450.0000" cy="25.0000" rx="247.5000" ry="15.0000" fill="url(#svgrt_94fc19f2_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_94fc19f2_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_94fc19f2_r2_h" cx="750.0000" cy="25.0000" rx="247.5000" ry="15.0000" fill="url(#svgrt_94fc19f2_r2_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_94fc19f2_r3_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_94fc19f2_r3_h" cx="1000.0000" cy="25.0000" rx="165.0000" ry="15.0000" fill="url(#svgrt_94fc19f2_r3_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_94fc19f2_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_94fc19f2(){
#     var data=["Node: 1\nProportion: 3\nMetric Onset: 0\nMetric Duration: 3/11", "Node: 2\nProportion: 3\nMetric Onset: 3/11\nMetric Duration: 3/11", "Node: 3\nProportion: 3\nMetric Onset: 6/11\nMetric Duration: 3/11", "Node: 4\nProportion: 2\nMetric Onset: 9/11\nMetric Duration: 2/11"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_94fc19f2_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_94fc19f2,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_94fc19f2']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_94fc19f2,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_17070e82_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_17070e82_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_17070e82_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_17070e82_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_17070e82_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@

# %% [markdown]
# 11 into 4 gives us 11 partitions — a much wider range of rhythmic options. Listen to the progression from top to bottom: the first partition `(8, 1, 1, 1)` is extremely lopsided, while the last `(3, 3, 3, 2)` is as close to even as 11 will allow. The partitions in between trace a smooth gradient from uneven to balanced.
#
# This is the real utility of `PS`: it gives us the *complete set* of rhythmic groupings for a given `n` and `k`, organized by their structural properties. We don't have to guess — we can see all the options and choose.

# %% [markdown]
# We can also ask: how does the number of groups `k` affect things for the same `n`?

# %%
for k in range(2, 5):
    ps_k = PS(13, k)
    print(f"\nPS(13, {k}) — {len(ps_k.partitions)} partitions:")
    for p in ps_k.partitions:
        rt = RT(subdivisions=p)
        plot(rt, layout='ratios').play(bpm=126, beat='1/4')
# Out:
# PS(13, 2) — 6 partitions:
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_e0af7a28_r0" x="0.00" y="20.00" width="1015.38" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_e0af7a28"/>
# <rect id="svgrt_e0af7a28_r1" x="1015.38" y="20.00" width="84.62" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_e0af7a28"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1015.38" y1="10.00" x2="1015.38" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_e0af7a28_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_e0af7a28_r0_h" cx="507.6923" cy="25.0000" rx="837.6923" ry="15.0000" fill="url(#svgrt_e0af7a28_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_e0af7a28_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_e0af7a28_r1_h" cx="1057.6923" cy="25.0000" rx="69.8077" ry="15.0000" fill="url(#svgrt_e0af7a28_r1_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_e0af7a28_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_e0af7a28(){
#     var data=["Node: 1\nProportion: 12\nMetric Onset: 0\nMetric Duration: 12/13", "Node: 2\nProportion: 1\nMetric Onset: 12/13\nMetric Duration: 1/13"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_e0af7a28_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_e0af7a28,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_e0af7a28']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_e0af7a28,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_7abec5e0_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_7abec5e0_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_7abec5e0_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_7abec5e0_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_7abec5e0_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
# var __klothoManifest = {
#   "synths": {
#     "sonic-pi-beep": { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_synth":      { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_sine":       { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_perc":       { "releaseMode": "free" }
#   },
#   "inserts": {
#     "__busRouter":        { "inParam": "inBus", "outParam": "outBus" },
#     "__busRouterMonitor": { "inParam": "inBus", "outParam": "outBus" }
#   }
# }
# ;
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (state && state.instance) return Promise.resolve(state.instance);
#         if (state && state.promise) return state.promise;
#         if (!state) {
#             state = { instance: null, promise: null, loadedDefs: new Set() };
#             globalThis.__klothoSonic = state;
#         }
#         state.promise = (async function() {
#             try {
#                 var mod = await import("https://unpkg.com/supersonic-scsynth@latest");
#                 globalThis.SuperSonic = mod.SuperSonic;
#                 var sonic = new mod.SuperSonic(__ssConfig);
#                 await sonic.init();
#                 try { await sonic.loadSynthDef("sonic-pi-beep"); } catch(e) {}
#                 state.instance = sonic;
#                 return sonic;
#             } catch(e) {
#                 state.promise = null;
#                 return null;
#             }
#         })();
#         return state.promise;
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_aebd451b_r0" x="0.00" y="20.00" width="930.77" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_aebd451b"/>
# <rect id="svgrt_aebd451b_r1" x="930.77" y="20.00" width="169.23" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_aebd451b"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="930.77" y1="10.00" x2="930.77" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_aebd451b_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_aebd451b_r0_h" cx="465.3846" cy="25.0000" rx="767.8846" ry="15.0000" fill="url(#svgrt_aebd451b_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_aebd451b_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_aebd451b_r1_h" cx="1015.3846" cy="25.0000" rx="139.6154" ry="15.0000" fill="url(#svgrt_aebd451b_r1_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_aebd451b_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_aebd451b(){
#     var data=["Node: 1\nProportion: 11\nMetric Onset: 0\nMetric Duration: 11/13", "Node: 2\nProportion: 2\nMetric Onset: 11/13\nMetric Duration: 2/13"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_aebd451b_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_aebd451b,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_aebd451b']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_aebd451b,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_f32a3c93_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_f32a3c93_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_f32a3c93_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_f32a3c93_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_f32a3c93_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
# var __klothoManifest = {
#   "synths": {
#     "sonic-pi-beep": { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_synth":      { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_sine":       { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_perc":       { "releaseMode": "free" }
#   },
#   "inserts": {
#     "__busRouter":        { "inParam": "inBus", "outParam": "outBus" },
#     "__busRouterMonitor": { "inParam": "inBus", "outParam": "outBus" }
#   }
# }
# ;
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (state && state.instance) return Promise.resolve(state.instance);
#         if (state && state.promise) return state.promise;
#         if (!state) {
#             state = { instance: null, promise: null, loadedDefs: new Set() };
#             globalThis.__klothoSonic = state;
#         }
#         state.promise = (async function() {
#             try {
#                 var mod = await import("https://unpkg.com/supersonic-scsynth@latest");
#                 globalThis.SuperSonic = mod.SuperSonic;
#                 var sonic = new mod.SuperSonic(__ssConfig);
#                 await sonic.init();
#                 try { await sonic.loadSynthDef("sonic-pi-beep"); } catch(e) {}
#                 state.instance = sonic;
#                 return sonic;
#             } catch(e) {
#                 state.promise = null;
#                 return null;
#             }
#         })();
#         return state.promise;
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_8b660da0_r0" x="0.00" y="20.00" width="846.15" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_8b660da0"/>
# <rect id="svgrt_8b660da0_r1" x="846.15" y="20.00" width="253.85" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_8b660da0"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="846.15" y1="10.00" x2="846.15" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_8b660da0_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_8b660da0_r0_h" cx="423.0769" cy="25.0000" rx="698.0769" ry="15.0000" fill="url(#svgrt_8b660da0_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_8b660da0_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_8b660da0_r1_h" cx="973.0769" cy="25.0000" rx="209.4231" ry="15.0000" fill="url(#svgrt_8b660da0_r1_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_8b660da0_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_8b660da0(){
#     var data=["Node: 1\nProportion: 10\nMetric Onset: 0\nMetric Duration: 10/13", "Node: 2\nProportion: 3\nMetric Onset: 10/13\nMetric Duration: 3/13"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_8b660da0_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_8b660da0,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_8b660da0']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_8b660da0,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_01042cb4_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_01042cb4_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_01042cb4_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_01042cb4_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_01042cb4_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
# var __klothoManifest = {
#   "synths": {
#     "sonic-pi-beep": { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_synth":      { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_sine":       { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_perc":       { "releaseMode": "free" }
#   },
#   "inserts": {
#     "__busRouter":        { "inParam": "inBus", "outParam": "outBus" },
#     "__busRouterMonitor": { "inParam": "inBus", "outParam": "outBus" }
#   }
# }
# ;
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (state && state.instance) return Promise.resolve(state.instance);
#         if (state && state.promise) return state.promise;
#         if (!state) {
#             state = { instance: null, promise: null, loadedDefs: new Set() };
#             globalThis.__klothoSonic = state;
#         }
#         state.promise = (async function() {
#             try {
#                 var mod = await import("https://unpkg.com/supersonic-scsynth@latest");
#                 globalThis.SuperSonic = mod.SuperSonic;
#                 var sonic = new mod.SuperSonic(__ssConfig);
#                 await sonic.init();
#                 try { await sonic.loadSynthDef("sonic-pi-beep"); } catch(e) {}
#                 state.instance = sonic;
#                 return sonic;
#             } catch(e) {
#                 state.promise = null;
#                 return null;
#             }
#         })();
#         return state.promise;
#     }
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_ba8356d8_r0" x="0.00" y="20.00" width="761.54" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_ba8356d8"/>
# <rect id="svgrt_ba8356d8_r1" x="761.54" y="20.00" width="338.46" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_ba8356d8"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="761.54" y1="10.00" x2="761.54" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_ba8356d8_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_ba8356d8_r0_h" cx="380.7692" cy="25.0000" rx="628.2692" ry="15.0000" fill="url(#svgrt_ba8356d8_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_ba8356d8_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_ba8356d8_r1_h" cx="930.7692" cy="25.0000" rx="279.2308" ry="15.0000" fill="url(#svgrt_ba8356d8_r1_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_ba8356d8_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_ba8356d8(){
#     var data=["Node: 1\nProportion: 9\nMetric Onset: 0\nMetric Duration: 9/13", "Node: 2\nProportion: 4\nMetric Onset: 9/13\nMetric Duration: 4/13"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_ba8356d8_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_ba8356d8,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_ba8356d8']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_ba8356d8,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_ec02bff7_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_ec02bff7_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_ec02bff7_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_ec02bff7_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_ec02bff7_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
# var __klothoManifest = {
#   "synths": {
#     "sonic-pi-beep": { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_synth":      { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_sine":       { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_perc":       { "releaseMode": "free" }
#   },
#   "inserts": {
#     "__busRouter":        { "inParam": "inBus", "outParam": "outBus" },
#     "__busRouterMonitor": { "inParam": "inBus", "outParam": "outBus" }
#   }
# }
# ;
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (state && state.instance) return Promise.resolve(state.instance);
#         if (state && state.promise) return state.promise;
#         if (!state) {
#             state = { instance: null, promise: null, loadedDefs: new Set() };
#             globalThis.__klothoSonic = state;
#         }
#         state.promise = (async function() {
#             try {
#                 var mod = await import("https://unpkg.com/supersonic-scsynth@latest");
#                 globalThis.SuperSonic = mod.SuperSonic;
#                 var sonic = new mod.SuperSonic(__ssConfig);
#                 await sonic.init();
#                 try { await sonic.loadSynthDef("sonic-pi-beep"); } catch(e) {}
#                 state.instance = sonic;
#                 return sonic;
#             } catch(e) {
#                 state.promise = null;
#                 return null;
#             }
#         })();
#         return state.promise;
#     };
# }
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_bb0b35b9_r0" x="0.00" y="20.00" width="676.92" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_bb0b35b9"/>
# <rect id="svgrt_bb0b35b9_r1" x="676.92" y="20.00" width="423.08" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_bb0b35b9"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="676.92" y1="10.00" x2="676.92" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_bb0b35b9_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_bb0b35b9_r0_h" cx="338.4615" cy="25.0000" rx="558.4615" ry="15.0000" fill="url(#svgrt_bb0b35b9_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_bb0b35b9_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_bb0b35b9_r1_h" cx="888.4615" cy="25.0000" rx="349.0385" ry="15.0000" fill="url(#svgrt_bb0b35b9_r1_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_bb0b35b9_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_bb0b35b9(){
#     var data=["Node: 1\nProportion: 8\nMetric Onset: 0\nMetric Duration: 8/13", "Node: 2\nProportion: 5\nMetric Onset: 8/13\nMetric Duration: 5/13"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_bb0b35b9_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_bb0b35b9,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_bb0b35b9']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_bb0b35b9,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_bf205c0b_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_bf205c0b_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_bf205c0b_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_bf205c0b_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_bf205c0b_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
# var __klothoManifest = {
#   "synths": {
#     "sonic-pi-beep": { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_synth":      { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_sine":       { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_perc":       { "releaseMode": "free" }
#   },
#   "inserts": {
#     "__busRouter":        { "inParam": "inBus", "outParam": "outBus" },
#     "__busRouterMonitor": { "inParam": "inBus", "outParam": "outBus" }
#   }
# }
# ;
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (state && state.instance) return Promise.resolve(state.instance);
#         if (state && state.promise) return state.promise;
#         if (!state) {
#             state = { instance: null, promise: null, loadedDefs: new Set() };
#             globalThis.__klothoSonic = state;
#         }
#         state.promise = (async function() {
#             try {
#                 var mod = await import("https://unpkg.com/supersonic-scsynth@latest");
#                 globalThis.SuperSonic = mod.SuperSonic;
#                 var sonic = new mod.SuperSonic(__ssConfig);
#                 await sonic.init();
#                 try { await sonic.loadSynthDef("sonic-pi-beep"); } catch(e) {}
#                 state.instance = sonic;
#                 return sonic;
#             } catch(e) {
#                 state.promise = null;
#                 return null;
#             }
#         })();
#         return state.promise;
#     };
# }
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_8b46f280_r0" x="0.00" y="20.00" width="592.31" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_8b46f280"/>
# <rect id="svgrt_8b46f280_r1" x="592.31" y="20.00" width="507.69" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_8b46f280"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="592.31" y1="10.00" x2="592.31" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_8b46f280_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_8b46f280_r0_h" cx="296.1538" cy="25.0000" rx="488.6538" ry="15.0000" fill="url(#svgrt_8b46f280_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_8b46f280_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_8b46f280_r1_h" cx="846.1538" cy="25.0000" rx="418.8462" ry="15.0000" fill="url(#svgrt_8b46f280_r1_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_8b46f280_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_8b46f280(){
#     var data=["Node: 1\nProportion: 7\nMetric Onset: 0\nMetric Duration: 7/13", "Node: 2\nProportion: 6\nMetric Onset: 7/13\nMetric Duration: 6/13"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_8b46f280_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_8b46f280,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_8b46f280']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_8b46f280,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_396b4591_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_396b4591_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_396b4591_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_396b4591_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_396b4591_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@latest/samples/"};
# var __klothoManifest = {
#   "synths": {
#     "sonic-pi-beep": { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_synth":      { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_sine":       { "releaseMode": "gate", "gateParam": "gate" },
#     "kl_perc":       { "releaseMode": "free" }
#   },
#   "inserts": {
#     "__busRouter":        { "inParam": "inBus", "outParam": "outBus" },
#     "__busRouterMonitor": { "inParam": "inBus", "outParam": "outBus" }
#   }
# }
# ;
# if (!globalThis.__ensureSuperSonic) {
#     globalThis.__ensureSuperSonic = function() {
#         var state = globalThis.__klothoSonic;
#         if (state && state.instance) return Promise.resolve(state.instance);
#         if (state && state.promise) return state.promise;
#         if (!state) {
#             state = { instance: null, promise: null, loadedDefs: new Set() };
#             globalThis.__klothoSonic = state;
#         }
#         state.promise = (async function() {
#             try {
#                 var mod = await import("https://unpkg.com/supersonic-scsynth@latest");
#                 globalThis.SuperSonic = mod.SuperSonic;
#                 var sonic = new mod.SuperSonic(__ssConfig);
#                 await sonic.init();
#                 try { await sonic.loadSynthDef("sonic-pi-beep"); } catch(e) {}
#                 state.instance = sonic;
#                 return sonic;
#             } catch(e) {
#                 state.promise = null;
#                 return null;
#             }
#         })();
# ...
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_e7d4a770_r0" x="0.00" y="20.00" width="338.46" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_e7d4a770"/>
# <rect id="svgrt_e7d4a770_r1" x="338.46" y="20.00" width="338.46" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_e7d4a770"/>
# <rect id="svgrt_e7d4a770_r2" x="676.92" y="20.00" width="253.85" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_e7d4a770"/>
# <rect id="svgrt_e7d4a770_r3" x="930.77" y="20.00" width="169.23" height="10.00" fill="#e6e6e6" stroke="none" data-idx="3" data-tip-uid="svgrt_e7d4a770"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="338.46" y1="10.00" x2="338.46" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="676.92" y1="10.00" x2="676.92" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="930.77" y1="10.00" x2="930.77" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_e7d4a770_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_e7d4a770_r0_h" cx="169.2308" cy="25.0000" rx="279.2308" ry="15.0000" fill="url(#svgrt_e7d4a770_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_e7d4a770_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_e7d4a770_r1_h" cx="507.6923" cy="25.0000" rx="279.2308" ry="15.0000" fill="url(#svgrt_e7d4a770_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_e7d4a770_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_e7d4a770_r2_h" cx="803.8462" cy="25.0000" rx="209.4231" ry="15.0000" fill="url(#svgrt_e7d4a770_r2_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_e7d4a770_r3_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_e7d4a770_r3_h" cx="1015.3846" cy="25.0000" rx="139.6154" ry="15.0000" fill="url(#svgrt_e7d4a770_r3_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_e7d4a770_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_e7d4a770(){
#     var data=["Node: 1\nProportion: 4\nMetric Onset: 0\nMetric Duration: 4/13", "Node: 2\nProportion: 4\nMetric Onset: 4/13\nMetric Duration: 4/13", "Node: 3\nProportion: 3\nMetric Onset: 8/13\nMetric Duration: 3/13", "Node: 4\nProportion: 2\nMetric Onset: 11/13\nMetric Duration: 2/13"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_e7d4a770_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_e7d4a770,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_e7d4a770']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_e7d4a770,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_f7c158ec_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_f7c158ec_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_f7c158ec_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_f7c158ec_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_f7c158ec_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples
# <div style="overflow-x:auto;overflow-y:hidden;background:black"><svg xmlns="http://www.w3.org/2000/svg" width="1100" height="50" viewBox="0 -50.0000 1100 50.0000" style="display:block;background:black" preserveAspectRatio="none"><g transform="scale(1,-1)"><rect x="0" y="0" width="1100" height="50" fill="black"/>
# <rect id="svgrt_fabbd337_r0" x="0.00" y="20.00" width="338.46" height="10.00" fill="#e6e6e6" stroke="none" data-idx="0" data-tip-uid="svgrt_fabbd337"/>
# <rect id="svgrt_fabbd337_r1" x="338.46" y="20.00" width="253.85" height="10.00" fill="#e6e6e6" stroke="none" data-idx="1" data-tip-uid="svgrt_fabbd337"/>
# <rect id="svgrt_fabbd337_r2" x="592.31" y="20.00" width="253.85" height="10.00" fill="#e6e6e6" stroke="none" data-idx="2" data-tip-uid="svgrt_fabbd337"/>
# <rect id="svgrt_fabbd337_r3" x="846.15" y="20.00" width="253.85" height="10.00" fill="#e6e6e6" stroke="none" data-idx="3" data-tip-uid="svgrt_fabbd337"/>
# <line x1="0.00" y1="10.00" x2="0.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="338.46" y1="10.00" x2="338.46" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="592.31" y1="10.00" x2="592.31" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="846.15" y1="10.00" x2="846.15" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <line x1="1100.00" y1="10.00" x2="1100.00" y2="40.00" stroke="#aaaaaa" stroke-width="2"/>
# <defs><radialGradient id="svgrt_fabbd337_r0_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_fabbd337_r0_h" cx="169.2308" cy="25.0000" rx="279.2308" ry="15.0000" fill="url(#svgrt_fabbd337_r0_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_fabbd337_r1_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_fabbd337_r1_h" cx="465.3846" cy="25.0000" rx="209.4231" ry="15.0000" fill="url(#svgrt_fabbd337_r1_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_fabbd337_r2_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_fabbd337_r2_h" cx="719.2308" cy="25.0000" rx="209.4231" ry="15.0000" fill="url(#svgrt_fabbd337_r2_rg)" style="display:none" pointer-events="none"/>
# <defs><radialGradient id="svgrt_fabbd337_r3_rg"><stop offset="0%" stop-color="rgb(100,160,255)" stop-opacity="0.5"/><stop offset="60%" stop-color="rgb(100,160,255)" stop-opacity="0.15"/><stop offset="100%" stop-color="rgb(100,160,255)" stop-opacity="0"/></radialGradient></defs>
# <ellipse id="svgrt_fabbd337_r3_h" cx="973.0769" cy="25.0000" rx="209.4231" ry="15.0000" fill="url(#svgrt_fabbd337_r3_rg)" style="display:none" pointer-events="none"/></g></svg></div><div id="svgrt_fabbd337_tip" style="
#     display:none;position:absolute;pointer-events:none;
#     background:rgba(30,30,30,0.92);color:#eee;font-family:monospace;
#     font-size:11px;padding:6px 10px;border-radius:4px;
#     white-space:pre;max-width:320px;z-index:10;
#     line-height:1.4;
# "></div>
# <script>
# (function _klothoTip_svgrt_fabbd337(){
#     var data=["Node: 1\nProportion: 4\nMetric Onset: 0\nMetric Duration: 4/13", "Node: 2\nProportion: 3\nMetric Onset: 4/13\nMetric Duration: 3/13", "Node: 3\nProportion: 3\nMetric Onset: 7/13\nMetric Duration: 3/13", "Node: 4\nProportion: 3\nMetric Onset: 10/13\nMetric Duration: 3/13"];
#     var active=null;
#     var freqs=null;
#     var tip=document.getElementById("svgrt_fabbd337_tip");
#     if(!tip){ setTimeout(_klothoTip_svgrt_fabbd337,50); return; }
#     var wrap=tip.parentElement;
#     if(wrap) wrap.style.position="relative";
#     var circles=document.querySelectorAll("[data-tip-uid='svgrt_fabbd337']");
#     if(!circles.length){ setTimeout(_klothoTip_svgrt_fabbd337,50); return; }
#
#     var _clickCtx=null;
#     function _playFreq(freq){
#         if(!freq||freq<=0) return;
#         try{
#             if(!_clickCtx) _clickCtx=new (window.AudioContext||window.webkitAudioContext)();
#             if(_clickCtx.state==="suspended") _clickCtx.resume();
#             var osc=_clickCtx.createOscillator();
#             var gain=_clickCtx.createGain();
#             osc.type="sine";
#             osc.frequency.value=freq;
#             gain.gain.setValueAtTime(0.3,_clickCtx.currentTime);
#             gain.gain.exponentialRampToValueAtTime(0.001,_clickCtx.currentTime+0.6);
#             osc.connect(gain);gain.connect(_clickCtx.destination);
#             osc.start();osc.stop(_clickCtx.currentTime+0.65);
#         }catch(e){}
#     }
#
#     circles.forEach(function(c){
#         c.addEventListener("mouseenter",function(ev){
#             var idx=parseInt(c.getAttribute("data-idx"),10);
#             if(isNaN(idx)||idx<0||idx>=data.length) return;
#             tip.textContent=data[idx];
#             if(active){
#                 if(active[idx]){
#                     tip.style.background="rgba(245,245,245,0.95)";
#                     tip.style.color="#222";
#                 }else{
#                     tip.style.background="rgba(30,30,30,0.92)";
#                     tip.style.color="#eee";
#                 }
#             }
#             tip.style.display="block";
#         });
#         c.addEventListener("mouseleave",function(){
#             tip.style.display="none";
#         });
#         c.addEventListener("mousemove",function(ev){
#             var r=wrap.getBoundingClientRect();
#             tip.style.left=(ev.clientX-r.left+12)+"px";
#             tip.style.top=(ev.clientY-r.top+12)+"px";
#         });
#         if(freqs){
#             c.style.cursor="pointer";
#             c.addEventListener("click",function(){
#                 var idx=parseInt(c.getAttribute("data-idx"),10);
#                 if(isNaN(idx)||idx<0||idx>=freqs.length) return;
#                 _playFreq(freqs[idx]);
#             });
#         }
#     });
# })();
# </script>
# <div id="klotho_svg_57b61c36_controls" style="
#     font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, monospace;
#     display: inline-flex; align-items: center; gap: 6px;
#     padding: 6px 10px; background: #1a1a2e; border-radius: 6px;
#     user-select: none; margin-top: 4px;">
#     <button id="klotho_svg_57b61c36_toggle" style="
#         width: 32px; height: 32px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0;">
#         <span id="klotho_svg_57b61c36_icon" style="
#             width: 0; height: 0;
#             border-top: 7px solid transparent; border-bottom: 7px solid transparent;
#             border-left: 12px solid #4ade80; margin-left: 3px;"></span>
#     </button>
#     <button id="klotho_svg_57b61c36_loop" style="
#         width: 28px; height: 28px; border: none; border-radius: 4px;
#         background: #16213e; cursor: pointer; display: flex;
#         align-items: center; justify-content: center; padding: 0; opacity: 0.5;">
#         <svg id="klotho_svg_57b61c36_loop_svg" width="16" height="16" viewBox="0 0 24 24"
#              fill="none" stroke="#a0a0a0" stroke-width="2.5"
#              stroke-linecap="round" stroke-linejoin="round">
#             <path d="M17 2l4 4-4 4"></path><path d="M3 11v-1a4 4 0 0 1 4-4h14"></path>
#             <path d="M7 22l-4-4 4-4"></path><path d="M21 13v1a4 4 0 0 1-4 4H3"></path>
#         </svg>
#     </button>
# </div>
# <script>
# var __ssConfig = {"baseURL": "https://unpkg.com/supersonic-scsynth@latest/dist/", "coreBaseURL": "https://unpkg.com/supersonic-scsynth-core@latest/", "synthdefBaseURL": "https://unpkg.com/supersonic-scsynth-synthdefs@latest/synthdefs/", "sampleBaseURL": "https://unpkg.com/supersonic-scsynth-samples@

# %% [markdown]
# A few things to notice:
#
# - Small `k` means fewer, longer groups — the rhythm is "chunkier".
# - Large `k` means many, shorter groups — the rhythm approaches a pulse.
# - For any given `k`, the most balanced partition (lowest variance) is always the one closest to dividing `n` evenly.
#
# ---

# %% [markdown]
# ## Filtering Choices

# %% [markdown]
# ---

# %% [markdown]
# ## Permutations

# %% [markdown]
# ---

# %% [markdown]
# ## Subdivisions

# %% [markdown]
# ---

# %% [markdown]
# ## Nesting

# %% [markdown]
# ---
